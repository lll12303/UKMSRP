# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, classification_report
#定义数据路径和输出文件路径
dpath = 'D:\\Python_study\\5组代码\\卒中发病预测\\'
outfile = dpath + 'output__new/Stroke__panel/Stroke_hierarchy.csv'
df = pd.read_csv("D:\\课题\\bio_people448749.csv")
# 确保 data_imputed 是 DataFrame
data_imputed_df = pd.read_csv("D:\\Python_study\\5组代码\\卒中发病预测\\bio_imputed_data448749(mean).csv")

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score
import time
import joblib
# 筛选来自英格兰的参与者
england_indices = df[df['Region'] == 'England'].index
X_england = data_imputed_df.loc[england_indices]
y_england = df.loc[england_indices, 'status']

# 定义5折交叉验证
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# 存储每折的评估结果
accuracy_scores = []
auc_scores = []
training_times = []
models = []
# 计算类别权重（需要在循环内计算，因为每折的分布可能不同）
# 注意：这里我们会在循环内计算，因为y_train在每折不同

# 固定参数（从你的网格中取第一个值）
params = {
    'alpha': 1.5,          # L1 正则化
    'lambda': 1.5,         # L2 正则化
    'gamma': 0.2,          # 分裂最小损失下降
    'colsample_bytree': 0.75,  # 特征采样比例
    'subsample': 0.85,     # 数据采样比例
    'learning_rate': 0.007, # 学习率
    'max_depth': 9,        # 树的最大深度
    'n_estimators': 5200,  # 树的数量
    'min_child_weight': 3, # 叶子节点最小样本权重
    'eval_metric':'auc'
}
# 开始交叉验证
for fold, (train_idx, val_idx) in enumerate(kf.split(X_england), 1):
    try:
        print(f"\n===== Fold {fold} =====\n")
        X_train, X_val = X_england.iloc[train_idx], X_england.iloc[val_idx]
        y_train, y_val = y_england.iloc[train_idx], y_england.iloc[val_idx]

        # 计算当前fold的类别权重
        scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)
        current_params = params.copy()
        current_params['scale_pos_weight'] = scale_pos_weight

        # 初始化模型
        model = XGBClassifier(**current_params)

        # 训练模型并计时
        start_time = time.time()
        print("Training started...")
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=10  # 每10轮显示一次进度
        )
        training_time = time.time() - start_time
        training_times.append(training_time)
        print(f"Training completed in {training_time:.2f} seconds")

        # 预测
        y_pred = model.predict(X_val)
        y_pred_proba = model.predict_proba(X_val)[:, 1]  # 获取正类的概率

        # 评估
        accuracy = accuracy_score(y_val, y_pred)
        auc = roc_auc_score(y_val, y_pred_proba)

        accuracy_scores.append(accuracy)
        auc_scores.append(auc)
        models.append(model)  # 保存当前fold的模型
        print(f"Fold {fold} Accuracy: {accuracy:.4f}")
        print(f"Fold {fold} AUC: {auc:.4f}")

    except KeyboardInterrupt:
        print("\nTraining interrupted by user")
        break
    except Exception as e:
        print(f"\nError occurred during fold {fold}: {str(e)}")
        continue

# 输出结果
if accuracy_scores:
    print("\n=== Final Results ===")
    print(f"Average Accuracy: {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
    print(f"Average AUC: {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
    print(f"Average Training Time: {np.mean(training_times):.2f} seconds")

    # 找到AUC最高的fold
    best_fold = np.argmax(auc_scores)
    best_model = models[best_fold]
    best_auc = auc_scores[best_fold]

    print(f"\nBest model from Fold {best_fold + 1} with AUC: {best_auc:.4f}")

    # 保存最佳模型
    model_filename = f"best_xgboost_model_fold{best_fold + 1}_auc{best_auc:.4f}.joblib"
    # joblib.dump(best_model, model_filename)
    print(f"Best model saved as {model_filename}")
else:
    print("\nNo valid results were obtained")
# Out:
# ===== Fold 1 =====
#
# Training started...
# [0]	validation_0-auc:0.60352
# [10]	validation_0-auc:0.65387
# [20]	validation_0-auc:0.65968
# [30]	validation_0-auc:0.66249
# [40]	validation_0-auc:0.66416
# [50]	validation_0-auc:0.66532
# [60]	validation_0-auc:0.66625
# [70]	validation_0-auc:0.66790
# [80]	validation_0-auc:0.66788
# [90]	validation_0-auc:0.66775
# [100]	validation_0-auc:0.66764
# [110]	validation_0-auc:0.66837
# [120]	validation_0-auc:0.66931
# [130]	validation_0-auc:0.66949
# [140]	validation_0-auc:0.66922
# [150]	validation_0-auc:0.66898
# [160]	validation_0-auc:0.66916
# [170]	validation_0-auc:0.66921
# [180]	validation_0-auc:0.66950
# [190]	validation_0-auc:0.66962
# [200]	validation_0-auc:0.66988
# [210]	validation_0-auc:0.66936
# [220]	validation_0-auc:0.66946
# [230]	validation_0-auc:0.66958
# [240]	validation_0-auc:0.66968
# [250]	validation_0-auc:0.66960
# [260]	validation_0-auc:0.66955
# [270]	validation_0-auc:0.66960
# [280]	validation_0-auc:0.66945
# [290]	validation_0-auc:0.66909
# [300]	validation_0-auc:0.66898
# [310]	validation_0-auc:0.66867
# [320]	validation_0-auc:0.66865
# [330]	validation_0-auc:0.66869
# [340]	validation_0-auc:0.66852
# [350]	validation_0-auc:0.66821
# [360]	validation_0-auc:0.66827
# [370]	validation_0-auc:0.66822
# [380]	validation_0-auc:0.66802
# [390]	validation_0-auc:0.66806
# [400]	validation_0-auc:0.66775
# [410]	validation_0-auc:0.66754
# [420]	validation_0-auc:0.66738
# [430]	validation_0-auc:0.66709
# [440]	validation_0-auc:0.66671
# [450]	validation_0-auc:0.66653
# [460]	validation_0-auc:0.66614
# [470]	validation_0-auc:0.66609
# [480]	validation_0-auc:0.66579
# [490]	validation_0-auc:0.66558
# [500]	validation_0-auc:0.66552
# [510]	validation_0-auc:0.66512
# [520]	validation_0-auc:0.66487
# [530]	validation_0-auc:0.66454
# [540]	validation_0-auc:0.66435
# [550]	validation_0-auc:0.66401
# [560]	validation_0-auc:0.66360
# [570]	validation_0-auc:0.66324
# [580]	validation_0-auc:0.66276
# [590]	validation_0-auc:0.66251
# [600]	validation_0-auc:0.66215
# [610]	validation_0-auc:0.66202
# [620]	validation_0-auc:0.66185
# [630]	validation_0-auc:0.66155
# [640]	validation_0-auc:0.66132
# [650]	validation_0-auc:0.66095
# [660]	validation_0-auc:0.66079
# [670]	validation_0-auc:0.66073
# [680]	validation_0-auc:0.66054
# [690]	validation_0-auc:0.66022
# [700]	validation_0-auc:0.65999
# [710]	validation_0-auc:0.65973
# [720]	validation_0-auc:0.65958
# [730]	validation_0-auc:0.65934
# [740]	validation_0-auc:0.65904
# [750]	validation_0-auc:0.65871
# [760]	validation_0-auc:0.65851
# [770]	validation_0-auc:0.65834
# [780]	validation_0-auc:0.65804
# [790]	validation_0-auc:0.65787
# [800]	validation_0-auc:0.65755
# [810]	validation_0-auc:0.65735
# [820]	validation_0-auc:0.65696
# [830]	validation_0-auc:0.65676
# [840]	validation_0-auc:0.65658
# [850]	validation_0-auc:0.65641
# [860]	validation_0-auc:0.65612
# [870]	validation_0-auc:0.65579
# [880]	validation_0-auc:0.65564
# [890]	validation_0-auc:0.65527
# [900]	validation_0-auc:0.65476
# [910]	validation_0-auc:0.65451
# [920]	validation_0-auc:0.65433
# [930]	validation_0-auc:0.65404
# [940]	validation_0-auc:0.65372
# [950]	validation_0-auc:0.65351
# [960]	validation_0-auc:0.65337
# [970]	validation_0-auc:0.65309
# [980]	validation_0-auc:0.65292
# [990]	validation_0-auc:0.65267
# [1000]	validation_0-auc:0.65250
# [1010]	validation_0-auc:0.65230
# [1020]	validation_0-auc:0.65223
# [1030]	validation_0-auc:0.65207
# [1040]	validation_0-auc:0.65191
# [1050]	validation_0-auc:0.65173
# [1060]	validation_0-auc:0.65153
# [1070]	validation_0-auc:0.65142
# [1080]	validation_0-auc:0.65117
# [1090]	validation_0-auc:0.65088
# [1100]	validation_0-auc:0.65057
# [1110]	validation_0-auc:0.65039
# [1120]	validation_0-auc:0.65019
# [1130]	validation_0-auc:0.64992
# [1140]	validation_0-auc:0.64967
# [1150]	validation_0-auc:0.64940
# [1160]	validation_0-auc:0.64919
# [1170]	validation_0-auc:0.64907
# [1180]	validation_0-auc:0.64872
# [1190]	validation_0-auc:0.64842
# [1200]	validation_0-auc:0.64823
# [1210]	validation_0-auc:0.64797
# [1220]	validation_0-auc:0.64767
# [1230]	validation_0-auc:0.64754
# [1240]	validation_0-auc:0.64734
# [1250]	validation_0-auc:0.64712
# [1260]	validation_0-auc:0.64683
# [1270]	validation_0-auc:0.64664
# [1280]	validation_0-auc:0.64621
# [1290]	validation_0-auc:0.64582
# [1300]	validation_0-auc:0.64559
# [1310]	validation_0-auc:0.64523
# [1320]	validation_0-auc:0.64504
# [1330]	validation_0-auc:0.64480
# [1340]	validation_0-auc:0.64464
# [1350]	validation_0-auc:0.64428
# [1360]	validation_0-auc:0.64415
# [1370]	validation_0-auc:0.64397
# [1380]	validation_0-auc:0.64372
# [1390]	validation_0-auc:0.64335
# [1400]	validation_0-auc:0.64302
# [1410]	validation_0-auc:0.64283
# [1420]	validation_0-auc:0.64264
# [1430]	validation_0-auc:0.64255
# [1440]	validation_0-auc:0.64227
# [1450]	validation_0-auc:0.64192
# [1460]	validation_0-auc:0.64162
# [1470]	validation_0-auc:0.64131
# [1480]	validation_0-auc:0.64114
# [1490]	validation_0-auc:0.64098
# [1500]	validation_0-auc:0.64078
# [1510]	validation_0-auc:0.64059
# [1520]	validation_0-auc:0.64030
# [1530]	validation_0-auc:0.64011
# [1540]	validation_0-auc:0.63976
# [1550]	validation_0-auc:0.63966
# [1560]	validation_0-auc:0.63957
# [1570]	validation_0-auc:0.63928
# [1580]	validation_0-auc:0.63900
# [1590]	validation_0-auc:0.63881
# [1600]	validation_0-auc:0.63859
# [1610]	validation_0-auc:0.63836
# [1620]	validation_0-auc:0.63824
# [1630]	validation_0-auc:0.63800
# [1640]	validation_0-auc:0.63775
# [1650]	validation_0-auc:0.63754
# [1660]	validation_0-auc:0.63744
# [1670]	validation_0-auc:0.63732
# [1680]	validation_0-auc:0.63713
# [1690]	validation_0-auc:0.63695
# [1700]	validation_0-auc:0.63685
# [1710]	validation_0-auc:0.63658
# [1720]	validation_0-auc:0.63638
# [1730]	validation_0-auc:0.63612
# [1740]	validation_0-auc:0.63591
# [1750]	validation_0-auc:0.63572
# [1760]	validation_0-auc:0.63538
# [1770]	validation_0-auc:0.63523
# [1780]	validation_0-auc:0.63506
# [1790]	validation_0-auc:0.63486
# [1800]	validation_0-auc:0.63475
# [1810]	validation_0-auc:0.63457
# [1820]	validation_0-auc:0.63453
# [1830]	validation_0-auc:0.63432
# [1840]	validation_0-auc:0.63407
# [1850]	validation_0-auc:0.63386
# [1860]	validation_0-auc:0.63362
# [1870]	validation_0-auc:0.63349
# [1880]	validation_0-auc:0.63334
# [1890]	validation_0-auc:0.63327
# [1900]	validation_0-auc:0.63302
# [1910]	validation_0-auc:0.63277
# [1920]	validation_0-auc:0.63253
# [1930]	validation_0-auc:0.63233
# [1940]	validation_0-auc:0.63198
# [1950]	validation_0-auc:0.63180
# [1960]	validation_0-auc:0.63156
# [1970]	validation_0-auc:0.63137
# [1980]	validation_0-auc:0.63123
# [1990]	validation_0-auc:0.63101
# [2000]	validation_0-auc:0.63075
# [2010]	validation_0-auc:0.63048
# [2020]	validation_0-auc:0.63024
# [2030]	validation_0-auc:0.63014
# [2040]	validation_0-auc:0.62989
# [2050]	validation_0-auc:0.62968
# [2060]	validation_0-auc:0.62951
# [2070]	validation_0-auc:0.62923
# [2080]	validation_0-auc:0.62911
# [2090]	validation_0-auc:0.62888
# [2100]	validation_0-auc:0.62856
# [2110]	validation_0-auc:0.62837
# [2120]	validation_0-auc:0.62813
# [2130]	validation_0-auc:0.62795
# [2140]	validation_0-auc:0.62783
# [2150]	validation_0-auc:0.62759
# [2160]	validation_0-auc:0.62753
# [2170]	validation_0-auc:0.62737
# [2180]	validation_0-auc:0.62721
# [2190]	validation_0-auc:0.62707
# [2200]	validation_0-auc:0.62694
# [2210]	validation_0-auc:0.62670
# [2220]	validation_0-auc:0.62654
# [2230]	validation_0-auc:0.62630
# [2240]	validation_0-auc:0.62617
# [2250]	validation_0-auc:0.62607
# [2260]	validation_0-auc:0.62597
# [2270]	validation_0-auc:0.62579
# [2280]	validation_0-auc:0.62555
# [2290]	validation_0-auc:0.62534
# [2300]	validation_0-auc:0.62517
# [2310]	validation_0-auc:0.62495
# [2320]	validation_0-auc:0.62483
# [2330]	validation_0-auc:0.62463
# [2340]	validation_0-auc:0.62446
# [2350]	validation_0-auc:0.62420
# [2360]	validation_0-auc:0.62396
# [2370]	validation_0-auc:0.62383
# [2380]	validation_0-auc:0.62366
# [2390]	validation_0-auc:0.62342
# [2400]	validation_0-auc:0.62339
# [2410]	validation_0-auc:0.62326
# [2420]	validation_0-auc:0.62307
# [2430]	validation_0-auc:0.62298
# [2440]	validation_0-auc:0.62286
# [2450]	validation_0-auc:0.62269
# [2460]	validation_0-auc:0.62242
# [2470]	validation_0-auc:0.62226
# [2480]	validation_0-auc:0.62205
# [2490]	validation_0-auc:0.62190
# [2500]	validation_0-auc:0.62177
# [2510]	validation_0-auc:0.62171
# [2520]	validation_0-auc:0.62163
# [2530]	validation_0-auc:0.62157
# [2540]	validation_0-auc:0.62140
# [2550]	validation_0-auc:0.62116
# [2560]	validation_0-auc:0.62100
# [2570]	validation_0-auc:0.62083
# [2580]	validation_0-auc:0.62083
# [2590]	validation_0-auc:0.62077
# [2600]	validation_0-auc:0.62054
# [2610]	validation_0-auc:0.62046
# [2620]	validation_0-auc:0.62030
# [2630]	validation_0-auc:0.62015
# [2640]	validation_0-auc:0.61988
# [2650]	validation_0-auc:0.61963
# [2660]	validation_0-auc:0.61950
# [2670]	validation_0-auc:0.61946
# [2680]	validation_0-auc:0.61922
# [2690]	validation_0-auc:0.61910
# [2700]	validation_0-auc:0.61890
# [2710]	validation_0-auc:0.61872
# [2720]	validation_0-auc:0.61858
# [2730]	validation_0-auc:0.61849
# [2740]	validation_0-auc:0.61837
# [2750]	validation_0-auc:0.61835
# [2760]	validation_0-auc:0.61822
# [2770]	validation_0-auc:0.61807
# [2780]	validation_0-auc:0.61797
# [2790]	validation_0-auc:0.61780
# [2800]	validation_0-auc:0.61763
# [2810]	validation_0-auc:0.61744
# [2820]	validation_0-auc:0.61734
# [2830]	validation_0-auc:0.61722
# [2840]	validation_0-auc:0.61703
# [2850]	validation_0-auc:0.61692
# [2860]	validation_0-auc:0.61676
# [2870]	validation_0-auc:0.61659
# [2880]	validation_0-auc:0.61655
# [2890]	validation_0-auc:0.61647
# [2900]	validation_0-auc:0.61639
# [2910]	validation_0-auc:0.61617
# [2920]	validation_0-auc:0.61597
# [2930]	validation_0-auc:0.61583
# [2940]	validation_0-auc:0.61563
# [2950]	validation_0-auc:0.61549
# [2960]	validation_0-auc:0.61536
# [2970]	validation_0-auc:0.61521
# [2980]	validation_0-auc:0.61509
# [2990]	validation_0-auc:0.61494
# [3000]	validation_0-auc:0.61475
# [3010]	validation_0-auc:0.61460
# [3020]	validation_0-auc:0.61452
# [3030]	validation_0-auc:0.61430
# [3040]	validation_0-auc:0.61416
# [3050]	validation_0-auc:0.61401
# [3060]	validation_0-auc:0.61382
# [3070]	validation_0-auc:0.61374
# [3080]	validation_0-auc:0.61354
# [3090]	validation_0-auc:0.61339
# [3100]	validation_0-auc:0.61331
# [3110]	validation_0-auc:0.61323
# [3120]	validation_0-auc:0.61320
# [3130]	validation_0-auc:0.61311
# [3140]	validation_0-auc:0.61299
# [3150]	validation_0-auc:0.61292
# [3160]	validation_0-auc:0.61277
# [3170]	validation_0-auc:0.61268
# [3180]	validation_0-auc:0.61251
# [3190]	validation_0-auc:0.61237
# [3200]	validation_0-auc:0.61224
# [3210]	validation_0-auc:0.61213
# [3220]	validation_0-auc:0.61200
# [3230]	validation_0-auc:0.61192
# [3240]	validation_0-auc:0.61179
# [3250]	validation_0-auc:0.61169
# [3260]	validation_0-auc:0.61163
# [3270]	validation_0-auc:0.61149
# [3280]	validation_0-auc:0.61138
# [3290]	validation_0-auc:0.61129
# [3300]	validation_0-auc:0.61113
# [3310]	validation_0-auc:0.61102
# [3320]	validation_0-auc:0.61091
# [3330]	validation_0-auc:0.61081
# [3340]	validation_0-auc:0.61072
# [3350]	validation_0-auc:0.61051
# [3360]	validation_0-auc:0.61034
# [3370]	validation_0-auc:0.61019
# [3380]	validation_0-auc:0.61007
# [3390]	validation_0-auc:0.60994
# [3400]	validation_0-auc:0.60978
# [3410]	validation_0-auc:0.60967
# [3420]	validation_0-auc:0.60953
# [3430]	validation_0-auc:0.60949
# [3440]	validation_0-auc:0.60941
# [3450]	validation_0-auc:0.60924
# [3460]	validation_0-auc:0.60923
# [3470]	validation_0-auc:0.60919
# [3480]	validation_0-auc:0.60911
# [3490]	validation_0-auc:0.60911
# [3500]	validation_0-auc:0.60897
# [3510]	validation_0-auc:0.60889
# [3520]	validation_0-auc:0.60869
# [3530]	validation_0-auc:0.60863
# [3540]	validation_0-auc:0.60846
# [3550]	validation_0-auc:0.60829
# [3560]	validation_0-auc:0.60823
# [3570]	validation_0-auc:0.60816
# [3580]	validation_0-auc:0.60806
# [3590]	validation_0-auc:0.60792
# [3600]	validation_0-auc:0.60782
# [3610]	validation_0-auc:0.60776
# [3620]	validation_0-auc:0.60762
# [3630]	validation_0-auc:0.60750
# [3640]	validation_0-auc:0.60737
# [3650]	validation_0-auc:0.60721
# [3660]	validation_0-auc:0.60707
# [3670]	validation_0-auc:0.60697
# [3680]	validation_0-auc:0.60682
# [3690]	validation_0-auc:0.60669
# [3700]	validation_0-auc:0.60662
# [3710]	validation_0-auc:0.60652
# [3720]	validation_0-auc:0.60646
# [3730]	validation_0-auc:0.60638
# [3740]	validation_0-auc:0.60631
# [3750]	validation_0-auc:0.60624
# [3760]	validation_0-auc:0.60614
# [3770]	validation_0-auc:0.60601
# [3780]	validation_0-auc:0.60589
# [3790]	validation_0-auc:0.60591
# [3800]	validation_0-auc:0.60583
# [3810]	validation_0-auc:0.60574
# [3820]	validation_0-auc:0.60563
# [3830]	validation_0-auc:0.60557
# [3840]	validation_0-auc:0.60553
# [3850]	validation_0-auc:0.60536
# [3860]	validation_0-auc:0.60527
# [3870]	validation_0-auc:0.60515
# [3880]	validation_0-auc:0.60503
# [3890]	validation_0-auc:0.60501
# [3900]	validation_0-auc:0.60486
# [3910]	validation_0-auc:0.60480
# [3920]	validation_0-auc:0.60465
# [3930]	validation_0-auc:0.60460
# [3940]	validation_0-auc:0.60456
# [3950]	validation_0-auc:0.60454
# [3960]	validation_0-auc:0.60439
# [3970]	validation_0-auc:0.60425
# [3980]	validation_0-auc:0.60416
# [3990]	validation_0-auc:0.60411
# [4000]	validation_0-auc:0.60393
# [4010]	validation_0-auc:0.60380
# [4020]	validation_0-auc:0.60369
# [4030]	validation_0-auc:0.60367
# [4040]	validation_0-auc:0.60360
# [4050]	validation_0-auc:0.60355
# [4060]	validation_0-auc:0.60343
# [4070]	validation_0-auc:0.60335
# [4080]	validation_0-auc:0.60323
# [4090]	validation_0-auc:0.60309
# [4100]	validation_0-auc:0.60303
# [4110]	validation_0-auc:0.60287
# [4120]	validation_0-auc:0.60281
# [4130]	validation_0-auc:0.60280
# [4140]	validation_0-auc:0.60279
# [4150]	validation_0-auc:0.60276
# [4160]	validation_0-auc:0.60278
# [4170]	validation_0-auc:0.60272
# [4180]	validation_0-auc:0.60270
# [4190]	validation_0-auc:0.60256
# [4200]	validation_0-auc:0.60251
# [4210]	validation_0-auc:0.60244
# [4220]	validation_0-auc:0.60240
# [4230]	validation_0-auc:0.60234
# [4240]	validation_0-auc:0.60236
# [4250]	validation_0-auc:0.60228
# [4260]	validation_0-auc:0.60225
# [4270]	validation_0-auc:0.60222
# [4280]	validation_0-auc:0.60217
# [4290]	validation_0-auc:0.60218
# [4300]	validation_0-auc:0.60222
# [4310]	validation_0-auc:0.60215
# [4320]	validation_0-auc:0.60205
# [4330]	validation_0-auc:0.60200
# [4340]	validation_0-auc:0.60202
# [4350]	validation_0-auc:0.60201
# [4360]	validation_0-auc:0.60199
# [4370]	validation_0-auc:0.60187
# [4380]	validation_0-auc:0.60188
# [4390]	validation_0-auc:0.60183
# [4400]	validation_0-auc:0.60169
# [4410]	validation_0-auc:0.60161
# [4420]	validation_0-auc:0.60155
# [4430]	validation_0-auc:0.60141
# [4440]	validation_0-auc:0.60132
# [4450]	validation_0-auc:0.60125
# [4460]	validation_0-auc:0.60116
# [4470]	validation_0-auc:0.60114
# [4480]	validation_0-auc:0.60105
# [4490]	validation_0-auc:0.60094
# [4500]	validation_0-auc:0.60089
# [4510]	validation_0-auc:0.60085
# [4520]	validation_0-auc:0.60074
# [4530]	validation_0-auc:0.60070
# [4540]	validation_0-auc:0.60066
# [4550]	validation_0-auc:0.60059
# [4560]	validation_0-auc:0.60054
# [4570]	validation_0-auc:0.60050
# [4580]	validation_0-auc:0.60042
# [4590]	validation_0-auc:0.60040
# [4600]	validation_0-auc:0.60032
# [4610]	validation_0-auc:0.60026
# [4620]	validation_0-auc:0.60024
# [4630]	validation_0-auc:0.60015
# [4640]	validation_0-auc:0.60006
# [4650]	validation_0-auc:0.59994
# [4660]	validation_0-auc:0.59992
# [4670]	validation_0-auc:0.59992
# [4680]	validation_0-auc:0.59982
# [4690]	validation_0-auc:0.59980
# [4700]	validation_0-auc:0.59967
# [4710]	validation_0-auc:0.59960
# [4720]	validation_0-auc:0.59956
# [4730]	validation_0-auc:0.59944
# [4740]	validation_0-auc:0.59933
# [4750]	validation_0-auc:0.59924
# [4760]	validation_0-auc:0.59917
# [4770]	validation_0-auc:0.59913
# [4780]	validation_0-auc:0.59904
# [4790]	validation_0-auc:0.59896
# [4800]	validation_0-auc:0.59893
# [4810]	validation_0-auc:0.59885
# [4820]	validation_0-auc:0.59881
# [4830]	validation_0-auc:0.59886
# [4840]	validation_0-auc:0.59880
# [4850]	validation_0-auc:0.59873
# [4860]	validation_0-auc:0.59875
# [4870]	validation_0-auc:0.59869
# [4880]	validation_0-auc:0.59860
# [4890]	validation_0-auc:0.59855
# [4900]	validation_0-auc:0.59846
# [4910]	validation_0-auc:0.59847
# [4920]	validation_0-auc:0.59842
# [4930]	validation_0-auc:0.59837
# [4940]	validation_0-auc:0.59839
# [4950]	validation_0-auc:0.59831
# [4960]	validation_0-auc:0.59834
# [4970]	validation_0-auc:0.59828
# [4980]	validation_0-auc:0.59822
# [4990]	validation_0-auc:0.59810
# [5000]	validation_0-auc:0.59805
# [5010]	validation_0-auc:0.59800
# [5020]	validation_0-auc:0.59803
# [5030]	validation_0-auc:0.59803
# [5040]	validation_0-auc:0.59804
# [5050]	validation_0-auc:0.59794
# [5060]	validation_0-auc:0.59795
# [5070]	validation_0-auc:0.59795
# [5080]	validation_0-auc:0.59794
# [5090]	validation_0-auc:0.59790
# [5100]	validation_0-auc:0.59778
# [5110]	validation_0-auc:0.59776
# [5120]	validation_0-auc:0.59769
# [5130]	validation_0-auc:0.59770
# [5140]	validation_0-auc:0.59758
# [5150]	validation_0-auc:0.59751
# [5160]	validation_0-auc:0.59746
# [5170]	validation_0-auc:0.59745
# [5180]	validation_0-auc:0.59738
# [5190]	validation_0-auc:0.59731
# [5199]	validation_0-auc:0.59729
# Training completed in 3292.51 seconds
# Fold 1 Accuracy: 0.9632
# Fold 1 AUC: 0.5973
#
# ===== Fold 2 =====
#
# Training started...
# [0]	validation_0-auc:0.60418
# [10]	validation_0-auc:0.64948
# [20]	validation_0-auc:0.65776
# [30]	validation_0-auc:0.66502
# [40]	validation_0-auc:0.66593
# [50]	validation_0-auc:0.66739
# [60]	validation_0-auc:0.66697
# [70]	validation_0-auc:0.66807
# [80]	validation_0-auc:0.66784
# [90]	validation_0-auc:0.66819
# [100]	validation_0-auc:0.66844
# [110]	validation_0-auc:0.66869
# [120]	validation_0-auc:0.66853
# [130]	validation_0-auc:0.66885
# [140]	validation_0-auc:0.66910
# [150]	validation_0-auc:0.66935
# [160]	validation_0-auc:0.66961
# [170]	validation_0-auc:0.66933
# [180]	validation_0-auc:0.66962
# [190]	validation_0-auc:0.66905
# [200]	validation_0-auc:0.66914
# [210]	validation_0-auc:0.66881
# [220]	validation_0-auc:0.66862
# [230]	validation_0-auc:0.66893
# [240]	validation_0-auc:0.66878
# [250]	validation_0-auc:0.66831
# [260]	validation_0-auc:0.66810
# [270]	validation_0-auc:0.66798
# [280]	validation_0-auc:0.66795
# [290]	validation_0-auc:0.66779
# [300]	validation_0-auc:0.66769
# [310]	validation_0-auc:0.66760
# [320]	validation_0-auc:0.66725
# [330]	validation_0-auc:0.66699
# [340]	validation_0-auc:0.66683
# [350]	validation_0-auc:0.66657
# [360]	validation_0-auc:0.66650
# [370]	validation_0-auc:0.66632
# [380]	validation_0-auc:0.66628
# [390]	validation_0-auc:0.66616
# [400]	validation_0-auc:0.66560
# [410]	validation_0-auc:0.66545
# [420]	validation_0-auc:0.66524
# [430]	validation_0-auc:0.66505
# [440]	validation_0-auc:0.66504
# [450]	validation_0-auc:0.66476
# [460]	validation_0-auc:0.66443
# [470]	validation_0-auc:0.66453
# [480]	validation_0-auc:0.66438
# [490]	validation_0-auc:0.66405
# [500]	validation_0-auc:0.66407
# [510]	validation_0-auc:0.66389
# [520]	validation_0-auc:0.66391
# [530]	validation_0-auc:0.66366
# [540]	validation_0-auc:0.66352
# [550]	validation_0-auc:0.66330
# [560]	validation_0-auc:0.66313
# [570]	validation_0-auc:0.66297
# [580]	validation_0-auc:0.66253
# [590]	validation_0-auc:0.66233
# [600]	validation_0-auc:0.66206
# [610]	validation_0-auc:0.66191
# [620]	validation_0-auc:0.66161
# [630]	validation_0-auc:0.66150
# [640]	validation_0-auc:0.66134
# [650]	validation_0-auc:0.66117
# [660]	validation_0-auc:0.66093
# [670]	validation_0-auc:0.66083
# [680]	validation_0-auc:0.66043
# [690]	validation_0-auc:0.66009
# [700]	validation_0-auc:0.65981
# [710]	validation_0-auc:0.65955
# [720]	validation_0-auc:0.65930
# [730]	validation_0-auc:0.65889
# [740]	validation_0-auc:0.65893
# [750]	validation_0-auc:0.65860
# [760]	validation_0-auc:0.65834
# [770]	validation_0-auc:0.65812
# [780]	validation_0-auc:0.65793
# [790]	validation_0-auc:0.65770
# [800]	validation_0-auc:0.65752
# [810]	validation_0-auc:0.65726
# [820]	validation_0-auc:0.65696
# [830]	validation_0-auc:0.65672
# [840]	validation_0-auc:0.65665
# [850]	validation_0-auc:0.65652
# [860]	validation_0-auc:0.65607
# [870]	validation_0-auc:0.65585
# [880]	validation_0-auc:0.65566
# [890]	validation_0-auc:0.65540
# [900]	validation_0-auc:0.65519
# [910]	validation_0-auc:0.65500
# [920]	validation_0-auc:0.65487
# [930]	validation_0-auc:0.65474
# [940]	validation_0-auc:0.65444
# [950]	validation_0-auc:0.65426
# [960]	validation_0-auc:0.65402
# [970]	validation_0-auc:0.65396
# [980]	validation_0-auc:0.65375
# [990]	validation_0-auc:0.65361
# [1000]	validation_0-auc:0.65327
# [1010]	validation_0-auc:0.65306
# [1020]	validation_0-auc:0.65285
# [1030]	validation_0-auc:0.65253
# [1040]	validation_0-auc:0.65229
# [1050]	validation_0-auc:0.65203
# [1060]	validation_0-auc:0.65178
# [1070]	validation_0-auc:0.65143
# [1080]	validation_0-auc:0.65135
# [1090]	validation_0-auc:0.65124
# [1100]	validation_0-auc:0.65103
# [1110]	validation_0-auc:0.65068
# [1120]	validation_0-auc:0.65056
# [1130]	validation_0-auc:0.65043
# [1140]	validation_0-auc:0.65014
# [1150]	validation_0-auc:0.64982
# [1160]	validation_0-auc:0.64948
# [1170]	validation_0-auc:0.64917
# [1180]	validation_0-auc:0.64908
# [1190]	validation_0-auc:0.64885
# [1200]	validation_0-auc:0.64867
# [1210]	validation_0-auc:0.64851
# [1220]	validation_0-auc:0.64830
# [1230]	validation_0-auc:0.64806
# [1240]	validation_0-auc:0.64781
# [1250]	validation_0-auc:0.64773
# [1260]	validation_0-auc:0.64750
# [1270]	validation_0-auc:0.64731
# [1280]	validation_0-auc:0.64704
# [1290]	validation_0-auc:0.64682
# [1300]	validation_0-auc:0.64653
# [1310]	validation_0-auc:0.64620
# [1320]	validation_0-auc:0.64601
# [1330]	validation_0-auc:0.64581
# [1340]	validation_0-auc:0.64554
# [1350]	validation_0-auc:0.64539
# [1360]	validation_0-auc:0.64520
# [1370]	validation_0-auc:0.64492
# [1380]	validation_0-auc:0.64476
# [1390]	validation_0-auc:0.64456
# [1400]	validation_0-auc:0.64443
# [1410]	validation_0-auc:0.64430
# [1420]	validation_0-auc:0.64394
# [1430]	validation_0-auc:0.64372
# [1440]	validation_0-auc:0.64346
# [1450]	validation_0-auc:0.64337
# [1460]	validation_0-auc:0.64313
# [1470]	validation_0-auc:0.64293
# [1480]	validation_0-auc:0.64265
# [1490]	validation_0-auc:0.64231
# [1500]	validation_0-auc:0.64197
# [1510]	validation_0-auc:0.64170
# [1520]	validation_0-auc:0.64157
# [1530]	validation_0-auc:0.64143
# [1540]	validation_0-auc:0.64118
# [1550]	validation_0-auc:0.64103
# [1560]	validation_0-auc:0.64075
# [1570]	validation_0-auc:0.64064
# [1580]	validation_0-auc:0.64029
# [1590]	validation_0-auc:0.64013
# [1600]	validation_0-auc:0.63997
# [1610]	validation_0-auc:0.63964
# [1620]	validation_0-auc:0.63943
# [1630]	validation_0-auc:0.63922
# [1640]	validation_0-auc:0.63898
# [1650]	validation_0-auc:0.63864
# [1660]	validation_0-auc:0.63832
# [1670]	validation_0-auc:0.63811
# [1680]	validation_0-auc:0.63794
# [1690]	validation_0-auc:0.63772
# [1700]	validation_0-auc:0.63762
# [1710]	validation_0-auc:0.63734
# [1720]	validation_0-auc:0.63710
# [1730]	validation_0-auc:0.63689
# [1740]	validation_0-auc:0.63675
# [1750]	validation_0-auc:0.63653
# [1760]	validation_0-auc:0.63633
# [1770]	validation_0-auc:0.63627
# [1780]	validation_0-auc:0.63607
# [1790]	validation_0-auc:0.63585
# [1800]	validation_0-auc:0.63556
# [1810]	validation_0-auc:0.63531
# [1820]	validation_0-auc:0.63513
# [1830]	validation_0-auc:0.63503
# [1840]	validation_0-auc:0.63475
# [1850]	validation_0-auc:0.63455
# [1860]	validation_0-auc:0.63436
# [1870]	validation_0-auc:0.63422
# [1880]	validation_0-auc:0.63396
# [1890]	validation_0-auc:0.63376
# [1900]	validation_0-auc:0.63359
# [1910]	validation_0-auc:0.63343
# [1920]	validation_0-auc:0.63321
# [1930]	validation_0-auc:0.63298
# [1940]	validation_0-auc:0.63283
# [1950]	validation_0-auc:0.63264
# [1960]	validation_0-auc:0.63245
# [1970]	validation_0-auc:0.63229
# [1980]	validation_0-auc:0.63209
# [1990]	validation_0-auc:0.63182
# [2000]	validation_0-auc:0.63172
# [2010]	validation_0-auc:0.63152
# [2020]	validation_0-auc:0.63136
# [2030]	validation_0-auc:0.63121
# [2040]	validation_0-auc:0.63101
# [2050]	validation_0-auc:0.63072
# [2060]	validation_0-auc:0.63050
# [2070]	validation_0-auc:0.63030
# [2080]	validation_0-auc:0.63011
# [2090]	validation_0-auc:0.62991
# [2100]	validation_0-auc:0.62978
# [2110]	validation_0-auc:0.62952
# [2120]	validation_0-auc:0.62928
# [2130]	validation_0-auc:0.62911
# [2140]	validation_0-auc:0.62891
# [2150]	validation_0-auc:0.62859
# [2160]	validation_0-auc:0.62842
# [2170]	validation_0-auc:0.62834
# [2180]	validation_0-auc:0.62819
# [2190]	validation_0-auc:0.62816
# [2200]	validation_0-auc:0.62812
# [2210]	validation_0-auc:0.62797
# [2220]	validation_0-auc:0.62773
# [2230]	validation_0-auc:0.62764
# [2240]	validation_0-auc:0.62755
# [2250]	validation_0-auc:0.62730
# [2260]	validation_0-auc:0.62716
# [2270]	validation_0-auc:0.62702
# [2280]	validation_0-auc:0.62676
# [2290]	validation_0-auc:0.62658
# [2300]	validation_0-auc:0.62640
# [2310]	validation_0-auc:0.62626
# [2320]	validation_0-auc:0.62612
# [2330]	validation_0-auc:0.62570
# [2340]	validation_0-auc:0.62558
# [2350]	validation_0-auc:0.62532
# [2360]	validation_0-auc:0.62520
# [2370]	validation_0-auc:0.62508
# [2380]	validation_0-auc:0.62483
# [2390]	validation_0-auc:0.62462
# [2400]	validation_0-auc:0.62440
# [2410]	validation_0-auc:0.62423
# [2420]	validation_0-auc:0.62413
# [2430]	validation_0-auc:0.62400
# [2440]	validation_0-auc:0.62404
# [2450]	validation_0-auc:0.62391
# [2460]	validation_0-auc:0.62376
# [2470]	validation_0-auc:0.62357
# [2480]	validation_0-auc:0.62337
# [2490]	validation_0-auc:0.62315
# [2500]	validation_0-auc:0.62301
# [2510]	validation_0-auc:0.62286
# [2520]	validation_0-auc:0.62270
# [2530]	validation_0-auc:0.62258
# [2540]	validation_0-auc:0.62238
# [2550]	validation_0-auc:0.62237
# [2560]	validation_0-auc:0.62226
# [2570]	validation_0-auc:0.62202
# [2580]	validation_0-auc:0.62185
# [2590]	validation_0-auc:0.62165
# [2600]	validation_0-auc:0.62144
# [2610]	validation_0-auc:0.62132
# [2620]	validation_0-auc:0.62112
# [2630]	validation_0-auc:0.62096
# [2640]	validation_0-auc:0.62074
# [2650]	validation_0-auc:0.62058
# [2660]	validation_0-auc:0.62049
# [2670]	validation_0-auc:0.62032
# [2680]	validation_0-auc:0.62023
# [2690]	validation_0-auc:0.62010
# [2700]	validation_0-auc:0.62004
# [2710]	validation_0-auc:0.61996
# [2720]	validation_0-auc:0.61980
# [2730]	validation_0-auc:0.61969
# [2740]	validation_0-auc:0.61955
# [2750]	validation_0-auc:0.61946
# [2760]	validation_0-auc:0.61924
# [2770]	validation_0-auc:0.61918
# [2780]	validation_0-auc:0.61905
# [2790]	validation_0-auc:0.61889
# [2800]	validation_0-auc:0.61874
# [2810]	validation_0-auc:0.61857
# [2820]	validation_0-auc:0.61837
# [2830]	validation_0-auc:0.61816
# [2840]	validation_0-auc:0.61812
# [2850]	validation_0-auc:0.61800
# [2860]	validation_0-auc:0.61792
# [2870]	validation_0-auc:0.61779
# [2880]	validation_0-auc:0.61757
# [2890]	validation_0-auc:0.61747
# [2900]	validation_0-auc:0.61731
# [2910]	validation_0-auc:0.61721
# [2920]	validation_0-auc:0.61714
# [2930]	validation_0-auc:0.61694
# [2940]	validation_0-auc:0.61684
# [2950]	validation_0-auc:0.61671
# [2960]	validation_0-auc:0.61659
# [2970]	validation_0-auc:0.61644
# [2980]	validation_0-auc:0.61639
# [2990]	validation_0-auc:0.61620
# [3000]	validation_0-auc:0.61613
# [3010]	validation_0-auc:0.61601
# [3020]	validation_0-auc:0.61582
# [3030]	validation_0-auc:0.61574
# [3040]	validation_0-auc:0.61556
# [3050]	validation_0-auc:0.61546
# [3060]	validation_0-auc:0.61523
# [3070]	validation_0-auc:0.61503
# [3080]	validation_0-auc:0.61488
# [3090]	validation_0-auc:0.61462
# [3100]	validation_0-auc:0.61448
# [3110]	validation_0-auc:0.61433
# [3120]	validation_0-auc:0.61421
# [3130]	validation_0-auc:0.61402
# [3140]	validation_0-auc:0.61386
# [3150]	validation_0-auc:0.61387
# [3160]	validation_0-auc:0.61375
# [3170]	validation_0-auc:0.61359
# [3180]	validation_0-auc:0.61340
# [3190]	validation_0-auc:0.61329
# [3200]	validation_0-auc:0.61316
# [3210]	validation_0-auc:0.61302
# [3220]	validation_0-auc:0.61289
# [3230]	validation_0-auc:0.61277
# [3240]	validation_0-auc:0.61261
# [3250]	validation_0-auc:0.61250
# [3260]	validation_0-auc:0.61241
# [3270]	validation_0-auc:0.61226
# [3280]	validation_0-auc:0.61211
# [3290]	validation_0-auc:0.61187
# [3300]	validation_0-auc:0.61175
# [3310]	validation_0-auc:0.61165
# [3320]	validation_0-auc:0.61158
# [3330]	validation_0-auc:0.61143
# [3340]	validation_0-auc:0.61145
# [3350]	validation_0-auc:0.61133
# [3360]	validation_0-auc:0.61118
# [3370]	validation_0-auc:0.61101
# [3380]	validation_0-auc:0.61082
# [3390]	validation_0-auc:0.61073
# [3400]	validation_0-auc:0.61053
# [3410]	validation_0-auc:0.61043
# [3420]	validation_0-auc:0.61032
# [3430]	validation_0-auc:0.61022
# [3440]	validation_0-auc:0.61015
# [3450]	validation_0-auc:0.61003
# [3460]	validation_0-auc:0.60986
# [3470]	validation_0-auc:0.60976
# [3480]	validation_0-auc:0.60959
# [3490]	validation_0-auc:0.60950
# [3500]	validation_0-auc:0.60941
# [3510]	validation_0-auc:0.60932
# [3520]	validation_0-auc:0.60933
# [3530]	validation_0-auc:0.60918
# [3540]	validation_0-auc:0.60910
# [3550]	validation_0-auc:0.60908
# [3560]	validation_0-auc:0.60896
# [3570]	validation_0-auc:0.60882
# [3580]	validation_0-auc:0.60873
# [3590]	validation_0-auc:0.60860
# [3600]	validation_0-auc:0.60854
# [3610]	validation_0-auc:0.60836
# [3620]	validation_0-auc:0.60825
# [3630]	validation_0-auc:0.60809
# [3640]	validation_0-auc:0.60794
# [3650]	validation_0-auc:0.60786
# [3660]	validation_0-auc:0.60779
# [3670]	validation_0-auc:0.60778
# [3680]	validation_0-auc:0.60780
# [3690]	validation_0-auc:0.60764
# [3700]	validation_0-auc:0.60757
# [3710]	validation_0-auc:0.60753
# [3720]	validation_0-auc:0.60737
# [3730]	validation_0-auc:0.60726
# [3740]	validation_0-auc:0.60721
# [3750]	validation_0-auc:0.60714
# [3760]	validation_0-auc:0.60700
# [3770]	validation_0-auc:0.60689
# [3780]	validation_0-auc:0.60678
# [3790]	validation_0-auc:0.60668
# [3800]	validation_0-auc:0.60659
# [3810]	validation_0-auc:0.60651
# [3820]	validation_0-auc:0.60638
# [3830]	validation_0-auc:0.60633
# [3840]	validation_0-auc:0.60611
# [3850]	validation_0-auc:0.60603
# [3860]	validation_0-auc:0.60596
# [3870]	validation_0-auc:0.60581
# [3880]	validation_0-auc:0.60574
# [3890]	validation_0-auc:0.60565
# [3900]	validation_0-auc:0.60563
# [3910]	validation_0-auc:0.60560
# [3920]	validation_0-auc:0.60548
# [3930]	validation_0-auc:0.60544
# [3940]	validation_0-auc:0.60528
# [3950]	validation_0-auc:0.60519
# [3960]	validation_0-auc:0.60516
# [3970]	validation_0-auc:0.60505
# [3980]	validation_0-auc:0.60501
# [3990]	validation_0-auc:0.60491
# [4000]	validation_0-auc:0.60491
# [4010]	validation_0-auc:0.60488
# [4020]	validation_0-auc:0.60476
# [4030]	validation_0-auc:0.60476
# [4040]	validation_0-auc:0.60467
# [4050]	validation_0-auc:0.60457
# [4060]	validation_0-auc:0.60446
# [4070]	validation_0-auc:0.60439
# [4080]	validation_0-auc:0.60430
# [4090]	validation_0-auc:0.60415
# [4100]	validation_0-auc:0.60395
# [4110]	validation_0-auc:0.60391
# [4120]	validation_0-auc:0.60384
# [4130]	validation_0-auc:0.60379
# [4140]	validation_0-auc:0.60374
# [4150]	validation_0-auc:0.60369
# [4160]	validation_0-auc:0.60370
# [4170]	validation_0-auc:0.60361
# [4180]	validation_0-auc:0.60355
# [4190]	validation_0-auc:0.60353
# [4200]	validation_0-auc:0.60343
# [4210]	validation_0-auc:0.60332
# [4220]	validation_0-auc:0.60323
# [4230]	validation_0-auc:0.60327
# [4240]	validation_0-auc:0.60320
# [4250]	validation_0-auc:0.60313
# [4260]	validation_0-auc:0.60308
# [4270]	validation_0-auc:0.60304
# [4280]	validation_0-auc:0.60305
# [4290]	validation_0-auc:0.60296
# [4300]	validation_0-auc:0.60296
# [4310]	validation_0-auc:0.60285
# [4320]	validation_0-auc:0.60287
# [4330]	validation_0-auc:0.60279
# [4340]	validation_0-auc:0.60279
# [4350]	validation_0-auc:0.60272
# [4360]	validation_0-auc:0.60262
# [4370]	validation_0-auc:0.60253
# [4380]	validation_0-auc:0.60243
# [4390]	validation_0-auc:0.60237
# [4400]	validation_0-auc:0.60233
# [4410]	validation_0-auc:0.60223
# [4420]	validation_0-auc:0.60220
# [4430]	validation_0-auc:0.60219
# [4440]	validation_0-auc:0.60219
# [4450]	validation_0-auc:0.60205
# [4460]	validation_0-auc:0.60199
# [4470]	validation_0-auc:0.60192
# [4480]	validation_0-auc:0.60183
# [4490]	validation_0-auc:0.60185
# [4500]	validation_0-auc:0.60173
# [4510]	validation_0-auc:0.60168
# [4520]	validation_0-auc:0.60163
# [4530]	validation_0-auc:0.60160
# [4540]	validation_0-auc:0.60147
# [4550]	validation_0-auc:0.60144
# [4560]	validation_0-auc:0.60138
# [4570]	validation_0-auc:0.60139
# [4580]	validation_0-auc:0.60139
# [4590]	validation_0-auc:0.60134
# [4600]	validation_0-auc:0.60134
# [4610]	validation_0-auc:0.60122
# [4620]	validation_0-auc:0.60115
# [4630]	validation_0-auc:0.60109
# [4640]	validation_0-auc:0.60105
# [4650]	validation_0-auc:0.60103
# [4660]	validation_0-auc:0.60097
# [4670]	validation_0-auc:0.60089
# [4680]	validation_0-auc:0.60083
# [4690]	validation_0-auc:0.60076
# [4700]	validation_0-auc:0.60071
# [4710]	validation_0-auc:0.60066
# [4720]	validation_0-auc:0.60064
# [4730]	validation_0-auc:0.60052
# [4740]	validation_0-auc:0.60048
# [4750]	validation_0-auc:0.60041
# [4760]	validation_0-auc:0.60044
# [4770]	validation_0-auc:0.60038
# [4780]	validation_0-auc:0.60038
# [4790]	validation_0-auc:0.60033
# [4800]	validation_0-auc:0.60032
# [4810]	validation_0-auc:0.60024
# [4820]	validation_0-auc:0.60016
# [4830]	validation_0-auc:0.60014
# [4840]	validation_0-auc:0.60012
# [4850]	validation_0-auc:0.60009
# [4860]	validation_0-auc:0.60006
# [4870]	validation_0-auc:0.60005
# [4880]	validation_0-auc:0.60002
# [4890]	validation_0-auc:0.59993
# [4900]	validation_0-auc:0.59991
# [4910]	validation_0-auc:0.59986
# [4920]	validation_0-auc:0.59977
# [4930]	validation_0-auc:0.59966
# [4940]	validation_0-auc:0.59970
# [4950]	validation_0-auc:0.59958
# [4960]	validation_0-auc:0.59953
# [4970]	validation_0-auc:0.59942
# [4980]	validation_0-auc:0.59936
# [4990]	validation_0-auc:0.59931
# [5000]	validation_0-auc:0.59929
# [5010]	validation_0-auc:0.59925
# [5020]	validation_0-auc:0.59922
# [5030]	validation_0-auc:0.59921
# [5040]	validation_0-auc:0.59920
# [5050]	validation_0-auc:0.59909
# [5060]	validation_0-auc:0.59901
# [5070]	validation_0-auc:0.59895
# [5080]	validation_0-auc:0.59896
# [5090]	validation_0-auc:0.59894
# [5100]	validation_0-auc:0.59893
# [5110]	validation_0-auc:0.59888
# [5120]	validation_0-auc:0.59891
# [5130]	validation_0-auc:0.59889
# [5140]	validation_0-auc:0.59883
# [5150]	validation_0-auc:0.59879
# [5160]	validation_0-auc:0.59875
# [5170]	validation_0-auc:0.59871
# [5180]	validation_0-auc:0.59867
# [5190]	validation_0-auc:0.59862
# [5199]	validation_0-auc:0.59860
# Training completed in 2168.97 seconds
# Fold 2 Accuracy: 0.9616
# Fold 2 AUC: 0.5986
#
# ===== Fold 3 =====
#
# Training started...
# [0]	validation_0-auc:0.60902
# [10]	validation_0-auc:0.65919
# [20]	validation_0-auc:0.66407
# [30]	validation_0-auc:0.66810
# [40]	validation_0-auc:0.66987
# [50]	validation_0-auc:0.67069
# [60]	validation_0-auc:0.67104
# [70]	validation_0-auc:0.67197
# [80]	validation_0-auc:0.67220
# [90]	validation_0-auc:0.67187
# [100]	validation_0-auc:0.67157
# [110]	validation_0-auc:0.67199
# [120]	validation_0-auc:0.67148
# [130]	validation_0-auc:0.67139
# [140]	validation_0-auc:0.67154
# [150]	validation_0-auc:0.67203
# [160]	validation_0-auc:0.67218
# [170]	validation_0-auc:0.67226
# [180]	validation_0-auc:0.67313
# [190]	validation_0-auc:0.67342
# [200]	validation_0-auc:0.67320
# [210]	validation_0-auc:0.67320
# [220]	validation_0-auc:0.67314
# [230]	validation_0-auc:0.67332
# [240]	validation_0-auc:0.67361
# [250]	validation_0-auc:0.67353
# [260]	validation_0-auc:0.67348
# [270]	validation_0-auc:0.67345
# [280]	validation_0-auc:0.67331
# [290]	validation_0-auc:0.67307
# [300]	validation_0-auc:0.67282
# [310]	validation_0-auc:0.67260
# [320]	validation_0-auc:0.67244
# [330]	validation_0-auc:0.67242
# [340]	validation_0-auc:0.67225
# [350]	validation_0-auc:0.67218
# [360]	validation_0-auc:0.67213
# [370]	validation_0-auc:0.67231
# [380]	validation_0-auc:0.67204
# [390]	validation_0-auc:0.67177
# [400]	validation_0-auc:0.67160
# [410]	validation_0-auc:0.67120
# [420]	validation_0-auc:0.67107
# [430]	validation_0-auc:0.67107
# [440]	validation_0-auc:0.67092
# [450]	validation_0-auc:0.67066
# [460]	validation_0-auc:0.67062
# [470]	validation_0-auc:0.67063
# [480]	validation_0-auc:0.67052
# [490]	validation_0-auc:0.67027
# [500]	validation_0-auc:0.67012
# [510]	validation_0-auc:0.66958
# [520]	validation_0-auc:0.66952
# [530]	validation_0-auc:0.66929
# [540]	validation_0-auc:0.66908
# [550]	validation_0-auc:0.66898
# [560]	validation_0-auc:0.66888
# [570]	validation_0-auc:0.66872
# [580]	validation_0-auc:0.66839
# [590]	validation_0-auc:0.66824
# [600]	validation_0-auc:0.66789
# [610]	validation_0-auc:0.66756
# [620]	validation_0-auc:0.66739
# [630]	validation_0-auc:0.66733
# [640]	validation_0-auc:0.66741
# [650]	validation_0-auc:0.66705
# [660]	validation_0-auc:0.66688
# [670]	validation_0-auc:0.66676
# [680]	validation_0-auc:0.66655
# [690]	validation_0-auc:0.66637
# [700]	validation_0-auc:0.66627
# [710]	validation_0-auc:0.66602
# [720]	validation_0-auc:0.66584
# [730]	validation_0-auc:0.66555
# [740]	validation_0-auc:0.66528
# [750]	validation_0-auc:0.66504
# [760]	validation_0-auc:0.66491
# [770]	validation_0-auc:0.66478
# [780]	validation_0-auc:0.66447
# [790]	validation_0-auc:0.66423
# [800]	validation_0-auc:0.66404
# [810]	validation_0-auc:0.66370
# [820]	validation_0-auc:0.66341
# [830]	validation_0-auc:0.66334
# [840]	validation_0-auc:0.66330
# [850]	validation_0-auc:0.66305
# [860]	validation_0-auc:0.66278
# [870]	validation_0-auc:0.66254
# [880]	validation_0-auc:0.66221
# [890]	validation_0-auc:0.66183
# [900]	validation_0-auc:0.66174
# [910]	validation_0-auc:0.66140
# [920]	validation_0-auc:0.66117
# [930]	validation_0-auc:0.66096
# [940]	validation_0-auc:0.66066
# [950]	validation_0-auc:0.66032
# [960]	validation_0-auc:0.66022
# [970]	validation_0-auc:0.66007
# [980]	validation_0-auc:0.65975
# [990]	validation_0-auc:0.65953
# [1000]	validation_0-auc:0.65924
# [1010]	validation_0-auc:0.65897
# [1020]	validation_0-auc:0.65888
# [1030]	validation_0-auc:0.65873
# [1040]	validation_0-auc:0.65854
# [1050]	validation_0-auc:0.65813
# [1060]	validation_0-auc:0.65791
# [1070]	validation_0-auc:0.65771
# [1080]	validation_0-auc:0.65761
# [1090]	validation_0-auc:0.65750
# [1100]	validation_0-auc:0.65729
# [1110]	validation_0-auc:0.65700
# [1120]	validation_0-auc:0.65681
# [1130]	validation_0-auc:0.65653
# [1140]	validation_0-auc:0.65619
# [1150]	validation_0-auc:0.65598
# [1160]	validation_0-auc:0.65568
# [1170]	validation_0-auc:0.65540
# [1180]	validation_0-auc:0.65511
# [1190]	validation_0-auc:0.65474
# [1200]	validation_0-auc:0.65437
# [1210]	validation_0-auc:0.65424
# [1220]	validation_0-auc:0.65396
# [1230]	validation_0-auc:0.65368
# [1240]	validation_0-auc:0.65330
# [1250]	validation_0-auc:0.65291
# [1260]	validation_0-auc:0.65263
# [1270]	validation_0-auc:0.65239
# [1280]	validation_0-auc:0.65210
# [1290]	validation_0-auc:0.65190
# [1300]	validation_0-auc:0.65149
# [1310]	validation_0-auc:0.65130
# [1320]	validation_0-auc:0.65096
# [1330]	validation_0-auc:0.65070
# [1340]	validation_0-auc:0.65040
# [1350]	validation_0-auc:0.65012
# [1360]	validation_0-auc:0.64990
# [1370]	validation_0-auc:0.64955
# [1380]	validation_0-auc:0.64936
# [1390]	validation_0-auc:0.64919
# [1400]	validation_0-auc:0.64886
# [1410]	validation_0-auc:0.64853
# [1420]	validation_0-auc:0.64828
# [1430]	validation_0-auc:0.64797
# [1440]	validation_0-auc:0.64775
# [1450]	validation_0-auc:0.64751
# [1460]	validation_0-auc:0.64726
# [1470]	validation_0-auc:0.64709
# [1480]	validation_0-auc:0.64690
# [1490]	validation_0-auc:0.64657
# [1500]	validation_0-auc:0.64636
# [1510]	validation_0-auc:0.64608
# [1520]	validation_0-auc:0.64591
# [1530]	validation_0-auc:0.64587
# [1540]	validation_0-auc:0.64561
# [1550]	validation_0-auc:0.64536
# [1560]	validation_0-auc:0.64517
# [1570]	validation_0-auc:0.64497
# [1580]	validation_0-auc:0.64471
# [1590]	validation_0-auc:0.64458
# [1600]	validation_0-auc:0.64429
# [1610]	validation_0-auc:0.64402
# [1620]	validation_0-auc:0.64365
# [1630]	validation_0-auc:0.64340
# [1640]	validation_0-auc:0.64308
# [1650]	validation_0-auc:0.64287
# [1660]	validation_0-auc:0.64275
# [1670]	validation_0-auc:0.64259
# [1680]	validation_0-auc:0.64225
# [1690]	validation_0-auc:0.64191
# [1700]	validation_0-auc:0.64179
# [1710]	validation_0-auc:0.64156
# [1720]	validation_0-auc:0.64132
# [1730]	validation_0-auc:0.64115
# [1740]	validation_0-auc:0.64106
# [1750]	validation_0-auc:0.64091
# [1760]	validation_0-auc:0.64072
# [1770]	validation_0-auc:0.64044
# [1780]	validation_0-auc:0.64014
# [1790]	validation_0-auc:0.63998
# [1800]	validation_0-auc:0.63978
# [1810]	validation_0-auc:0.63955
# [1820]	validation_0-auc:0.63915
# [1830]	validation_0-auc:0.63898
# [1840]	validation_0-auc:0.63871
# [1850]	validation_0-auc:0.63844
# [1860]	validation_0-auc:0.63823
# [1870]	validation_0-auc:0.63797
# [1880]	validation_0-auc:0.63771
# [1890]	validation_0-auc:0.63748
# [1900]	validation_0-auc:0.63729
# [1910]	validation_0-auc:0.63710
# [1920]	validation_0-auc:0.63681
# [1930]	validation_0-auc:0.63667
# [1940]	validation_0-auc:0.63626
# [1950]	validation_0-auc:0.63620
# [1960]	validation_0-auc:0.63602
# [1970]	validation_0-auc:0.63581
# [1980]	validation_0-auc:0.63555
# [1990]	validation_0-auc:0.63536
# [2000]	validation_0-auc:0.63521
# [2010]	validation_0-auc:0.63498
# [2020]	validation_0-auc:0.63481
# [2030]	validation_0-auc:0.63467
# [2040]	validation_0-auc:0.63453
# [2050]	validation_0-auc:0.63441
# [2060]	validation_0-auc:0.63414
# [2070]	validation_0-auc:0.63395
# [2080]	validation_0-auc:0.63367
# [2090]	validation_0-auc:0.63349
# [2100]	validation_0-auc:0.63315
# [2110]	validation_0-auc:0.63292
# [2120]	validation_0-auc:0.63273
# [2130]	validation_0-auc:0.63249
# [2140]	validation_0-auc:0.63240
# [2150]	validation_0-auc:0.63219
# [2160]	validation_0-auc:0.63201
# [2170]	validation_0-auc:0.63170
# [2180]	validation_0-auc:0.63139
# [2190]	validation_0-auc:0.63115
# [2200]	validation_0-auc:0.63099
# [2210]	validation_0-auc:0.63081
# [2220]	validation_0-auc:0.63066
# [2230]	validation_0-auc:0.63038
# [2240]	validation_0-auc:0.63016
# [2250]	validation_0-auc:0.63003
# [2260]	validation_0-auc:0.62983
# [2270]	validation_0-auc:0.62959
# [2280]	validation_0-auc:0.62941
# [2290]	validation_0-auc:0.62924
# [2300]	validation_0-auc:0.62898
# [2310]	validation_0-auc:0.62885
# [2320]	validation_0-auc:0.62867
# [2330]	validation_0-auc:0.62846
# [2340]	validation_0-auc:0.62830
# [2350]	validation_0-auc:0.62817
# [2360]	validation_0-auc:0.62800
# [2370]	validation_0-auc:0.62786
# [2380]	validation_0-auc:0.62758
# [2390]	validation_0-auc:0.62752
# [2400]	validation_0-auc:0.62738
# [2410]	validation_0-auc:0.62725
# [2420]	validation_0-auc:0.62716
# [2430]	validation_0-auc:0.62702
# [2440]	validation_0-auc:0.62681
# [2450]	validation_0-auc:0.62651
# [2460]	validation_0-auc:0.62630
# [2470]	validation_0-auc:0.62618
# [2480]	validation_0-auc:0.62593
# [2490]	validation_0-auc:0.62577
# [2500]	validation_0-auc:0.62563
# [2510]	validation_0-auc:0.62553
# [2520]	validation_0-auc:0.62531
# [2530]	validation_0-auc:0.62510
# [2540]	validation_0-auc:0.62492
# [2550]	validation_0-auc:0.62468
# [2560]	validation_0-auc:0.62446
# [2570]	validation_0-auc:0.62433
# [2580]	validation_0-auc:0.62413
# [2590]	validation_0-auc:0.62398
# [2600]	validation_0-auc:0.62380
# [2610]	validation_0-auc:0.62366
# [2620]	validation_0-auc:0.62359
# [2630]	validation_0-auc:0.62331
# [2640]	validation_0-auc:0.62320
# [2650]	validation_0-auc:0.62303
# [2660]	validation_0-auc:0.62287
# [2670]	validation_0-auc:0.62279
# [2680]	validation_0-auc:0.62272
# [2690]	validation_0-auc:0.62254
# [2700]	validation_0-auc:0.62231
# [2710]	validation_0-auc:0.62217
# [2720]	validation_0-auc:0.62202
# [2730]	validation_0-auc:0.62189
# [2740]	validation_0-auc:0.62180
# [2750]	validation_0-auc:0.62157
# [2760]	validation_0-auc:0.62142
# [2770]	validation_0-auc:0.62127
# [2780]	validation_0-auc:0.62109
# [2790]	validation_0-auc:0.62095
# [2800]	validation_0-auc:0.62071
# [2810]	validation_0-auc:0.62064
# [2820]	validation_0-auc:0.62047
# [2830]	validation_0-auc:0.62031
# [2840]	validation_0-auc:0.62016
# [2850]	validation_0-auc:0.62009
# [2860]	validation_0-auc:0.61993
# [2870]	validation_0-auc:0.61981
# [2880]	validation_0-auc:0.61961
# [2890]	validation_0-auc:0.61952
# [2900]	validation_0-auc:0.61949
# [2910]	validation_0-auc:0.61941
# [2920]	validation_0-auc:0.61922
# [2930]	validation_0-auc:0.61904
# [2940]	validation_0-auc:0.61896
# [2950]	validation_0-auc:0.61875
# [2960]	validation_0-auc:0.61864
# [2970]	validation_0-auc:0.61845
# [2980]	validation_0-auc:0.61831
# [2990]	validation_0-auc:0.61817
# [3000]	validation_0-auc:0.61803
# [3010]	validation_0-auc:0.61775
# [3020]	validation_0-auc:0.61761
# [3030]	validation_0-auc:0.61746
# [3040]	validation_0-auc:0.61743
# [3050]	validation_0-auc:0.61740
# [3060]	validation_0-auc:0.61723
# [3070]	validation_0-auc:0.61722
# [3080]	validation_0-auc:0.61706
# [3090]	validation_0-auc:0.61686
# [3100]	validation_0-auc:0.61677
# [3110]	validation_0-auc:0.61672
# [3120]	validation_0-auc:0.61667
# [3130]	validation_0-auc:0.61653
# [3140]	validation_0-auc:0.61623
# [3150]	validation_0-auc:0.61604
# [3160]	validation_0-auc:0.61596
# [3170]	validation_0-auc:0.61591
# [3180]	validation_0-auc:0.61587
# [3190]	validation_0-auc:0.61571
# [3200]	validation_0-auc:0.61565
# [3210]	validation_0-auc:0.61563
# [3220]	validation_0-auc:0.61557
# [3230]	validation_0-auc:0.61551
# [3240]	validation_0-auc:0.61536
# [3250]	validation_0-auc:0.61524
# [3260]	validation_0-auc:0.61519
# [3270]	validation_0-auc:0.61505
# [3280]	validation_0-auc:0.61497
# [3290]	validation_0-auc:0.61487
# [3300]	validation_0-auc:0.61479
# [3310]	validation_0-auc:0.61466
# [3320]	validation_0-auc:0.61464
# [3330]	validation_0-auc:0.61459
# [3340]	validation_0-auc:0.61450
# [3350]	validation_0-auc:0.61451
# [3360]	validation_0-auc:0.61442
# [3370]	validation_0-auc:0.61429
# [3380]	validation_0-auc:0.61418
# [3390]	validation_0-auc:0.61407
# [3400]	validation_0-auc:0.61393
# [3410]	validation_0-auc:0.61375
# [3420]	validation_0-auc:0.61356
# [3430]	validation_0-auc:0.61354
# [3440]	validation_0-auc:0.61342
# [3450]	validation_0-auc:0.61327
# [3460]	validation_0-auc:0.61315
# [3470]	validation_0-auc:0.61299
# [3480]	validation_0-auc:0.61289
# [3490]	validation_0-auc:0.61281
# [3500]	validation_0-auc:0.61255
# [3510]	validation_0-auc:0.61246
# [3520]	validation_0-auc:0.61231
# [3530]	validation_0-auc:0.61221
# [3540]	validation_0-auc:0.61202
# [3550]	validation_0-auc:0.61190
# [3560]	validation_0-auc:0.61179
# [3570]	validation_0-auc:0.61181
# [3580]	validation_0-auc:0.61178
# [3590]	validation_0-auc:0.61163
# [3600]	validation_0-auc:0.61154
# [3610]	validation_0-auc:0.61134
# [3620]	validation_0-auc:0.61128
# [3630]	validation_0-auc:0.61109
# [3640]	validation_0-auc:0.61100
# [3650]	validation_0-auc:0.61088
# [3660]	validation_0-auc:0.61076
# [3670]	validation_0-auc:0.61060
# [3680]	validation_0-auc:0.61056
# [3690]	validation_0-auc:0.61049
# [3700]	validation_0-auc:0.61036
# [3710]	validation_0-auc:0.61031
# [3720]	validation_0-auc:0.61026
# [3730]	validation_0-auc:0.61010
# [3740]	validation_0-auc:0.60995
# [3750]	validation_0-auc:0.60980
# [3760]	validation_0-auc:0.60969
# [3770]	validation_0-auc:0.60958
# [3780]	validation_0-auc:0.60964
# [3790]	validation_0-auc:0.60952
# [3800]	validation_0-auc:0.60944
# [3810]	validation_0-auc:0.60925
# [3820]	validation_0-auc:0.60907
# [3830]	validation_0-auc:0.60901
# [3840]	validation_0-auc:0.60888
# [3850]	validation_0-auc:0.60879
# [3860]	validation_0-auc:0.60864
# [3870]	validation_0-auc:0.60842
# [3880]	validation_0-auc:0.60834
# [3890]	validation_0-auc:0.60829
# [3900]	validation_0-auc:0.60823
# [3910]	validation_0-auc:0.60809
# [3920]	validation_0-auc:0.60800
# [3930]	validation_0-auc:0.60788
# [3940]	validation_0-auc:0.60777
# [3950]	validation_0-auc:0.60771
# [3960]	validation_0-auc:0.60759
# [3970]	validation_0-auc:0.60745
# [3980]	validation_0-auc:0.60727
# [3990]	validation_0-auc:0.60710
# [4000]	validation_0-auc:0.60703
# [4010]	validation_0-auc:0.60692
# [4020]	validation_0-auc:0.60678
# [4030]	validation_0-auc:0.60669
# [4040]	validation_0-auc:0.60652
# [4050]	validation_0-auc:0.60649
# [4060]	validation_0-auc:0.60641
# [4070]	validation_0-auc:0.60630
# [4080]	validation_0-auc:0.60625
# [4090]	validation_0-auc:0.60613
# [4100]	validation_0-auc:0.60610
# [4110]	validation_0-auc:0.60598
# [4120]	validation_0-auc:0.60588
# [4130]	validation_0-auc:0.60583
# [4140]	validation_0-auc:0.60586
# [4150]	validation_0-auc:0.60578
# [4160]	validation_0-auc:0.60575
# [4170]	validation_0-auc:0.60561
# [4180]	validation_0-auc:0.60555
# [4190]	validation_0-auc:0.60547
# [4200]	validation_0-auc:0.60539
# [4210]	validation_0-auc:0.60523
# [4220]	validation_0-auc:0.60515
# [4230]	validation_0-auc:0.60513
# [4240]	validation_0-auc:0.60500
# [4250]	validation_0-auc:0.60494
# [4260]	validation_0-auc:0.60489
# [4270]	validation_0-auc:0.60479
# [4280]	validation_0-auc:0.60480
# [4290]	validation_0-auc:0.60473
# [4300]	validation_0-auc:0.60463
# [4310]	validation_0-auc:0.60452
# [4320]	validation_0-auc:0.60452
# [4330]	validation_0-auc:0.60442
# [4340]	validation_0-auc:0.60437
# [4350]	validation_0-auc:0.60435
# [4360]	validation_0-auc:0.60430
# [4370]	validation_0-auc:0.60418
# [4380]	validation_0-auc:0.60419
# [4390]	validation_0-auc:0.60412
# [4400]	validation_0-auc:0.60403
# [4410]	validation_0-auc:0.60400
# [4420]	validation_0-auc:0.60394
# [4430]	validation_0-auc:0.60390
# [4440]	validation_0-auc:0.60385
# [4450]	validation_0-auc:0.60380
# [4460]	validation_0-auc:0.60375
# [4470]	validation_0-auc:0.60373
# [4480]	validation_0-auc:0.60370
# [4490]	validation_0-auc:0.60351
# [4500]	validation_0-auc:0.60341
# [4510]	validation_0-auc:0.60326
# [4520]	validation_0-auc:0.60318
# [4530]	validation_0-auc:0.60307
# [4540]	validation_0-auc:0.60292
# [4550]	validation_0-auc:0.60283
# [4560]	validation_0-auc:0.60271
# [4570]	validation_0-auc:0.60257
# [4580]	validation_0-auc:0.60251
# ...
# [290]	validation_0-auc:0.66814
# [300]	validation_0-auc:0.66790
# [310]	validation_0-auc:0.66767
# [320]	validation_0-auc:0.66757
# [330]	validation_0-auc:0.66735
# [340]	validation_0-auc:0.66691
# [350]	validation_0-auc:0.66684
# [360]	validation_0-auc:0.66674
# [370]	validation_0-auc:0.66639
# [380]	validation_0-auc:0.66600
# [390]	validation_0-auc:0.66569
# [400]	validation_0-auc:0.66551
# [410]	validation_0-auc:0.66537
# [420]	validation_0-auc:0.66521
# [430]	validation_0-auc:0.66531
# [440]	validation_0-auc:0.66516
# [450]	validation_0-auc:0.66470
# [460]	validation_0-auc:0.66418
# [470]	validation_0-auc:0.66410
# [480]	validation_0-auc:0.66369
# [490]	validation_0-auc:0.66352
# [500]	validation_0-auc:0.66337
# [510]	validation_0-auc:0.66326
# [520]	validation_0-auc:0.66297
# [530]	validation_0-auc:0.66251
# [540]	validation_0-auc:0.66208
# [550]	validation_0-auc:0.66175
# [560]	validation_0-auc:0.66137
# [570]	validation_0-auc:0.66112
# [580]	validation_0-auc:0.66100
# [590]	validation_0-auc:0.66070
# [600]	validation_0-auc:0.66038
# [610]	validation_0-auc:0.66016
# [620]	validation_0-auc:0.65977
# [630]	validation_0-auc:0.65951
# [640]	validation_0-auc:0.65883
# [650]	validation_0-auc:0.65853
# [660]	validation_0-auc:0.65819
# [670]	validation_0-auc:0.65786
# [680]	validation_0-auc:0.65741
# [690]	validation_0-auc:0.65710
# [700]	validation_0-auc:0.65671
# [710]	validation_0-auc:0.65647
# [720]	validation_0-auc:0.65614
# [730]	validation_0-auc:0.65589
# [740]	validation_0-auc:0.65559
# [750]	validation_0-auc:0.65516
# [760]	validation_0-auc:0.65489
# [770]	validation_0-auc:0.65449
# [780]	validation_0-auc:0.65411
# [790]	validation_0-auc:0.65373
# [800]	validation_0-auc:0.65336
# [810]	validation_0-auc:0.65309
# [820]	validation_0-auc:0.65267
# [830]	validation_0-auc:0.65239
# [840]	validation_0-auc:0.65201
# [850]	validation_0-auc:0.65173
# [860]	validation_0-auc:0.65152
# [870]	validation_0-auc:0.65122
# [880]	validation_0-auc:0.65088
# [890]	validation_0-auc:0.65071
# [900]	validation_0-auc:0.65032
# [910]	validation_0-auc:0.65014
# [920]	validation_0-auc:0.64974
# [930]	validation_0-auc:0.64954
# [940]	validation_0-auc:0.64933
# [950]	validation_0-auc:0.64913
# [960]	validation_0-auc:0.64894
# [970]	validation_0-auc:0.64852
# [980]	validation_0-auc:0.64827
# [990]	validation_0-auc:0.64797
# [1000]	validation_0-auc:0.64770
# [1010]	validation_0-auc:0.64759
# [1020]	validation_0-auc:0.64729
# [1030]	validation_0-auc:0.64690
# [1040]	validation_0-auc:0.64648
# [1050]	validation_0-auc:0.64609
# [1060]	validation_0-auc:0.64570
# [1070]	validation_0-auc:0.64543
# [1080]	validation_0-auc:0.64508
# [1090]	validation_0-auc:0.64481
# [1100]	validation_0-auc:0.64458
# [1110]	validation_0-auc:0.64444
# [1120]	validation_0-auc:0.64430
# [1130]	validation_0-auc:0.64402
# [1140]	validation_0-auc:0.64378
# [1150]	validation_0-auc:0.64362
# [1160]	validation_0-auc:0.64338
# [1170]	validation_0-auc:0.64325
# [1180]	validation_0-auc:0.64306
# [1190]	validation_0-auc:0.64277
# [1200]	validation_0-auc:0.64242
# [1210]	validation_0-auc:0.64202
# [1220]	validation_0-auc:0.64181
# [1230]	validation_0-auc:0.64143
# [1240]	validation_0-auc:0.64135
# [1250]	validation_0-auc:0.64107
# [1260]	validation_0-auc:0.64088
# [1270]	validation_0-auc:0.64055
# [1280]	validation_0-auc:0.64035
# [1290]	validation_0-auc:0.64010
# [1300]	validation_0-auc:0.63968
# [1310]	validation_0-auc:0.63928
# [1320]	validation_0-auc:0.63909
# [1330]	validation_0-auc:0.63884
# [1340]	validation_0-auc:0.63859
# [1350]	validation_0-auc:0.63842
# [1360]	validation_0-auc:0.63827
# [1370]	validation_0-auc:0.63801
# [1380]	validation_0-auc:0.63764
# [1390]	validation_0-auc:0.63724
# [1400]	validation_0-auc:0.63712
# [1410]	validation_0-auc:0.63688
# [1420]	validation_0-auc:0.63667
# [1430]	validation_0-auc:0.63644
# [1440]	validation_0-auc:0.63629
# [1450]	validation_0-auc:0.63615
# [1460]	validation_0-auc:0.63576
# [1470]	validation_0-auc:0.63551
# [1480]	validation_0-auc:0.63533
# [1490]	validation_0-auc:0.63510
# [1500]	validation_0-auc:0.63496
# [1510]	validation_0-auc:0.63471
# [1520]	validation_0-auc:0.63454
# [1530]	validation_0-auc:0.63428
# [1540]	validation_0-auc:0.63398
# [1550]	validation_0-auc:0.63386
# [1560]	validation_0-auc:0.63368
# [1570]	validation_0-auc:0.63357
# [1580]	validation_0-auc:0.63326
# [1590]	validation_0-auc:0.63306
# [1600]	validation_0-auc:0.63276
# [1610]	validation_0-auc:0.63256
# [1620]	validation_0-auc:0.63221
# [1630]	validation_0-auc:0.63196
# [1640]	validation_0-auc:0.63174
# [1650]	validation_0-auc:0.63158
# [1660]	validation_0-auc:0.63136
# [1670]	validation_0-auc:0.63106
# [1680]	validation_0-auc:0.63064
# [1690]	validation_0-auc:0.63047
# [1700]	validation_0-auc:0.63019
# [1710]	validation_0-auc:0.63004
# [1720]	validation_0-auc:0.62984
# [1730]	validation_0-auc:0.62962
# [1740]	validation_0-auc:0.62939
# [1750]	validation_0-auc:0.62913
# [1760]	validation_0-auc:0.62876
# [1770]	validation_0-auc:0.62852
# [1780]	validation_0-auc:0.62825
# [1790]	validation_0-auc:0.62808
# [1800]	validation_0-auc:0.62781
# [1810]	validation_0-auc:0.62755
# [1820]	validation_0-auc:0.62727
# [1830]	validation_0-auc:0.62711
# [1840]	validation_0-auc:0.62705
# [1850]	validation_0-auc:0.62681
# [1860]	validation_0-auc:0.62664
# [1870]	validation_0-auc:0.62639
# [1880]	validation_0-auc:0.62619
# [1890]	validation_0-auc:0.62589
# [1900]	validation_0-auc:0.62561
# [1910]	validation_0-auc:0.62543
# [1920]	validation_0-auc:0.62519
# [1930]	validation_0-auc:0.62494
# [1940]	validation_0-auc:0.62474
# [1950]	validation_0-auc:0.62454
# [1960]	validation_0-auc:0.62431
# [1970]	validation_0-auc:0.62416
# [1980]	validation_0-auc:0.62384
# [1990]	validation_0-auc:0.62372
# [2000]	validation_0-auc:0.62358
# [2010]	validation_0-auc:0.62336
# [2020]	validation_0-auc:0.62311
# [2030]	validation_0-auc:0.62284
# [2040]	validation_0-auc:0.62275
# [2050]	validation_0-auc:0.62251
# [2060]	validation_0-auc:0.62235
# [2070]	validation_0-auc:0.62213
# [2080]	validation_0-auc:0.62202
# [2090]	validation_0-auc:0.62187
# [2100]	validation_0-auc:0.62156
# [2110]	validation_0-auc:0.62128
# [2120]	validation_0-auc:0.62101
# [2130]	validation_0-auc:0.62076
# [2140]	validation_0-auc:0.62064
# [2150]	validation_0-auc:0.62052
# [2160]	validation_0-auc:0.62032
# [2170]	validation_0-auc:0.62023
# [2180]	validation_0-auc:0.62012
# [2190]	validation_0-auc:0.61995
# [2200]	validation_0-auc:0.61969
# [2210]	validation_0-auc:0.61958
# [2220]	validation_0-auc:0.61938
# [2230]	validation_0-auc:0.61924
# [2240]	validation_0-auc:0.61908
# [2250]	validation_0-auc:0.61887
# [2260]	validation_0-auc:0.61883
# [2270]	validation_0-auc:0.61866
# [2280]	validation_0-auc:0.61851
# [2290]	validation_0-auc:0.61832
# [2300]	validation_0-auc:0.61816
# [2310]	validation_0-auc:0.61797
# [2320]	validation_0-auc:0.61783
# [2330]	validation_0-auc:0.61765
# [2340]	validation_0-auc:0.61736
# [2350]	validation_0-auc:0.61718
# [2360]	validation_0-auc:0.61701
# [2370]	validation_0-auc:0.61686
# [2380]	validation_0-auc:0.61679
# [2390]	validation_0-auc:0.61671
# [2400]	validation_0-auc:0.61648
# [2410]	validation_0-auc:0.61625
# [2420]	validation_0-auc:0.61608
# [2430]	validation_0-auc:0.61591
# [2440]	validation_0-auc:0.61575
# [2450]	validation_0-auc:0.61568
# [2460]	validation_0-auc:0.61556
# [2470]	validation_0-auc:0.61532
# [2480]	validation_0-auc:0.61509
# [2490]	validation_0-auc:0.61497
# [2500]	validation_0-auc:0.61488
# [2510]	validation_0-auc:0.61466
# [2520]	validation_0-auc:0.61451
# [2530]	validation_0-auc:0.61441
# [2540]	validation_0-auc:0.61429
# [2550]	validation_0-auc:0.61419
# [2560]	validation_0-auc:0.61404
# [2570]	validation_0-auc:0.61396
# [2580]	validation_0-auc:0.61380
# [2590]	validation_0-auc:0.61368
# [2600]	validation_0-auc:0.61363
# [2610]	validation_0-auc:0.61340
# [2620]	validation_0-auc:0.61337
# [2630]	validation_0-auc:0.61318
# [2640]	validation_0-auc:0.61308
# [2650]	validation_0-auc:0.61293
# [2660]	validation_0-auc:0.61268
# [2670]	validation_0-auc:0.61253
# [2680]	validation_0-auc:0.61247
# [2690]	validation_0-auc:0.61232
# [2700]	validation_0-auc:0.61221
# [2710]	validation_0-auc:0.61201
# [2720]	validation_0-auc:0.61197
# [2730]	validation_0-auc:0.61182
# [2740]	validation_0-auc:0.61166
# [2750]	validation_0-auc:0.61149
# [2760]	validation_0-auc:0.61134
# [2770]	validation_0-auc:0.61124
# [2780]	validation_0-auc:0.61107
# [2790]	validation_0-auc:0.61084
# [2800]	validation_0-auc:0.61062
# [2810]	validation_0-auc:0.61044
# [2820]	validation_0-auc:0.61019
# [2830]	validation_0-auc:0.61008
# [2840]	validation_0-auc:0.60990
# [2850]	validation_0-auc:0.60965
# [2860]	validation_0-auc:0.60952
# [2870]	validation_0-auc:0.60935
# [2880]	validation_0-auc:0.60919
# [2890]	validation_0-auc:0.60905
# [2900]	validation_0-auc:0.60893
# [2910]	validation_0-auc:0.60875
# [2920]	validation_0-auc:0.60865
# [2930]	validation_0-auc:0.60847
# [2940]	validation_0-auc:0.60837
# [2950]	validation_0-auc:0.60821
# [2960]	validation_0-auc:0.60803
# [2970]	validation_0-auc:0.60785
# [2980]	validation_0-auc:0.60781
# [2990]	validation_0-auc:0.60767
# [3000]	validation_0-auc:0.60758
# [3010]	validation_0-auc:0.60739
# [3020]	validation_0-auc:0.60730
# [3030]	validation_0-auc:0.60713
# [3040]	validation_0-auc:0.60703
# [3050]	validation_0-auc:0.60700
# [3060]	validation_0-auc:0.60682
# [3070]	validation_0-auc:0.60676
# [3080]	validation_0-auc:0.60660
# [3090]	validation_0-auc:0.60658
# [3100]	validation_0-auc:0.60653
# [3110]	validation_0-auc:0.60620
# [3120]	validation_0-auc:0.60604
# [3130]	validation_0-auc:0.60581
# [3140]	validation_0-auc:0.60577
# [3150]	validation_0-auc:0.60564
# [3160]	validation_0-auc:0.60553
# [3170]	validation_0-auc:0.60540
# [3180]	validation_0-auc:0.60533
# [3190]	validation_0-auc:0.60524
# [3200]	validation_0-auc:0.60514
# [3210]	validation_0-auc:0.60507
# [3220]	validation_0-auc:0.60493
# [3230]	validation_0-auc:0.60485
# [3240]	validation_0-auc:0.60465
# [3250]	validation_0-auc:0.60453
# [3260]	validation_0-auc:0.60458
# [3270]	validation_0-auc:0.60447
# [3280]	validation_0-auc:0.60437
# [3290]	validation_0-auc:0.60438
# [3300]	validation_0-auc:0.60432
# [3310]	validation_0-auc:0.60422
# [3320]	validation_0-auc:0.60407
# [3330]	validation_0-auc:0.60394
# [3340]	validation_0-auc:0.60384
# [3350]	validation_0-auc:0.60371
# [3360]	validation_0-auc:0.60364
# [3370]	validation_0-auc:0.60349
# [3380]	validation_0-auc:0.60345
# [3390]	validation_0-auc:0.60334
# [3400]	validation_0-auc:0.60323
# [3410]	validation_0-auc:0.60311
# [3420]	validation_0-auc:0.60306
# [3430]	validation_0-auc:0.60284
# [3440]	validation_0-auc:0.60278
# [3450]	validation_0-auc:0.60267
# [3460]	validation_0-auc:0.60261
# [3470]	validation_0-auc:0.60247
# [3480]	validation_0-auc:0.60245
# [3490]	validation_0-auc:0.60237
# [3500]	validation_0-auc:0.60225
# [3510]	validation_0-auc:0.60224
# [3520]	validation_0-auc:0.60208
# [3530]	validation_0-auc:0.60201
# [3540]	validation_0-auc:0.60191
# [3550]	validation_0-auc:0.60187
# [3560]	validation_0-auc:0.60174
# [3570]	validation_0-auc:0.60167
# [3580]	validation_0-auc:0.60162
# [3590]	validation_0-auc:0.60142
# [3600]	validation_0-auc:0.60127
# [3610]	validation_0-auc:0.60123
# [3620]	validation_0-auc:0.60113
# [3630]	validation_0-auc:0.60102
# [3640]	validation_0-auc:0.60097
# [3650]	validation_0-auc:0.60091
# [3660]	validation_0-auc:0.60087
# [3670]	validation_0-auc:0.60078
# [3680]	validation_0-auc:0.60066
# [3690]	validation_0-auc:0.60056
# [3700]	validation_0-auc:0.60048
# [3710]	validation_0-auc:0.60043
# [3720]	validation_0-auc:0.60032
# [3730]	validation_0-auc:0.60024
# [3740]	validation_0-auc:0.60020
# [3750]	validation_0-auc:0.60024
# [3760]	validation_0-auc:0.60012
# [3770]	validation_0-auc:0.60002
# [3780]	validation_0-auc:0.59993
# [3790]	validation_0-auc:0.59986
# [3800]	validation_0-auc:0.59977
# [3810]	validation_0-auc:0.59965
# [3820]	validation_0-auc:0.59956
# [3830]	validation_0-auc:0.59943
# [3840]	validation_0-auc:0.59938
# [3850]	validation_0-auc:0.59930
# [3860]	validation_0-auc:0.59920
# [3870]	validation_0-auc:0.59912
# [3880]	validation_0-auc:0.59901
# [3890]	validation_0-auc:0.59901
# [3900]	validation_0-auc:0.59890
# [3910]	validation_0-auc:0.59888
# [3920]	validation_0-auc:0.59883
# [3930]	validation_0-auc:0.59872
# [3940]	validation_0-auc:0.59859
# [3950]	validation_0-auc:0.59850
# [3960]	validation_0-auc:0.59846
# [3970]	validation_0-auc:0.59844
# [3980]	validation_0-auc:0.59836
# [3990]	validation_0-auc:0.59834
# [4000]	validation_0-auc:0.59819
# [4010]	validation_0-auc:0.59810
# [4020]	validation_0-auc:0.59804
# [4030]	validation_0-auc:0.59795
# [4040]	validation_0-auc:0.59784
# [4050]	validation_0-auc:0.59767
# [4060]	validation_0-auc:0.59761
# [4070]	validation_0-auc:0.59750
# [4080]	validation_0-auc:0.59733
# [4090]	validation_0-auc:0.59734
# [4100]	validation_0-auc:0.59729
# [4110]	validation_0-auc:0.59723
# [4120]	validation_0-auc:0.59719
# [4130]	validation_0-auc:0.59714
# [4140]	validation_0-auc:0.59704
# [4150]	validation_0-auc:0.59700
# [4160]	validation_0-auc:0.59688
# [4170]	validation_0-auc:0.59686
# [4180]	validation_0-auc:0.59680
# [4190]	validation_0-auc:0.59673
# [4200]	validation_0-auc:0.59661
# [4210]	validation_0-auc:0.59651
# [4220]	validation_0-auc:0.59650
# [4230]	validation_0-auc:0.59649
# [4240]	validation_0-auc:0.59640
# [4250]	validation_0-auc:0.59632
# [4260]	validation_0-auc:0.59615
# [4270]	validation_0-auc:0.59615
# [4280]	validation_0-auc:0.59605
# [4290]	validation_0-auc:0.59597
# [4300]	validation_0-auc:0.59594
# [4310]	validation_0-auc:0.59579
# [4320]	validation_0-auc:0.59569
# [4330]	validation_0-auc:0.59562
# [4340]	validation_0-auc:0.59561
# [4350]	validation_0-auc:0.59556
# [4360]	validation_0-auc:0.59554
# [4370]	validation_0-auc:0.59550
# [4380]	validation_0-auc:0.59541
# [4390]	validation_0-auc:0.59531
# [4400]	validation_0-auc:0.59520
# [4410]	validation_0-auc:0.59512
# [4420]	validation_0-auc:0.59509
# [4430]	validation_0-auc:0.59508
# [4440]	validation_0-auc:0.59499
# [4450]	validation_0-auc:0.59503
# [4460]	validation_0-auc:0.59491
# [4470]	validation_0-auc:0.59481
# [4480]	validation_0-auc:0.59476
# [4490]	validation_0-auc:0.59472
# [4500]	validation_0-auc:0.59470
# [4510]	validation_0-auc:0.59469
# [4520]	validation_0-auc:0.59466
# [4530]	validation_0-auc:0.59464
# [4540]	validation_0-auc:0.59457
# [4550]	validation_0-auc:0.59454
# [4560]	validation_0-auc:0.59448
# [4570]	validation_0-auc:0.59441
# [4580]	validation_0-auc:0.59438
# [4590]	validation_0-auc:0.59425
# [4600]	validation_0-auc:0.59419
# [4610]	validation_0-auc:0.59417
# [4620]	validation_0-auc:0.59413
# [4630]	validation_0-auc:0.59400
# [4640]	validation_0-auc:0.59396
# [4650]	validation_0-auc:0.59388
# [4660]	validation_0-auc:0.59390
# [4670]	validation_0-auc:0.59387
# [4680]	validation_0-auc:0.59384
# [4690]	validation_0-auc:0.59385
# [4700]	validation_0-auc:0.59380
# [4710]	validation_0-auc:0.59379
# [4720]	validation_0-auc:0.59370
# [4730]	validation_0-auc:0.59361
# [4740]	validation_0-auc:0.59364
# [4750]	validation_0-auc:0.59360
# [4760]	validation_0-auc:0.59349
# [4770]	validation_0-auc:0.59343
# [4780]	validation_0-auc:0.59334
# [4790]	validation_0-auc:0.59330
# [4800]	validation_0-auc:0.59321
# [4810]	validation_0-auc:0.59314
# [4820]	validation_0-auc:0.59307
# [4830]	validation_0-auc:0.59301
# [4840]	validation_0-auc:0.59282
# [4850]	validation_0-auc:0.59274
# [4860]	validation_0-auc:0.59270
# [4870]	validation_0-auc:0.59259
# [4880]	validation_0-auc:0.59257
# [4890]	validation_0-auc:0.59254
# [4900]	validation_0-auc:0.59249
# [4910]	validation_0-auc:0.59249
# [4920]	validation_0-auc:0.59244
# [4930]	validation_0-auc:0.59245
# [4940]	validation_0-auc:0.59243
# [4950]	validation_0-auc:0.59236
# [4960]	validation_0-auc:0.59227
# [4970]	validation_0-auc:0.59225
# [4980]	validation_0-auc:0.59215
# [4990]	validation_0-auc:0.59206
# [5000]	validation_0-auc:0.59191
# [5010]	validation_0-auc:0.59190
# [5020]	validation_0-auc:0.59187
# [5030]	validation_0-auc:0.59181
# [5040]	validation_0-auc:0.59177
# [5050]	validation_0-auc:0.59167
# [5060]	validation_0-auc:0.59168
# [5070]	validation_0-auc:0.59164
# [5080]	validation_0-auc:0.59162
# [5090]	validation_0-auc:0.59162
# [5100]	validation_0-auc:0.59162
# [5110]	validation_0-auc:0.59159
# [5120]	validation_0-auc:0.59152
# [5130]	validation_0-auc:0.59143
# [5140]	validation_0-auc:0.59139
# [5150]	validation_0-auc:0.59139
# [5160]	validation_0-auc:0.59134
# [5170]	validation_0-auc:0.59121
# [5180]	validation_0-auc:0.59120
# [5190]	validation_0-auc:0.59108
# [5199]	validation_0-auc:0.59099
# Training completed in 2777.12 seconds
# Fold 5 Accuracy: 0.9628
# Fold 5 AUC: 0.5910
#
# === Final Results ===
# Average Accuracy: 0.9629 ± 0.0007
# Average AUC: 0.5983 ± 0.0045
# Average Training Time: 2613.52 seconds
#
# Best model from Fold 4 with AUC: 0.6050
# Best model saved as best_xgboost_model_fold4_auc0.6050.joblib

# %%
external_indices = df[df['Region'].isin(['Scotland', 'Wales'])].index
# 获取苏格兰和威尔士参与者的数据
X_external = data_imputed_df.loc[external_indices]  # 特征
y_external = df.loc[external_indices, 'status']  # 标签
print("外部验证集形状:", X_external.shape)
X_external
# 预测类别（0/1）
y_pred = best_model.predict(X_external)
# 预测概率（用于 AUC 等指标）
y_pred_proba = best_model.predict_proba(X_external)[:, 1]  # 正类的概率
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# 计算准确率和 AUC
accuracy = accuracy_score(y_external, y_pred)
auc = roc_auc_score(y_external, y_pred_proba)

print(f"测试集准确率: {accuracy:.4f}")
print(f"测试集 AUC: {auc:.4f}")
# Out:
# 外部验证集形状: (50653, 62)
# 测试集准确率: 0.9637
# 测试集 AUC: 0.6084

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score
import time
import joblib
# 筛选来自英格兰的参与者
england_indices = df[df['Region'] == 'England'].index
X_england = data_imputed_df.loc[england_indices]
y_england = df.loc[england_indices, 'status']

# 定义5折交叉验证
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# 存储每折的评估结果
accuracy_scores = []
auc_scores = []
training_times = []
models = []
# 计算类别权重（需要在循环内计算，因为每折的分布可能不同）
# 注意：这里我们会在循环内计算，因为y_train在每折不同

# 固定参数（从你的网格中取第一个值）
params = {
    'alpha': 1.5,          # L1 正则化
    'lambda': 1.5,         # L2 正则化
    'colsample_bytree': 0.75,  # 特征采样比例
    'n_estimators': 400,
    'learning_rate': 0.01,
    'max_depth': 3,
    'subsample': 0.7,
    'min_child_weight': 3,
    'gamma': 0.9,
    'eval_metric':'auc'
}
# 开始交叉验证
for fold, (train_idx, val_idx) in enumerate(kf.split(X_england), 1):
    try:
        print(f"\n===== Fold {fold} =====\n")
        X_train, X_val = X_england.iloc[train_idx], X_england.iloc[val_idx]
        y_train, y_val = y_england.iloc[train_idx], y_england.iloc[val_idx]

        # 计算当前fold的类别权重
        scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)
        current_params = params.copy()
        current_params['scale_pos_weight'] = scale_pos_weight

        # 初始化模型
        model = XGBClassifier(**current_params)

        # 训练模型并计时
        start_time = time.time()
        print("Training started...")
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=10  # 每10轮显示一次进度
        )
        training_time = time.time() - start_time
        training_times.append(training_time)
        print(f"Training completed in {training_time:.2f} seconds")

        # 预测
        y_pred = model.predict(X_val)
        y_pred_proba = model.predict_proba(X_val)[:, 1]  # 获取正类的概率

        # 评估
        accuracy = accuracy_score(y_val, y_pred)
        auc = roc_auc_score(y_val, y_pred_proba)

        accuracy_scores.append(accuracy)
        auc_scores.append(auc)
        models.append(model)  # 保存当前fold的模型
        print(f"Fold {fold} Accuracy: {accuracy:.4f}")
        print(f"Fold {fold} AUC: {auc:.4f}")

    except KeyboardInterrupt:
        print("\nTraining interrupted by user")
        break
    except Exception as e:
        print(f"\nError occurred during fold {fold}: {str(e)}")
        continue

# 输出结果
if accuracy_scores:
    print("\n=== Final Results ===")
    print(f"Average Accuracy: {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
    print(f"Average AUC: {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
    print(f"Average Training Time: {np.mean(training_times):.2f} seconds")

    # 找到AUC最高的fold
    best_fold = np.argmax(auc_scores)
    best_model = models[best_fold]
    best_auc = auc_scores[best_fold]

    print(f"\nBest model from Fold {best_fold + 1} with AUC: {best_auc:.4f}")

    # 保存最佳模型
    model_filename = f"best_xgboost_model_fold{best_fold + 1}_auc{best_auc:.4f}.joblib"
    # joblib.dump(best_model, model_filename)
    print(f"Best model saved as {model_filename}")
else:
    print("\nNo valid results were obtained")
# Out:
# ===== Fold 1 =====
#
# Training started...
# [0]	validation_0-auc:0.63862
# [10]	validation_0-auc:0.65990
# [20]	validation_0-auc:0.66114
# [30]	validation_0-auc:0.66283
# [40]	validation_0-auc:0.66297
# [50]	validation_0-auc:0.66462
# [60]	validation_0-auc:0.66497
# [70]	validation_0-auc:0.66587
# [80]	validation_0-auc:0.66567
# [90]	validation_0-auc:0.66638
# [100]	validation_0-auc:0.66708
# [110]	validation_0-auc:0.66768
# [120]	validation_0-auc:0.66829
# [130]	validation_0-auc:0.66908
# [140]	validation_0-auc:0.66957
# [150]	validation_0-auc:0.67014
# [160]	validation_0-auc:0.67124
# [170]	validation_0-auc:0.67196
# [180]	validation_0-auc:0.67272
# [190]	validation_0-auc:0.67346
# [200]	validation_0-auc:0.67407
# [210]	validation_0-auc:0.67483
# [220]	validation_0-auc:0.67528
# [230]	validation_0-auc:0.67605
# [240]	validation_0-auc:0.67642
# [250]	validation_0-auc:0.67704
# [260]	validation_0-auc:0.67748
# [270]	validation_0-auc:0.67797
# [280]	validation_0-auc:0.67843
# [290]	validation_0-auc:0.67890
# [300]	validation_0-auc:0.67922
# [310]	validation_0-auc:0.67956
# [320]	validation_0-auc:0.68006
# [330]	validation_0-auc:0.68043
# [340]	validation_0-auc:0.68081
# [350]	validation_0-auc:0.68121
# [360]	validation_0-auc:0.68158
# [370]	validation_0-auc:0.68193
# [380]	validation_0-auc:0.68226
# [390]	validation_0-auc:0.68260
# [399]	validation_0-auc:0.68285
# Training completed in 93.21 seconds
# Fold 1 Accuracy: 0.6371
# Fold 1 AUC: 0.6829
#
# ===== Fold 2 =====
#
# Training started...
# [0]	validation_0-auc:0.62877
# [10]	validation_0-auc:0.65280
# [20]	validation_0-auc:0.65365
# [30]	validation_0-auc:0.65636
# [40]	validation_0-auc:0.65537
# [50]	validation_0-auc:0.65652
# [60]	validation_0-auc:0.65667
# [70]	validation_0-auc:0.65733
# [80]	validation_0-auc:0.65726
# [90]	validation_0-auc:0.65784
# [100]	validation_0-auc:0.65871
# [110]	validation_0-auc:0.65922
# [120]	validation_0-auc:0.65971
# [130]	validation_0-auc:0.66069
# [140]	validation_0-auc:0.66136
# [150]	validation_0-auc:0.66255
# [160]	validation_0-auc:0.66349
# [170]	validation_0-auc:0.66408
# [180]	validation_0-auc:0.66484
# [190]	validation_0-auc:0.66564
# [200]	validation_0-auc:0.66609
# [210]	validation_0-auc:0.66702
# [220]	validation_0-auc:0.66782
# [230]	validation_0-auc:0.66870
# [240]	validation_0-auc:0.66928
# [250]	validation_0-auc:0.66972
# [260]	validation_0-auc:0.67020
# [270]	validation_0-auc:0.67083
# [280]	validation_0-auc:0.67135
# [290]	validation_0-auc:0.67175
# [300]	validation_0-auc:0.67234
# [310]	validation_0-auc:0.67295
# [320]	validation_0-auc:0.67338
# [330]	validation_0-auc:0.67378
# [340]	validation_0-auc:0.67423
# [350]	validation_0-auc:0.67469
# [360]	validation_0-auc:0.67505
# [370]	validation_0-auc:0.67538
# [380]	validation_0-auc:0.67566
# [390]	validation_0-auc:0.67607
# [399]	validation_0-auc:0.67624
# Training completed in 106.89 seconds
# Fold 2 Accuracy: 0.6379
# Fold 2 AUC: 0.6762
#
# ===== Fold 3 =====
#
#
# Error occurred during fold 3: Unable to allocate 148. MiB for an array with shape (61, 318477) and data type float64
#
# ===== Fold 4 =====
#
#
# Error occurred during fold 4: Unable to allocate 148. MiB for an array with shape (61, 318477) and data type float64
#
# ===== Fold 5 =====
#
#
# Error occurred during fold 5: Unable to allocate 148. MiB for an array with shape (61, 318477) and data type float64
#
# === Final Results ===
# Average Accuracy: 0.6375 ± 0.0004
# Average AUC: 0.6795 ± 0.0033
# Average Training Time: 100.05 seconds
#
# Best model from Fold 1 with AUC: 0.6829
# Best model saved as best_xgboost_model_fold1_auc0.6829.joblib

# %%
external_indices = df[df['Region'].isin(['Scotland', 'Wales'])].index
# 获取苏格兰和威尔士参与者的数据
X_external = data_imputed_df.loc[external_indices]  # 特征
y_external = df.loc[external_indices, 'status']  # 标签
print("外部验证集形状:", X_external.shape)
X_external
# 预测类别（0/1）
y_pred = best_model.predict(X_external)
# 预测概率（用于 AUC 等指标）
y_pred_proba = best_model.predict_proba(X_external)[:, 1]  # 正类的概率
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# 计算准确率和 AUC
accuracy = accuracy_score(y_external, y_pred)
auc = roc_auc_score(y_external, y_pred_proba)

print(f"测试集准确率: {accuracy:.4f}")
print(f"测试集 AUC: {auc:.4f}")
# Out:
# 外部验证集形状: (50653, 62)
# 测试集准确率: 0.6152
# 测试集 AUC: 0.6975

# %%
from sklearn.metrics import roc_curve, auc, classification_report

# 用最佳模型预测
y_proba = best_model.predict_proba(X_test)[:, 1]
# 计算并绘制 ROC 曲线
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('Best XGBoost ROC Curve(internal)')
plt.legend()
plt.show()
#绘制混淆矩阵
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 使用最佳模型进行预测
y_pred = best_model.predict(X_test)

# 计算混淆矩阵
cm = confusion_matrix(y_test, y_pred)

# 可视化混淆矩阵
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['No Stroke', 'Stroke'])
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix for Stroke Prediction(internal)')
plt.show()
# 筛选来自苏格兰和威尔士的参与者
external_indices = df[df['Region'].isin(['Scotland', 'Wales'])].index
# 获取苏格兰和威尔士参与者的数据
X_external = data_imputed_df.loc[external_indices]  # 特征
y_external = df.loc[external_indices, 'status']  # 标签
print("外部验证集形状:", X_external.shape)
#外部 4. 用最佳模型预测
y_proba = best_model.predict_proba(X_external)[:, 1]
# 5. 计算并绘制 ROC 曲线
fpr, tpr, _ = roc_curve(y_external, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('Best XGBoost ROC Curve(external)')
plt.legend()
plt.show()
#绘制混淆矩阵
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 使用最佳模型进行预测
y_pred = best_model.predict(X_external)

# 计算混淆矩阵
cm = confusion_matrix(y_external, y_pred)

# 可视化混淆矩阵
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['No Stroke', 'Stroke'])
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix for Stroke Prediction(external)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 # 5. 计算并绘制 ROC 曲线
#       4 fpr, tpr, _ = roc_curve(y_val, y_proba)
# ----> 5 roc_auc = auc(fpr, tpr)
#       7 plt.figure()
#       8 plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
#
# TypeError: 'numpy.float64' object is not callable
