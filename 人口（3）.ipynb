# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, classification_report

#定义数据路径和输出文件路径
dpath = 'D:\\Python_study\\5组代码\\卒中发病预测\\'
outfile = dpath + 'output__new/Stroke___panel/Stroke_hierarchy.csv'
df = pd.read_csv("D:\\课题\\peo_people448749.csv")
# 确保 data_imputed 是 DataFrame
data_imputed_df = pd.read_csv("D:\\Python_study\\5组代码\\卒中发病预测\\peo_imputed_data448749(mean).csv")

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score
import time
import joblib
# 筛选来自英格兰的参与者
england_indices = df[df['Region'] == 'England'].index
X_england = data_imputed_df.loc[england_indices]
y_england = df.loc[england_indices, 'status']

# 定义5折交叉验证
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# 存储每折的评估结果
accuracy_scores = []
auc_scores = []
training_times = []
models = []
# 计算类别权重（需要在循环内计算，因为每折的分布可能不同）
# 注意：这里我们会在循环内计算，因为y_train在每折不同

# 固定参数（从你的网格中取第一个值）
params = {
    'alpha': 1.5,          # L1 正则化
    'lambda': 1.5,         # L2 正则化
    'gamma': 0.2,          # 分裂最小损失下降
    'colsample_bytree': 0.75,  # 特征采样比例
    'subsample': 0.85,     # 数据采样比例
    'learning_rate': 0.007, # 学习率
    'max_depth': 9,        # 树的最大深度
    'n_estimators': 5200,  # 树的数量
    'min_child_weight': 3, # 叶子节点最小样本权重
    'eval_metric':'auc'
}
# 开始交叉验证
for fold, (train_idx, val_idx) in enumerate(kf.split(X_england), 1):
    try:
        print(f"\n===== Fold {fold} =====\n")
        X_train, X_val = X_england.iloc[train_idx], X_england.iloc[val_idx]
        y_train, y_val = y_england.iloc[train_idx], y_england.iloc[val_idx]

        # 计算当前fold的类别权重
        scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)
        current_params = params.copy()
        current_params['scale_pos_weight'] = scale_pos_weight

        # 初始化模型
        model = XGBClassifier(**current_params)

        # 训练模型并计时
        start_time = time.time()
        print("Training started...")
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=10  # 每10轮显示一次进度
        )
        training_time = time.time() - start_time
        training_times.append(training_time)
        print(f"Training completed in {training_time:.2f} seconds")

        # 预测
        y_pred = model.predict(X_val)
        y_pred_proba = model.predict_proba(X_val)[:, 1]  # 获取正类的概率

        # 评估
        accuracy = accuracy_score(y_val, y_pred)
        auc = roc_auc_score(y_val, y_pred_proba)

        accuracy_scores.append(accuracy)
        auc_scores.append(auc)
        models.append(model)  # 保存当前fold的模型
        print(f"Fold {fold} Accuracy: {accuracy:.4f}")
        print(f"Fold {fold} AUC: {auc:.4f}")

    except KeyboardInterrupt:
        print("\nTraining interrupted by user")
        break
    except Exception as e:
        print(f"\nError occurred during fold {fold}: {str(e)}")
        continue

# 输出结果
if accuracy_scores:
    print("\n=== Final Results ===")
    print(f"Average Accuracy: {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
    print(f"Average AUC: {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
    print(f"Average Training Time: {np.mean(training_times):.2f} seconds")

    # 找到AUC最高的fold
    best_fold = np.argmax(auc_scores)
    best_model = models[best_fold]
    best_auc = auc_scores[best_fold]

    print(f"\nBest model from Fold {best_fold + 1} with AUC: {best_auc:.4f}")

    # 保存最佳模型
    model_filename = f"best_xgboost_model_fold{best_fold + 1}_auc{best_auc:.4f}.joblib"
    # joblib.dump(best_model, model_filename)
    print(f"Best model saved as {model_filename}")
else:
    print("\nNo valid results were obtained")
# Out:
# ===== Fold 1 =====
#
# Training started...
# [0]	validation_0-auc:0.65544
# [10]	validation_0-auc:0.70464
# [20]	validation_0-auc:0.70877
# [30]	validation_0-auc:0.71047
# [40]	validation_0-auc:0.71158
# [50]	validation_0-auc:0.71282
# [60]	validation_0-auc:0.71355
# [70]	validation_0-auc:0.71420
# [80]	validation_0-auc:0.71483
# [90]	validation_0-auc:0.71448
# [100]	validation_0-auc:0.71464
# [110]	validation_0-auc:0.71465
# [120]	validation_0-auc:0.71493
# [130]	validation_0-auc:0.71525
# [140]	validation_0-auc:0.71547
# [150]	validation_0-auc:0.71545
# [160]	validation_0-auc:0.71549
# [170]	validation_0-auc:0.71578
# [180]	validation_0-auc:0.71612
# [190]	validation_0-auc:0.71645
# [200]	validation_0-auc:0.71648
# [210]	validation_0-auc:0.71622
# [220]	validation_0-auc:0.71628
# [230]	validation_0-auc:0.71634
# [240]	validation_0-auc:0.71616
# [250]	validation_0-auc:0.71616
# [260]	validation_0-auc:0.71616
# [270]	validation_0-auc:0.71604
# [280]	validation_0-auc:0.71597
# [290]	validation_0-auc:0.71598
# [300]	validation_0-auc:0.71604
# [310]	validation_0-auc:0.71590
# [320]	validation_0-auc:0.71572
# [330]	validation_0-auc:0.71574
# [340]	validation_0-auc:0.71560
# [350]	validation_0-auc:0.71556
# [360]	validation_0-auc:0.71541
# [370]	validation_0-auc:0.71525
# [380]	validation_0-auc:0.71519
# [390]	validation_0-auc:0.71512
# [400]	validation_0-auc:0.71519
# [410]	validation_0-auc:0.71512
# [420]	validation_0-auc:0.71498
# [430]	validation_0-auc:0.71498
# [440]	validation_0-auc:0.71502
# [450]	validation_0-auc:0.71504
# [460]	validation_0-auc:0.71488
# [470]	validation_0-auc:0.71466
# [480]	validation_0-auc:0.71448
# [490]	validation_0-auc:0.71443
# [500]	validation_0-auc:0.71443
# [510]	validation_0-auc:0.71427
# [520]	validation_0-auc:0.71415
# [530]	validation_0-auc:0.71386
# [540]	validation_0-auc:0.71375
# [550]	validation_0-auc:0.71368
# [560]	validation_0-auc:0.71350
# [570]	validation_0-auc:0.71337
# [580]	validation_0-auc:0.71316
# [590]	validation_0-auc:0.71302
# [600]	validation_0-auc:0.71283
# [610]	validation_0-auc:0.71273
# [620]	validation_0-auc:0.71261
# [630]	validation_0-auc:0.71247
# [640]	validation_0-auc:0.71225
# [650]	validation_0-auc:0.71218
# [660]	validation_0-auc:0.71207
# [670]	validation_0-auc:0.71190
# [680]	validation_0-auc:0.71184
# [690]	validation_0-auc:0.71175
# [700]	validation_0-auc:0.71175
# [710]	validation_0-auc:0.71168
# [720]	validation_0-auc:0.71155
# [730]	validation_0-auc:0.71138
# [740]	validation_0-auc:0.71115
# [750]	validation_0-auc:0.71103
# [760]	validation_0-auc:0.71096
# [770]	validation_0-auc:0.71088
# [780]	validation_0-auc:0.71078
# [790]	validation_0-auc:0.71071
# [800]	validation_0-auc:0.71053
# [810]	validation_0-auc:0.71045
# [820]	validation_0-auc:0.71037
# [830]	validation_0-auc:0.71020
# [840]	validation_0-auc:0.71008
# [850]	validation_0-auc:0.70990
# [860]	validation_0-auc:0.70988
# [870]	validation_0-auc:0.70974
# [880]	validation_0-auc:0.70959
# [890]	validation_0-auc:0.70950
# [900]	validation_0-auc:0.70947
# [910]	validation_0-auc:0.70940
# [920]	validation_0-auc:0.70934
# [930]	validation_0-auc:0.70915
# [940]	validation_0-auc:0.70910
# [950]	validation_0-auc:0.70897
# [960]	validation_0-auc:0.70889
# [970]	validation_0-auc:0.70875
# [980]	validation_0-auc:0.70852
# [990]	validation_0-auc:0.70845
# [1000]	validation_0-auc:0.70839
# [1010]	validation_0-auc:0.70832
# [1020]	validation_0-auc:0.70824
# [1030]	validation_0-auc:0.70807
# [1040]	validation_0-auc:0.70799
# [1050]	validation_0-auc:0.70798
# [1060]	validation_0-auc:0.70788
# [1070]	validation_0-auc:0.70773
# [1080]	validation_0-auc:0.70756
# [1090]	validation_0-auc:0.70751
# [1100]	validation_0-auc:0.70741
# [1110]	validation_0-auc:0.70717
# [1120]	validation_0-auc:0.70716
# [1130]	validation_0-auc:0.70697
# [1140]	validation_0-auc:0.70689
# [1150]	validation_0-auc:0.70677
# [1160]	validation_0-auc:0.70661
# [1170]	validation_0-auc:0.70646
# [1180]	validation_0-auc:0.70637
# [1190]	validation_0-auc:0.70625
# [1200]	validation_0-auc:0.70618
# [1210]	validation_0-auc:0.70614
# [1220]	validation_0-auc:0.70591
# [1230]	validation_0-auc:0.70582
# [1240]	validation_0-auc:0.70573
# [1250]	validation_0-auc:0.70567
# [1260]	validation_0-auc:0.70556
# [1270]	validation_0-auc:0.70536
# [1280]	validation_0-auc:0.70527
# [1290]	validation_0-auc:0.70510
# [1300]	validation_0-auc:0.70503
# [1310]	validation_0-auc:0.70487
# [1320]	validation_0-auc:0.70472
# [1330]	validation_0-auc:0.70451
# [1340]	validation_0-auc:0.70433
# [1350]	validation_0-auc:0.70437
# [1360]	validation_0-auc:0.70427
# [1370]	validation_0-auc:0.70417
# [1380]	validation_0-auc:0.70417
# [1390]	validation_0-auc:0.70404
# [1400]	validation_0-auc:0.70389
# [1410]	validation_0-auc:0.70370
# [1420]	validation_0-auc:0.70359
# [1430]	validation_0-auc:0.70345
# [1440]	validation_0-auc:0.70335
# [1450]	validation_0-auc:0.70314
# [1460]	validation_0-auc:0.70305
# [1470]	validation_0-auc:0.70301
# [1480]	validation_0-auc:0.70289
# [1490]	validation_0-auc:0.70267
# [1500]	validation_0-auc:0.70260
# [1510]	validation_0-auc:0.70241
# [1520]	validation_0-auc:0.70229
# [1530]	validation_0-auc:0.70209
# [1540]	validation_0-auc:0.70186
# [1550]	validation_0-auc:0.70181
# [1560]	validation_0-auc:0.70177
# [1570]	validation_0-auc:0.70171
# [1580]	validation_0-auc:0.70159
# [1590]	validation_0-auc:0.70144
# [1600]	validation_0-auc:0.70128
# [1610]	validation_0-auc:0.70113
# [1620]	validation_0-auc:0.70103
# [1630]	validation_0-auc:0.70092
# [1640]	validation_0-auc:0.70083
# [1650]	validation_0-auc:0.70071
# [1660]	validation_0-auc:0.70070
# [1670]	validation_0-auc:0.70060
# [1680]	validation_0-auc:0.70048
# [1690]	validation_0-auc:0.70027
# [1700]	validation_0-auc:0.70021
# [1710]	validation_0-auc:0.70001
# [1720]	validation_0-auc:0.69990
# [1730]	validation_0-auc:0.69978
# [1740]	validation_0-auc:0.69961
# [1750]	validation_0-auc:0.69953
# [1760]	validation_0-auc:0.69937
# [1770]	validation_0-auc:0.69918
# [1780]	validation_0-auc:0.69902
# [1790]	validation_0-auc:0.69895
# [1800]	validation_0-auc:0.69882
# [1810]	validation_0-auc:0.69879
# [1820]	validation_0-auc:0.69866
# [1830]	validation_0-auc:0.69846
# [1840]	validation_0-auc:0.69831
# [1850]	validation_0-auc:0.69820
# [1860]	validation_0-auc:0.69806
# [1870]	validation_0-auc:0.69784
# [1880]	validation_0-auc:0.69763
# [1890]	validation_0-auc:0.69751
# [1900]	validation_0-auc:0.69739
# [1910]	validation_0-auc:0.69726
# [1920]	validation_0-auc:0.69707
# [1930]	validation_0-auc:0.69696
# [1940]	validation_0-auc:0.69690
# [1950]	validation_0-auc:0.69674
# [1960]	validation_0-auc:0.69652
# [1970]	validation_0-auc:0.69647
# [1980]	validation_0-auc:0.69631
# [1990]	validation_0-auc:0.69616
# [2000]	validation_0-auc:0.69602
# [2010]	validation_0-auc:0.69592
# [2020]	validation_0-auc:0.69583
# [2030]	validation_0-auc:0.69564
# [2040]	validation_0-auc:0.69559
# [2050]	validation_0-auc:0.69541
# [2060]	validation_0-auc:0.69521
# [2070]	validation_0-auc:0.69505
# [2080]	validation_0-auc:0.69502
# [2090]	validation_0-auc:0.69485
# [2100]	validation_0-auc:0.69476
# [2110]	validation_0-auc:0.69466
# [2120]	validation_0-auc:0.69448
# [2130]	validation_0-auc:0.69438
# [2140]	validation_0-auc:0.69425
# [2150]	validation_0-auc:0.69424
# [2160]	validation_0-auc:0.69405
# [2170]	validation_0-auc:0.69396
# [2180]	validation_0-auc:0.69377
# [2190]	validation_0-auc:0.69371
# [2200]	validation_0-auc:0.69361
# [2210]	validation_0-auc:0.69350
# [2220]	validation_0-auc:0.69346
# [2230]	validation_0-auc:0.69332
# [2240]	validation_0-auc:0.69322
# [2250]	validation_0-auc:0.69309
# [2260]	validation_0-auc:0.69301
# [2270]	validation_0-auc:0.69288
# [2280]	validation_0-auc:0.69276
# [2290]	validation_0-auc:0.69261
# [2300]	validation_0-auc:0.69249
# [2310]	validation_0-auc:0.69236
# [2320]	validation_0-auc:0.69220
# [2330]	validation_0-auc:0.69210
# [2340]	validation_0-auc:0.69191
# [2350]	validation_0-auc:0.69173
# [2360]	validation_0-auc:0.69162
# [2370]	validation_0-auc:0.69154
# [2380]	validation_0-auc:0.69146
# [2390]	validation_0-auc:0.69136
# [2400]	validation_0-auc:0.69126
# [2410]	validation_0-auc:0.69108
# [2420]	validation_0-auc:0.69097
# [2430]	validation_0-auc:0.69077
# [2440]	validation_0-auc:0.69065
# [2450]	validation_0-auc:0.69050
# [2460]	validation_0-auc:0.69041
# [2470]	validation_0-auc:0.69030
# [2480]	validation_0-auc:0.69021
# [2490]	validation_0-auc:0.69006
# [2500]	validation_0-auc:0.68986
# [2510]	validation_0-auc:0.68973
# [2520]	validation_0-auc:0.68964
# [2530]	validation_0-auc:0.68950
# [2540]	validation_0-auc:0.68931
# [2550]	validation_0-auc:0.68923
# [2560]	validation_0-auc:0.68907
# [2570]	validation_0-auc:0.68899
# [2580]	validation_0-auc:0.68894
# [2590]	validation_0-auc:0.68881
# [2600]	validation_0-auc:0.68879
# [2610]	validation_0-auc:0.68854
# [2620]	validation_0-auc:0.68840
# [2630]	validation_0-auc:0.68827
# [2640]	validation_0-auc:0.68816
# [2650]	validation_0-auc:0.68805
# [2660]	validation_0-auc:0.68796
# [2670]	validation_0-auc:0.68782
# [2680]	validation_0-auc:0.68765
# [2690]	validation_0-auc:0.68758
# [2700]	validation_0-auc:0.68755
# [2710]	validation_0-auc:0.68735
# [2720]	validation_0-auc:0.68722
# [2730]	validation_0-auc:0.68716
# [2740]	validation_0-auc:0.68703
# [2750]	validation_0-auc:0.68695
# [2760]	validation_0-auc:0.68685
# [2770]	validation_0-auc:0.68667
# [2780]	validation_0-auc:0.68657
# [2790]	validation_0-auc:0.68646
# [2800]	validation_0-auc:0.68641
# [2810]	validation_0-auc:0.68637
# [2820]	validation_0-auc:0.68626
# [2830]	validation_0-auc:0.68613
# [2840]	validation_0-auc:0.68597
# [2850]	validation_0-auc:0.68585
# [2860]	validation_0-auc:0.68582
# [2870]	validation_0-auc:0.68565
# [2880]	validation_0-auc:0.68550
# [2890]	validation_0-auc:0.68542
# [2900]	validation_0-auc:0.68527
# [2910]	validation_0-auc:0.68519
# [2920]	validation_0-auc:0.68502
# [2930]	validation_0-auc:0.68488
# [2940]	validation_0-auc:0.68477
# [2950]	validation_0-auc:0.68465
# [2960]	validation_0-auc:0.68452
# [2970]	validation_0-auc:0.68437
# [2980]	validation_0-auc:0.68425
# [2990]	validation_0-auc:0.68414
# [3000]	validation_0-auc:0.68402
# [3010]	validation_0-auc:0.68388
# [3020]	validation_0-auc:0.68376
# [3030]	validation_0-auc:0.68363
# [3040]	validation_0-auc:0.68355
# [3050]	validation_0-auc:0.68338
# [3060]	validation_0-auc:0.68328
# [3070]	validation_0-auc:0.68318
# [3080]	validation_0-auc:0.68309
# [3090]	validation_0-auc:0.68289
# [3100]	validation_0-auc:0.68276
# [3110]	validation_0-auc:0.68257
# [3120]	validation_0-auc:0.68247
# [3130]	validation_0-auc:0.68233
# [3140]	validation_0-auc:0.68225
# [3150]	validation_0-auc:0.68210
# [3160]	validation_0-auc:0.68196
# [3170]	validation_0-auc:0.68188
# [3180]	validation_0-auc:0.68183
# [3190]	validation_0-auc:0.68173
# [3200]	validation_0-auc:0.68160
# [3210]	validation_0-auc:0.68141
# [3220]	validation_0-auc:0.68126
# [3230]	validation_0-auc:0.68111
# [3240]	validation_0-auc:0.68091
# [3250]	validation_0-auc:0.68084
# [3260]	validation_0-auc:0.68069
# [3270]	validation_0-auc:0.68056
# [3280]	validation_0-auc:0.68045
# [3290]	validation_0-auc:0.68042
# [3300]	validation_0-auc:0.68033
# [3310]	validation_0-auc:0.68015
# [3320]	validation_0-auc:0.67999
# [3330]	validation_0-auc:0.67986
# [3340]	validation_0-auc:0.67972
# [3350]	validation_0-auc:0.67958
# [3360]	validation_0-auc:0.67943
# [3370]	validation_0-auc:0.67929
# [3380]	validation_0-auc:0.67919
# [3390]	validation_0-auc:0.67904
# [3400]	validation_0-auc:0.67889
# [3410]	validation_0-auc:0.67876
# [3420]	validation_0-auc:0.67859
# [3430]	validation_0-auc:0.67848
# [3440]	validation_0-auc:0.67832
# [3450]	validation_0-auc:0.67827
# [3460]	validation_0-auc:0.67814
# [3470]	validation_0-auc:0.67805
# [3480]	validation_0-auc:0.67793
# [3490]	validation_0-auc:0.67786
# [3500]	validation_0-auc:0.67780
# [3510]	validation_0-auc:0.67760
# [3520]	validation_0-auc:0.67746
# [3530]	validation_0-auc:0.67736
# [3540]	validation_0-auc:0.67723
# [3550]	validation_0-auc:0.67712
# [3560]	validation_0-auc:0.67699
# [3570]	validation_0-auc:0.67694
# [3580]	validation_0-auc:0.67682
# [3590]	validation_0-auc:0.67676
# [3600]	validation_0-auc:0.67666
# [3610]	validation_0-auc:0.67656
# [3620]	validation_0-auc:0.67648
# [3630]	validation_0-auc:0.67630
# [3640]	validation_0-auc:0.67615
# [3650]	validation_0-auc:0.67601
# [3660]	validation_0-auc:0.67589
# [3670]	validation_0-auc:0.67569
# [3680]	validation_0-auc:0.67560
# [3690]	validation_0-auc:0.67540
# [3700]	validation_0-auc:0.67534
# [3710]	validation_0-auc:0.67528
# [3720]	validation_0-auc:0.67518
# [3730]	validation_0-auc:0.67509
# [3740]	validation_0-auc:0.67501
# [3750]	validation_0-auc:0.67491
# [3760]	validation_0-auc:0.67484
# [3770]	validation_0-auc:0.67473
# [3780]	validation_0-auc:0.67465
# [3790]	validation_0-auc:0.67456
# [3800]	validation_0-auc:0.67446
# [3810]	validation_0-auc:0.67440
# [3820]	validation_0-auc:0.67429
# [3830]	validation_0-auc:0.67421
# [3840]	validation_0-auc:0.67407
# [3850]	validation_0-auc:0.67394
# [3860]	validation_0-auc:0.67380
# [3870]	validation_0-auc:0.67365
# [3880]	validation_0-auc:0.67349
# [3890]	validation_0-auc:0.67335
# [3900]	validation_0-auc:0.67319
# [3910]	validation_0-auc:0.67310
# [3920]	validation_0-auc:0.67299
# [3930]	validation_0-auc:0.67297
# [3940]	validation_0-auc:0.67289
# [3950]	validation_0-auc:0.67284
# [3960]	validation_0-auc:0.67277
# [3970]	validation_0-auc:0.67264
# [3980]	validation_0-auc:0.67250
# [3990]	validation_0-auc:0.67237
# [4000]	validation_0-auc:0.67228
# [4010]	validation_0-auc:0.67220
# [4020]	validation_0-auc:0.67203
# [4030]	validation_0-auc:0.67192
# [4040]	validation_0-auc:0.67183
# [4050]	validation_0-auc:0.67179
# [4060]	validation_0-auc:0.67163
# [4070]	validation_0-auc:0.67156
# [4080]	validation_0-auc:0.67146
# [4090]	validation_0-auc:0.67132
# [4100]	validation_0-auc:0.67123
# [4110]	validation_0-auc:0.67120
# [4120]	validation_0-auc:0.67107
# [4130]	validation_0-auc:0.67097
# [4140]	validation_0-auc:0.67085
# [4150]	validation_0-auc:0.67071
# [4160]	validation_0-auc:0.67060
# [4170]	validation_0-auc:0.67054
# [4180]	validation_0-auc:0.67045
# [4190]	validation_0-auc:0.67035
# [4200]	validation_0-auc:0.67028
# [4210]	validation_0-auc:0.67016
# [4220]	validation_0-auc:0.67001
# [4230]	validation_0-auc:0.66994
# [4240]	validation_0-auc:0.66990
# [4250]	validation_0-auc:0.66981
# [4260]	validation_0-auc:0.66976
# [4270]	validation_0-auc:0.66971
# [4280]	validation_0-auc:0.66966
# [4290]	validation_0-auc:0.66956
# [4300]	validation_0-auc:0.66942
# [4310]	validation_0-auc:0.66926
# [4320]	validation_0-auc:0.66915
# [4330]	validation_0-auc:0.66909
# [4340]	validation_0-auc:0.66900
# [4350]	validation_0-auc:0.66885
# [4360]	validation_0-auc:0.66876
# [4370]	validation_0-auc:0.66863
# [4380]	validation_0-auc:0.66849
# [4390]	validation_0-auc:0.66843
# [4400]	validation_0-auc:0.66833
# [4410]	validation_0-auc:0.66821
# [4420]	validation_0-auc:0.66817
# [4430]	validation_0-auc:0.66807
# [4440]	validation_0-auc:0.66801
# [4450]	validation_0-auc:0.66797
# [4460]	validation_0-auc:0.66785
# [4470]	validation_0-auc:0.66777
# [4480]	validation_0-auc:0.66773
# [4490]	validation_0-auc:0.66766
# [4500]	validation_0-auc:0.66759
# [4510]	validation_0-auc:0.66752
# [4520]	validation_0-auc:0.66745
# [4530]	validation_0-auc:0.66736
# [4540]	validation_0-auc:0.66728
# [4550]	validation_0-auc:0.66711
# [4560]	validation_0-auc:0.66702
# [4570]	validation_0-auc:0.66693
# [4580]	validation_0-auc:0.66685
# [4590]	validation_0-auc:0.66682
# [4600]	validation_0-auc:0.66663
# [4610]	validation_0-auc:0.66657
# [4620]	validation_0-auc:0.66649
# [4630]	validation_0-auc:0.66643
# [4640]	validation_0-auc:0.66634
# [4650]	validation_0-auc:0.66623
# [4660]	validation_0-auc:0.66620
# [4670]	validation_0-auc:0.66608
# [4680]	validation_0-auc:0.66598
# [4690]	validation_0-auc:0.66583
# [4700]	validation_0-auc:0.66578
# [4710]	validation_0-auc:0.66574
# [4720]	validation_0-auc:0.66565
# [4730]	validation_0-auc:0.66565
# [4740]	validation_0-auc:0.66557
# [4750]	validation_0-auc:0.66546
# [4760]	validation_0-auc:0.66539
# [4770]	validation_0-auc:0.66527
# [4780]	validation_0-auc:0.66520
# [4790]	validation_0-auc:0.66518
# [4800]	validation_0-auc:0.66509
# [4810]	validation_0-auc:0.66498
# [4820]	validation_0-auc:0.66488
# [4830]	validation_0-auc:0.66478
# [4840]	validation_0-auc:0.66471
# [4850]	validation_0-auc:0.66466
# [4860]	validation_0-auc:0.66456
# [4870]	validation_0-auc:0.66450
# [4880]	validation_0-auc:0.66442
# [4890]	validation_0-auc:0.66440
# [4900]	validation_0-auc:0.66438
# [4910]	validation_0-auc:0.66427
# [4920]	validation_0-auc:0.66416
# [4930]	validation_0-auc:0.66414
# [4940]	validation_0-auc:0.66413
# [4950]	validation_0-auc:0.66407
# [4960]	validation_0-auc:0.66393
# [4970]	validation_0-auc:0.66389
# [4980]	validation_0-auc:0.66385
# [4990]	validation_0-auc:0.66383
# [5000]	validation_0-auc:0.66374
# [5010]	validation_0-auc:0.66374
# [5020]	validation_0-auc:0.66365
# [5030]	validation_0-auc:0.66357
# [5040]	validation_0-auc:0.66349
# [5050]	validation_0-auc:0.66343
# [5060]	validation_0-auc:0.66334
# [5070]	validation_0-auc:0.66327
# [5080]	validation_0-auc:0.66320
# [5090]	validation_0-auc:0.66312
# [5100]	validation_0-auc:0.66307
# [5110]	validation_0-auc:0.66296
# [5120]	validation_0-auc:0.66288
# [5130]	validation_0-auc:0.66273
# [5140]	validation_0-auc:0.66271
# [5150]	validation_0-auc:0.66263
# [5160]	validation_0-auc:0.66255
# [5170]	validation_0-auc:0.66248
# [5180]	validation_0-auc:0.66243
# [5190]	validation_0-auc:0.66232
# [5199]	validation_0-auc:0.66229
# Training completed in 3273.89 seconds
# Fold 1 Accuracy: 0.9694
# Fold 1 AUC: 0.6623
#
# ===== Fold 2 =====
#
# Training started...
# [0]	validation_0-auc:0.65619
# [10]	validation_0-auc:0.70967
# [20]	validation_0-auc:0.71452
# [30]	validation_0-auc:0.71723
# [40]	validation_0-auc:0.71729
# [50]	validation_0-auc:0.71836
# [60]	validation_0-auc:0.71952
# [70]	validation_0-auc:0.72034
# [80]	validation_0-auc:0.72006
# [90]	validation_0-auc:0.72036
# [100]	validation_0-auc:0.72044
# [110]	validation_0-auc:0.72051
# [120]	validation_0-auc:0.72073
# [130]	validation_0-auc:0.72045
# [140]	validation_0-auc:0.72020
# [150]	validation_0-auc:0.72046
# [160]	validation_0-auc:0.72059
# [170]	validation_0-auc:0.72065
# [180]	validation_0-auc:0.72079
# [190]	validation_0-auc:0.72071
# [200]	validation_0-auc:0.72091
# [210]	validation_0-auc:0.72110
# [220]	validation_0-auc:0.72109
# [230]	validation_0-auc:0.72101
# [240]	validation_0-auc:0.72113
# [250]	validation_0-auc:0.72134
# [260]	validation_0-auc:0.72130
# [270]	validation_0-auc:0.72156
# [280]	validation_0-auc:0.72161
# [290]	validation_0-auc:0.72134
# [300]	validation_0-auc:0.72124
# [310]	validation_0-auc:0.72108
# [320]	validation_0-auc:0.72092
# [330]	validation_0-auc:0.72088
# [340]	validation_0-auc:0.72090
# [350]	validation_0-auc:0.72099
# [360]	validation_0-auc:0.72104
# [370]	validation_0-auc:0.72099
# [380]	validation_0-auc:0.72081
# [390]	validation_0-auc:0.72081
# [400]	validation_0-auc:0.72064
# [410]	validation_0-auc:0.72060
# [420]	validation_0-auc:0.72064
# [430]	validation_0-auc:0.72070
# [440]	validation_0-auc:0.72067
# [450]	validation_0-auc:0.72056
# [460]	validation_0-auc:0.72045
# [470]	validation_0-auc:0.72040
# [480]	validation_0-auc:0.72033
# [490]	validation_0-auc:0.72033
# [500]	validation_0-auc:0.72018
# [510]	validation_0-auc:0.72015
# [520]	validation_0-auc:0.71993
# [530]	validation_0-auc:0.71979
# [540]	validation_0-auc:0.71975
# [550]	validation_0-auc:0.71955
# [560]	validation_0-auc:0.71938
# [570]	validation_0-auc:0.71929
# [580]	validation_0-auc:0.71916
# [590]	validation_0-auc:0.71911
# [600]	validation_0-auc:0.71905
# [610]	validation_0-auc:0.71908
# [620]	validation_0-auc:0.71902
# [630]	validation_0-auc:0.71885
# [640]	validation_0-auc:0.71868
# [650]	validation_0-auc:0.71855
# [660]	validation_0-auc:0.71831
# [670]	validation_0-auc:0.71816
# [680]	validation_0-auc:0.71803
# [690]	validation_0-auc:0.71796
# [700]	validation_0-auc:0.71781
# [710]	validation_0-auc:0.71775
# [720]	validation_0-auc:0.71764
# [730]	validation_0-auc:0.71769
# [740]	validation_0-auc:0.71755
# [750]	validation_0-auc:0.71738
# [760]	validation_0-auc:0.71723
# [770]	validation_0-auc:0.71710
# [780]	validation_0-auc:0.71701
# [790]	validation_0-auc:0.71687
# [800]	validation_0-auc:0.71663
# [810]	validation_0-auc:0.71654
# [820]	validation_0-auc:0.71630
# [830]	validation_0-auc:0.71612
# [840]	validation_0-auc:0.71608
# [850]	validation_0-auc:0.71605
# [860]	validation_0-auc:0.71591
# [870]	validation_0-auc:0.71567
# [880]	validation_0-auc:0.71561
# [890]	validation_0-auc:0.71550
# [900]	validation_0-auc:0.71534
# [910]	validation_0-auc:0.71513
# [920]	validation_0-auc:0.71506
# [930]	validation_0-auc:0.71490
# [940]	validation_0-auc:0.71480
# [950]	validation_0-auc:0.71474
# [960]	validation_0-auc:0.71456
# [970]	validation_0-auc:0.71440
# [980]	validation_0-auc:0.71422
# [990]	validation_0-auc:0.71411
# [1000]	validation_0-auc:0.71400
# [1010]	validation_0-auc:0.71379
# [1020]	validation_0-auc:0.71369
# [1030]	validation_0-auc:0.71356
# [1040]	validation_0-auc:0.71338
# [1050]	validation_0-auc:0.71319
# [1060]	validation_0-auc:0.71300
# [1070]	validation_0-auc:0.71298
# [1080]	validation_0-auc:0.71284
# [1090]	validation_0-auc:0.71273
# [1100]	validation_0-auc:0.71264
# [1110]	validation_0-auc:0.71252
# [1120]	validation_0-auc:0.71241
# [1130]	validation_0-auc:0.71231
# [1140]	validation_0-auc:0.71218
# [1150]	validation_0-auc:0.71211
# [1160]	validation_0-auc:0.71198
# [1170]	validation_0-auc:0.71186
# [1180]	validation_0-auc:0.71169
# [1190]	validation_0-auc:0.71156
# [1200]	validation_0-auc:0.71146
# [1210]	validation_0-auc:0.71131
# [1220]	validation_0-auc:0.71123
# [1230]	validation_0-auc:0.71112
# [1240]	validation_0-auc:0.71097
# [1250]	validation_0-auc:0.71088
# [1260]	validation_0-auc:0.71083
# [1270]	validation_0-auc:0.71066
# [1280]	validation_0-auc:0.71052
# [1290]	validation_0-auc:0.71049
# [1300]	validation_0-auc:0.71045
# [1310]	validation_0-auc:0.71036
# [1320]	validation_0-auc:0.71023
# [1330]	validation_0-auc:0.71005
# [1340]	validation_0-auc:0.70987
# [1350]	validation_0-auc:0.70967
# [1360]	validation_0-auc:0.70957
# [1370]	validation_0-auc:0.70942
# [1380]	validation_0-auc:0.70935
# [1390]	validation_0-auc:0.70919
# [1400]	validation_0-auc:0.70907
# [1410]	validation_0-auc:0.70883
# [1420]	validation_0-auc:0.70861
# [1430]	validation_0-auc:0.70854
# [1440]	validation_0-auc:0.70845
# [1450]	validation_0-auc:0.70828
# [1460]	validation_0-auc:0.70812
# [1470]	validation_0-auc:0.70793
# [1480]	validation_0-auc:0.70771
# [1490]	validation_0-auc:0.70759
# [1500]	validation_0-auc:0.70743
# [1510]	validation_0-auc:0.70725
# [1520]	validation_0-auc:0.70712
# [1530]	validation_0-auc:0.70700
# [1540]	validation_0-auc:0.70691
# [1550]	validation_0-auc:0.70686
# [1560]	validation_0-auc:0.70664
# [1570]	validation_0-auc:0.70658
# [1580]	validation_0-auc:0.70644
# [1590]	validation_0-auc:0.70633
# [1600]	validation_0-auc:0.70624
# [1610]	validation_0-auc:0.70620
# [1620]	validation_0-auc:0.70604
# [1630]	validation_0-auc:0.70595
# [1640]	validation_0-auc:0.70583
# [1650]	validation_0-auc:0.70571
# [1660]	validation_0-auc:0.70556
# [1670]	validation_0-auc:0.70554
# [1680]	validation_0-auc:0.70550
# [1690]	validation_0-auc:0.70539
# [1700]	validation_0-auc:0.70525
# [1710]	validation_0-auc:0.70503
# [1720]	validation_0-auc:0.70495
# [1730]	validation_0-auc:0.70485
# [1740]	validation_0-auc:0.70472
# [1750]	validation_0-auc:0.70458
# [1760]	validation_0-auc:0.70444
# [1770]	validation_0-auc:0.70435
# [1780]	validation_0-auc:0.70422
# [1790]	validation_0-auc:0.70409
# [1800]	validation_0-auc:0.70403
# [1810]	validation_0-auc:0.70389
# [1820]	validation_0-auc:0.70382
# [1830]	validation_0-auc:0.70362
# [1840]	validation_0-auc:0.70342
# [1850]	validation_0-auc:0.70334
# [1860]	validation_0-auc:0.70325
# [1870]	validation_0-auc:0.70314
# [1880]	validation_0-auc:0.70297
# [1890]	validation_0-auc:0.70290
# [1900]	validation_0-auc:0.70286
# [1910]	validation_0-auc:0.70267
# [1920]	validation_0-auc:0.70256
# [1930]	validation_0-auc:0.70245
# [1940]	validation_0-auc:0.70235
# [1950]	validation_0-auc:0.70227
# [1960]	validation_0-auc:0.70212
# [1970]	validation_0-auc:0.70191
# [1980]	validation_0-auc:0.70175
# [1990]	validation_0-auc:0.70162
# [2000]	validation_0-auc:0.70145
# [2010]	validation_0-auc:0.70122
# [2020]	validation_0-auc:0.70115
# [2030]	validation_0-auc:0.70095
# [2040]	validation_0-auc:0.70074
# [2050]	validation_0-auc:0.70060
# [2060]	validation_0-auc:0.70051
# [2070]	validation_0-auc:0.70051
# [2080]	validation_0-auc:0.70039
# [2090]	validation_0-auc:0.70025
# [2100]	validation_0-auc:0.70010
# [2110]	validation_0-auc:0.69993
# [2120]	validation_0-auc:0.69978
# [2130]	validation_0-auc:0.69965
# [2140]	validation_0-auc:0.69952
# [2150]	validation_0-auc:0.69943
# [2160]	validation_0-auc:0.69934
# [2170]	validation_0-auc:0.69928
# [2180]	validation_0-auc:0.69916
# [2190]	validation_0-auc:0.69902
# [2200]	validation_0-auc:0.69882
# [2210]	validation_0-auc:0.69877
# [2220]	validation_0-auc:0.69869
# [2230]	validation_0-auc:0.69850
# [2240]	validation_0-auc:0.69845
# [2250]	validation_0-auc:0.69829
# [2260]	validation_0-auc:0.69817
# [2270]	validation_0-auc:0.69807
# [2280]	validation_0-auc:0.69803
# [2290]	validation_0-auc:0.69793
# [2300]	validation_0-auc:0.69781
# [2310]	validation_0-auc:0.69774
# [2320]	validation_0-auc:0.69759
# [2330]	validation_0-auc:0.69748
# [2340]	validation_0-auc:0.69739
# [2350]	validation_0-auc:0.69742
# [2360]	validation_0-auc:0.69728
# [2370]	validation_0-auc:0.69716
# [2380]	validation_0-auc:0.69712
# [2390]	validation_0-auc:0.69701
# [2400]	validation_0-auc:0.69687
# [2410]	validation_0-auc:0.69671
# [2420]	validation_0-auc:0.69665
# [2430]	validation_0-auc:0.69651
# [2440]	validation_0-auc:0.69627
# [2450]	validation_0-auc:0.69615
# [2460]	validation_0-auc:0.69606
# [2470]	validation_0-auc:0.69585
# [2480]	validation_0-auc:0.69575
# [2490]	validation_0-auc:0.69564
# [2500]	validation_0-auc:0.69554
# [2510]	validation_0-auc:0.69545
# [2520]	validation_0-auc:0.69534
# [2530]	validation_0-auc:0.69517
# [2540]	validation_0-auc:0.69510
# [2550]	validation_0-auc:0.69499
# [2560]	validation_0-auc:0.69481
# [2570]	validation_0-auc:0.69468
# [2580]	validation_0-auc:0.69455
# [2590]	validation_0-auc:0.69442
# [2600]	validation_0-auc:0.69429
# [2610]	validation_0-auc:0.69406
# [2620]	validation_0-auc:0.69390
# [2630]	validation_0-auc:0.69380
# [2640]	validation_0-auc:0.69373
# [2650]	validation_0-auc:0.69363
# [2660]	validation_0-auc:0.69350
# [2670]	validation_0-auc:0.69350
# [2680]	validation_0-auc:0.69339
# [2690]	validation_0-auc:0.69329
# [2700]	validation_0-auc:0.69314
# [2710]	validation_0-auc:0.69295
# [2720]	validation_0-auc:0.69280
# [2730]	validation_0-auc:0.69279
# [2740]	validation_0-auc:0.69265
# [2750]	validation_0-auc:0.69254
# [2760]	validation_0-auc:0.69244
# [2770]	validation_0-auc:0.69232
# [2780]	validation_0-auc:0.69215
# [2790]	validation_0-auc:0.69201
# [2800]	validation_0-auc:0.69180
# [2810]	validation_0-auc:0.69152
# [2820]	validation_0-auc:0.69142
# [2830]	validation_0-auc:0.69128
# [2840]	validation_0-auc:0.69120
# [2850]	validation_0-auc:0.69109
# [2860]	validation_0-auc:0.69104
# [2870]	validation_0-auc:0.69096
# [2880]	validation_0-auc:0.69086
# [2890]	validation_0-auc:0.69073
# [2900]	validation_0-auc:0.69066
# [2910]	validation_0-auc:0.69048
# [2920]	validation_0-auc:0.69042
# [2930]	validation_0-auc:0.69034
# [2940]	validation_0-auc:0.69019
# [2950]	validation_0-auc:0.69009
# [2960]	validation_0-auc:0.68999
# [2970]	validation_0-auc:0.68988
# [2980]	validation_0-auc:0.68983
# [2990]	validation_0-auc:0.68964
# [3000]	validation_0-auc:0.68957
# [3010]	validation_0-auc:0.68947
# [3020]	validation_0-auc:0.68926
# [3030]	validation_0-auc:0.68916
# [3040]	validation_0-auc:0.68905
# [3050]	validation_0-auc:0.68895
# [3060]	validation_0-auc:0.68887
# [3070]	validation_0-auc:0.68883
# [3080]	validation_0-auc:0.68865
# [3090]	validation_0-auc:0.68857
# [3100]	validation_0-auc:0.68838
# [3110]	validation_0-auc:0.68831
# [3120]	validation_0-auc:0.68819
# [3130]	validation_0-auc:0.68810
# [3140]	validation_0-auc:0.68794
# [3150]	validation_0-auc:0.68774
# [3160]	validation_0-auc:0.68759
# [3170]	validation_0-auc:0.68741
# [3180]	validation_0-auc:0.68731
# [3190]	validation_0-auc:0.68721
# [3200]	validation_0-auc:0.68704
# [3210]	validation_0-auc:0.68695
# [3220]	validation_0-auc:0.68683
# [3230]	validation_0-auc:0.68672
# [3240]	validation_0-auc:0.68659
# [3250]	validation_0-auc:0.68646
# [3260]	validation_0-auc:0.68636
# [3270]	validation_0-auc:0.68629
# [3280]	validation_0-auc:0.68617
# [3290]	validation_0-auc:0.68601
# [3300]	validation_0-auc:0.68586
# [3310]	validation_0-auc:0.68570
# [3320]	validation_0-auc:0.68563
# [3330]	validation_0-auc:0.68557
# [3340]	validation_0-auc:0.68546
# [3350]	validation_0-auc:0.68538
# [3360]	validation_0-auc:0.68531
# [3370]	validation_0-auc:0.68523
# [3380]	validation_0-auc:0.68515
# [3390]	validation_0-auc:0.68506
# [3400]	validation_0-auc:0.68500
# [3410]	validation_0-auc:0.68492
# [3420]	validation_0-auc:0.68479
# [3430]	validation_0-auc:0.68470
# [3440]	validation_0-auc:0.68464
# [3450]	validation_0-auc:0.68459
# [3460]	validation_0-auc:0.68449
# [3470]	validation_0-auc:0.68432
# [3480]	validation_0-auc:0.68426
# [3490]	validation_0-auc:0.68409
# [3500]	validation_0-auc:0.68400
# [3510]	validation_0-auc:0.68386
# [3520]	validation_0-auc:0.68376
# [3530]	validation_0-auc:0.68368
# [3540]	validation_0-auc:0.68349
# [3550]	validation_0-auc:0.68340
# [3560]	validation_0-auc:0.68330
# [3570]	validation_0-auc:0.68322
# [3580]	validation_0-auc:0.68314
# [3590]	validation_0-auc:0.68298
# [3600]	validation_0-auc:0.68297
# [3610]	validation_0-auc:0.68286
# [3620]	validation_0-auc:0.68280
# [3630]	validation_0-auc:0.68271
# [3640]	validation_0-auc:0.68266
# [3650]	validation_0-auc:0.68250
# [3660]	validation_0-auc:0.68235
# [3670]	validation_0-auc:0.68222
# [3680]	validation_0-auc:0.68210
# [3690]	validation_0-auc:0.68209
# [3700]	validation_0-auc:0.68196
# [3710]	validation_0-auc:0.68185
# [3720]	validation_0-auc:0.68175
# [3730]	validation_0-auc:0.68165
# [3740]	validation_0-auc:0.68151
# [3750]	validation_0-auc:0.68144
# [3760]	validation_0-auc:0.68129
# [3770]	validation_0-auc:0.68115
# [3780]	validation_0-auc:0.68106
# [3790]	validation_0-auc:0.68093
# [3800]	validation_0-auc:0.68084
# [3810]	validation_0-auc:0.68070
# [3820]	validation_0-auc:0.68064
# [3830]	validation_0-auc:0.68053
# [3840]	validation_0-auc:0.68044
# [3850]	validation_0-auc:0.68033
# [3860]	validation_0-auc:0.68023
# [3870]	validation_0-auc:0.68009
# [3880]	validation_0-auc:0.67995
# [3890]	validation_0-auc:0.67984
# [3900]	validation_0-auc:0.67975
# [3910]	validation_0-auc:0.67970
# [3920]	validation_0-auc:0.67965
# [3930]	validation_0-auc:0.67956
# [3940]	validation_0-auc:0.67947
# [3950]	validation_0-auc:0.67936
# [3960]	validation_0-auc:0.67921
# [3970]	validation_0-auc:0.67914
# [3980]	validation_0-auc:0.67907
# [3990]	validation_0-auc:0.67894
# [4000]	validation_0-auc:0.67888
# [4010]	validation_0-auc:0.67879
# [4020]	validation_0-auc:0.67872
# [4030]	validation_0-auc:0.67863
# [4040]	validation_0-auc:0.67851
# [4050]	validation_0-auc:0.67848
# [4060]	validation_0-auc:0.67839
# [4070]	validation_0-auc:0.67829
# [4080]	validation_0-auc:0.67820
# [4090]	validation_0-auc:0.67811
# [4100]	validation_0-auc:0.67803
# [4110]	validation_0-auc:0.67792
# [4120]	validation_0-auc:0.67780
# [4130]	validation_0-auc:0.67769
# [4140]	validation_0-auc:0.67750
# [4150]	validation_0-auc:0.67744
# [4160]	validation_0-auc:0.67730
# [4170]	validation_0-auc:0.67711
# [4180]	validation_0-auc:0.67702
# [4190]	validation_0-auc:0.67690
# [4200]	validation_0-auc:0.67680
# [4210]	validation_0-auc:0.67672
# [4220]	validation_0-auc:0.67658
# [4230]	validation_0-auc:0.67646
# [4240]	validation_0-auc:0.67632
# [4250]	validation_0-auc:0.67630
# [4260]	validation_0-auc:0.67621
# [4270]	validation_0-auc:0.67609
# [4280]	validation_0-auc:0.67597
# [4290]	validation_0-auc:0.67590
# [4300]	validation_0-auc:0.67582
# [4310]	validation_0-auc:0.67569
# [4320]	validation_0-auc:0.67562
# [4330]	validation_0-auc:0.67555
# [4340]	validation_0-auc:0.67549
# [4350]	validation_0-auc:0.67545
# [4360]	validation_0-auc:0.67541
# [4370]	validation_0-auc:0.67529
# [4380]	validation_0-auc:0.67521
# [4390]	validation_0-auc:0.67506
# [4400]	validation_0-auc:0.67498
# [4410]	validation_0-auc:0.67490
# [4420]	validation_0-auc:0.67482
# [4430]	validation_0-auc:0.67471
# [4440]	validation_0-auc:0.67466
# [4450]	validation_0-auc:0.67453
# [4460]	validation_0-auc:0.67444
# [4470]	validation_0-auc:0.67433
# [4480]	validation_0-auc:0.67428
# [4490]	validation_0-auc:0.67417
# [4500]	validation_0-auc:0.67404
# [4510]	validation_0-auc:0.67395
# [4520]	validation_0-auc:0.67392
# [4530]	validation_0-auc:0.67385
# [4540]	validation_0-auc:0.67382
# [4550]	validation_0-auc:0.67373
# [4560]	validation_0-auc:0.67367
# [4570]	validation_0-auc:0.67360
# [4580]	validation_0-auc:0.67352
# [4590]	validation_0-auc:0.67343
# [4600]	validation_0-auc:0.67332
# [4610]	validation_0-auc:0.67328
# [4620]	validation_0-auc:0.67317
# [4630]	validation_0-auc:0.67311
# [4640]	validation_0-auc:0.67301
# [4650]	validation_0-auc:0.67297
# [4660]	validation_0-auc:0.67287
# [4670]	validation_0-auc:0.67278
# [4680]	validation_0-auc:0.67278
# [4690]	validation_0-auc:0.67269
# [4700]	validation_0-auc:0.67266
# [4710]	validation_0-auc:0.67254
# [4720]	validation_0-auc:0.67252
# [4730]	validation_0-auc:0.67252
# [4740]	validation_0-auc:0.67246
# [4750]	validation_0-auc:0.67238
# [4760]	validation_0-auc:0.67228
# [4770]	validation_0-auc:0.67218
# [4780]	validation_0-auc:0.67210
# [4790]	validation_0-auc:0.67205
# [4800]	validation_0-auc:0.67195
# [4810]	validation_0-auc:0.67190
# [4820]	validation_0-auc:0.67179
# [4830]	validation_0-auc:0.67170
# [4840]	validation_0-auc:0.67164
# [4850]	validation_0-auc:0.67158
# [4860]	validation_0-auc:0.67146
# [4870]	validation_0-auc:0.67134
# [4880]	validation_0-auc:0.67131
# [4890]	validation_0-auc:0.67128
# [4900]	validation_0-auc:0.67118
# [4910]	validation_0-auc:0.67112
# [4920]	validation_0-auc:0.67109
# [4930]	validation_0-auc:0.67102
# [4940]	validation_0-auc:0.67097
# [4950]	validation_0-auc:0.67085
# [4960]	validation_0-auc:0.67076
# [4970]	validation_0-auc:0.67064
# [4980]	validation_0-auc:0.67054
# [4990]	validation_0-auc:0.67048
# [5000]	validation_0-auc:0.67035
# [5010]	validation_0-auc:0.67032
# [5020]	validation_0-auc:0.67021
# [5030]	validation_0-auc:0.67019
# [5040]	validation_0-auc:0.67012
# [5050]	validation_0-auc:0.67004
# [5060]	validation_0-auc:0.66997
# [5070]	validation_0-auc:0.66993
# [5080]	validation_0-auc:0.66984
# [5090]	validation_0-auc:0.66974
# [5100]	validation_0-auc:0.66967
# [5110]	validation_0-auc:0.66962
# [5120]	validation_0-auc:0.66954
# [5130]	validation_0-auc:0.66948
# [5140]	validation_0-auc:0.66939
# [5150]	validation_0-auc:0.66927
# [5160]	validation_0-auc:0.66918
# [5170]	validation_0-auc:0.66915
# [5180]	validation_0-auc:0.66912
# [5190]	validation_0-auc:0.66909
# [5199]	validation_0-auc:0.66907
# Training completed in 2124.64 seconds
# Fold 2 Accuracy: 0.9695
# Fold 2 AUC: 0.6691
#
# ===== Fold 3 =====
#
# Training started...
# [0]	validation_0-auc:0.64168
# [10]	validation_0-auc:0.69718
# [20]	validation_0-auc:0.70326
# [30]	validation_0-auc:0.70426
# [40]	validation_0-auc:0.70621
# [50]	validation_0-auc:0.70705
# [60]	validation_0-auc:0.70751
# [70]	validation_0-auc:0.70865
# [80]	validation_0-auc:0.70894
# [90]	validation_0-auc:0.70934
# [100]	validation_0-auc:0.70945
# [110]	validation_0-auc:0.70977
# [120]	validation_0-auc:0.70988
# [130]	validation_0-auc:0.70985
# [140]	validation_0-auc:0.71004
# [150]	validation_0-auc:0.71036
# [160]	validation_0-auc:0.71017
# [170]	validation_0-auc:0.71034
# [180]	validation_0-auc:0.71033
# [190]	validation_0-auc:0.71062
# [200]	validation_0-auc:0.71057
# [210]	validation_0-auc:0.71051
# [220]	validation_0-auc:0.71054
# [230]	validation_0-auc:0.71067
# [240]	validation_0-auc:0.71066
# [250]	validation_0-auc:0.71063
# [260]	validation_0-auc:0.71050
# [270]	validation_0-auc:0.71053
# [280]	validation_0-auc:0.71062
# [290]	validation_0-auc:0.71069
# [300]	validation_0-auc:0.71050
# [310]	validation_0-auc:0.71046
# [320]	validation_0-auc:0.71050
# [330]	validation_0-auc:0.71048
# [340]	validation_0-auc:0.71050
# [350]	validation_0-auc:0.71055
# [360]	validation_0-auc:0.71055
# [370]	validation_0-auc:0.71040
# [380]	validation_0-auc:0.71041
# [390]	validation_0-auc:0.71039
# [400]	validation_0-auc:0.71014
# [410]	validation_0-auc:0.71006
# [420]	validation_0-auc:0.71005
# [430]	validation_0-auc:0.70988
# [440]	validation_0-auc:0.70992
# [450]	validation_0-auc:0.70990
# [460]	validation_0-auc:0.70978
# [470]	validation_0-auc:0.70969
# [480]	validation_0-auc:0.70944
# [490]	validation_0-auc:0.70922
# [500]	validation_0-auc:0.70911
# [510]	validation_0-auc:0.70901
# [520]	validation_0-auc:0.70894
# [530]	validation_0-auc:0.70886
# [540]	validation_0-auc:0.70875
# [550]	validation_0-auc:0.70863
# [560]	validation_0-auc:0.70853
# [570]	validation_0-auc:0.70842
# [580]	validation_0-auc:0.70848
# [590]	validation_0-auc:0.70823
# [600]	validation_0-auc:0.70796
# [610]	validation_0-auc:0.70794
# [620]	validation_0-auc:0.70801
# [630]	validation_0-auc:0.70782
# [640]	validation_0-auc:0.70768
# [650]	validation_0-auc:0.70745
# [660]	validation_0-auc:0.70724
# [670]	validation_0-auc:0.70713
# [680]	validation_0-auc:0.70689
# [690]	validation_0-auc:0.70675
# [700]	validation_0-auc:0.70662
# [710]	validation_0-auc:0.70653
# [720]	validation_0-auc:0.70635
# [730]	validation_0-auc:0.70618
# [740]	validation_0-auc:0.70610
# [750]	validation_0-auc:0.70599
# [760]	validation_0-auc:0.70584
# [770]	validation_0-auc:0.70583
# [780]	validation_0-auc:0.70578
# [790]	validation_0-auc:0.70581
# [800]	validation_0-auc:0.70566
# [810]	validation_0-auc:0.70545
# [820]	validation_0-auc:0.70532
# [830]	validation_0-auc:0.70521
# [840]	validation_0-auc:0.70509
# [850]	validation_0-auc:0.70476
# [860]	validation_0-auc:0.70459
# [870]	validation_0-auc:0.70432
# [880]	validation_0-auc:0.70424
# [890]	validation_0-auc:0.70418
# [900]	validation_0-auc:0.70401
# [910]	validation_0-auc:0.70394
# [920]	validation_0-auc:0.70382
# [930]	validation_0-auc:0.70365
# [940]	validation_0-auc:0.70370
# [950]	validation_0-auc:0.70355
# [960]	validation_0-auc:0.70342
# [970]	validation_0-auc:0.70316
# [980]	validation_0-auc:0.70295
# [990]	validation_0-auc:0.70289
# [1000]	validation_0-auc:0.70274
# [1010]	validation_0-auc:0.70257
# [1020]	validation_0-auc:0.70248
# [1030]	validation_0-auc:0.70234
# [1040]	validation_0-auc:0.70217
# [1050]	validation_0-auc:0.70193
# [1060]	validation_0-auc:0.70178
# [1070]	validation_0-auc:0.70167
# [1080]	validation_0-auc:0.70160
# [1090]	validation_0-auc:0.70149
# [1100]	validation_0-auc:0.70133
# [1110]	validation_0-auc:0.70108
# [1120]	validation_0-auc:0.70098
# [1130]	validation_0-auc:0.70084
# [1140]	validation_0-auc:0.70076
# [1150]	validation_0-auc:0.70057
# [1160]	validation_0-auc:0.70040
# [1170]	validation_0-auc:0.70037
# [1180]	validation_0-auc:0.70031
# [1190]	validation_0-auc:0.70022
# [1200]	validation_0-auc:0.70022
# [1210]	validation_0-auc:0.70009
# [1220]	validation_0-auc:0.69998
# [1230]	validation_0-auc:0.69979
# [1240]	validation_0-auc:0.69956
# [1250]	validation_0-auc:0.69938
# [1260]	validation_0-auc:0.69928
# [1270]	validation_0-auc:0.69904
# [1280]	validation_0-auc:0.69896
# [1290]	validation_0-auc:0.69885
# [1300]	validation_0-auc:0.69865
# [1310]	validation_0-auc:0.69851
# [1320]	validation_0-auc:0.69839
# [1330]	validation_0-auc:0.69815
# [1340]	validation_0-auc:0.69795
# [1350]	validation_0-auc:0.69774
# [1360]	validation_0-auc:0.69749
# [1370]	validation_0-auc:0.69729
# [1380]	validation_0-auc:0.69722
# [1390]	validation_0-auc:0.69698
# [1400]	validation_0-auc:0.69684
# [1410]	validation_0-auc:0.69673
# [1420]	validation_0-auc:0.69641
# [1430]	validation_0-auc:0.69632
# [1440]	validation_0-auc:0.69616
# [1450]	validation_0-auc:0.69604
# [1460]	validation_0-auc:0.69587
# [1470]	validation_0-auc:0.69579
# [1480]	validation_0-auc:0.69557
# [1490]	validation_0-auc:0.69545
# [1500]	validation_0-auc:0.69529
# [1510]	validation_0-auc:0.69523
# [1520]	validation_0-auc:0.69510
# [1530]	validation_0-auc:0.69497
# [1540]	validation_0-auc:0.69488
# [1550]	validation_0-auc:0.69473
# [1560]	validation_0-auc:0.69458
# [1570]	validation_0-auc:0.69449
# [1580]	validation_0-auc:0.69430
# [1590]	validation_0-auc:0.69414
# [1600]	validation_0-auc:0.69402
# [1610]	validation_0-auc:0.69384
# [1620]	validation_0-auc:0.69375
# [1630]	validation_0-auc:0.69365
# [1640]	validation_0-auc:0.69350
# [1650]	validation_0-auc:0.69342
# [1660]	validation_0-auc:0.69333
# [1670]	validation_0-auc:0.69320
# [1680]	validation_0-auc:0.69306
# [1690]	validation_0-auc:0.69290
# [1700]	validation_0-auc:0.69270
# [1710]	validation_0-auc:0.69260
# [1720]	validation_0-auc:0.69240
# [1730]	validation_0-auc:0.69221
# [1740]	validation_0-auc:0.69203
# [1750]	validation_0-auc:0.69186
# [1760]	validation_0-auc:0.69174
# [1770]	validation_0-auc:0.69163
# [1780]	validation_0-auc:0.69142
# [1790]	validation_0-auc:0.69130
# [1800]	validation_0-auc:0.69113
# [1810]	validation_0-auc:0.69094
# [1820]	validation_0-auc:0.69085
# [1830]	validation_0-auc:0.69067
# [1840]	validation_0-auc:0.69057
# [1850]	validation_0-auc:0.69046
# [1860]	validation_0-auc:0.69037
# [1870]	validation_0-auc:0.69029
# [1880]	validation_0-auc:0.69020
# [1890]	validation_0-auc:0.69013
# [1900]	validation_0-auc:0.68999
# [1910]	validation_0-auc:0.68986
# [1920]	validation_0-auc:0.68979
# [1930]	validation_0-auc:0.68963
# [1940]	validation_0-auc:0.68957
# [1950]	validation_0-auc:0.68935
# [1960]	validation_0-auc:0.68914
# [1970]	validation_0-auc:0.68911
# [1980]	validation_0-auc:0.68886
# [1990]	validation_0-auc:0.68876
# [2000]	validation_0-auc:0.68875
# [2010]	validation_0-auc:0.68868
# [2020]	validation_0-auc:0.68853
# [2030]	validation_0-auc:0.68849
# [2040]	validation_0-auc:0.68843
# [2050]	validation_0-auc:0.68826
# [2060]	validation_0-auc:0.68816
# [2070]	validation_0-auc:0.68805
# [2080]	validation_0-auc:0.68798
# [2090]	validation_0-auc:0.68784
# [2100]	validation_0-auc:0.68772
# [2110]	validation_0-auc:0.68757
# [2120]	validation_0-auc:0.68743
# [2130]	validation_0-auc:0.68720
# [2140]	validation_0-auc:0.68705
# [2150]	validation_0-auc:0.68690
# [2160]	validation_0-auc:0.68675
# [2170]	validation_0-auc:0.68664
# [2180]	validation_0-auc:0.68654
# [2190]	validation_0-auc:0.68646
# [2200]	validation_0-auc:0.68627
# [2210]	validation_0-auc:0.68605
# [2220]	validation_0-auc:0.68595
# [2230]	validation_0-auc:0.68579
# [2240]	validation_0-auc:0.68568
# [2250]	validation_0-auc:0.68556
# [2260]	validation_0-auc:0.68539
# [2270]	validation_0-auc:0.68530
# [2280]	validation_0-auc:0.68515
# [2290]	validation_0-auc:0.68506
# [2300]	validation_0-auc:0.68492
# [2310]	validation_0-auc:0.68480
# [2320]	validation_0-auc:0.68470
# [2330]	validation_0-auc:0.68457
# [2340]	validation_0-auc:0.68440
# [2350]	validation_0-auc:0.68422
# [2360]	validation_0-auc:0.68410
# [2370]	validation_0-auc:0.68391
# [2380]	validation_0-auc:0.68385
# [2390]	validation_0-auc:0.68372
# [2400]	validation_0-auc:0.68363
# [2410]	validation_0-auc:0.68340
# [2420]	validation_0-auc:0.68328
# [2430]	validation_0-auc:0.68316
# [2440]	validation_0-auc:0.68306
# [2450]	validation_0-auc:0.68288
# [2460]	validation_0-auc:0.68277
# [2470]	validation_0-auc:0.68272
# [2480]	validation_0-auc:0.68255
# [2490]	validation_0-auc:0.68235
# [2500]	validation_0-auc:0.68223
# [2510]	validation_0-auc:0.68208
# [2520]	validation_0-auc:0.68186
# [2530]	validation_0-auc:0.68176
# [2540]	validation_0-auc:0.68162
# [2550]	validation_0-auc:0.68150
# [2560]	validation_0-auc:0.68136
# [2570]	validation_0-auc:0.68122
# [2580]	validation_0-auc:0.68109
# [2590]	validation_0-auc:0.68095
# [2600]	validation_0-auc:0.68097
# [2610]	validation_0-auc:0.68083
# [2620]	validation_0-auc:0.68069
# [2630]	validation_0-auc:0.68070
# [2640]	validation_0-auc:0.68052
# [2650]	validation_0-auc:0.68036
# [2660]	validation_0-auc:0.68022
# [2670]	validation_0-auc:0.68009
# [2680]	validation_0-auc:0.67994
# [2690]	validation_0-auc:0.67970
# [2700]	validation_0-auc:0.67964
# [2710]	validation_0-auc:0.67945
# [2720]	validation_0-auc:0.67934
# [2730]	validation_0-auc:0.67923
# [2740]	validation_0-auc:0.67910
# [2750]	validation_0-auc:0.67894
# [2760]	validation_0-auc:0.67879
# [2770]	validation_0-auc:0.67873
# [2780]	validation_0-auc:0.67852
# [2790]	validation_0-auc:0.67841
# [2800]	validation_0-auc:0.67826
# [2810]	validation_0-auc:0.67801
# [2820]	validation_0-auc:0.67786
# [2830]	validation_0-auc:0.67768
# [2840]	validation_0-auc:0.67755
# [2850]	validation_0-auc:0.67748
# [2860]	validation_0-auc:0.67733
# [2870]	validation_0-auc:0.67719
# [2880]	validation_0-auc:0.67703
# [2890]	validation_0-auc:0.67691
# [2900]	validation_0-auc:0.67682
# [2910]	validation_0-auc:0.67662
# [2920]	validation_0-auc:0.67639
# [2930]	validation_0-auc:0.67624
# [2940]	validation_0-auc:0.67613
# [2950]	validation_0-auc:0.67604
# [2960]	validation_0-auc:0.67591
# [2970]	validation_0-auc:0.67571
# [2980]	validation_0-auc:0.67557
# [2990]	validation_0-auc:0.67543
# [3000]	validation_0-auc:0.67534
# [3010]	validation_0-auc:0.67515
# [3020]	validation_0-auc:0.67497
# [3030]	validation_0-auc:0.67482
# [3040]	validation_0-auc:0.67470
# [3050]	validation_0-auc:0.67454
# [3060]	validation_0-auc:0.67444
# [3070]	validation_0-auc:0.67423
# [3080]	validation_0-auc:0.67414
# [3090]	validation_0-auc:0.67401
# [3100]	validation_0-auc:0.67383
# [3110]	validation_0-auc:0.67365
# [3120]	validation_0-auc:0.67352
# [3130]	validation_0-auc:0.67333
# [3140]	validation_0-auc:0.67328
# [3150]	validation_0-auc:0.67314
# [3160]	validation_0-auc:0.67303
# [3170]	validation_0-auc:0.67293
# [3180]	validation_0-auc:0.67278
# [3190]	validation_0-auc:0.67262
# [3200]	validation_0-auc:0.67251
# [3210]	validation_0-auc:0.67237
# [3220]	validation_0-auc:0.67224
# [3230]	validation_0-auc:0.67208
# [3240]	validation_0-auc:0.67182
# [3250]	validation_0-auc:0.67166
# [3260]	validation_0-auc:0.67164
# [3270]	validation_0-auc:0.67156
# [3280]	validation_0-auc:0.67140
# [3290]	validation_0-auc:0.67131
# [3300]	validation_0-auc:0.67114
# [3310]	validation_0-auc:0.67106
# [3320]	validation_0-auc:0.67093
# [3330]	validation_0-auc:0.67077
# [3340]	validation_0-auc:0.67067
# [3350]	validation_0-auc:0.67054
# [3360]	validation_0-auc:0.67035
# [3370]	validation_0-auc:0.67025
# [3380]	validation_0-auc:0.67024
# [3390]	validation_0-auc:0.67012
# [3400]	validation_0-auc:0.66991
# [3410]	validation_0-auc:0.66980
# [3420]	validation_0-auc:0.66971
# [3430]	validation_0-auc:0.66960
# [3440]	validation_0-auc:0.66939
# [3450]	validation_0-auc:0.66930
# [3460]	validation_0-auc:0.66920
# [3470]	validation_0-auc:0.66909
# [3480]	validation_0-auc:0.66902
# [3490]	validation_0-auc:0.66890
# [3500]	validation_0-auc:0.66874
# [3510]	validation_0-auc:0.66872
# [3520]	validation_0-auc:0.66860
# [3530]	validation_0-auc:0.66852
# [3540]	validation_0-auc:0.66835
# [3550]	validation_0-auc:0.66823
# [3560]	validation_0-auc:0.66807
# [3570]	validation_0-auc:0.66786
# [3580]	validation_0-auc:0.66774
# [3590]	validation_0-auc:0.66755
# [3600]	validation_0-auc:0.66742
# [3610]	validation_0-auc:0.66732
# [3620]	validation_0-auc:0.66721
# [3630]	validation_0-auc:0.66707
# [3640]	validation_0-auc:0.66692
# [3650]	validation_0-auc:0.66687
# [3660]	validation_0-auc:0.66675
# [3670]	validation_0-auc:0.66673
# [3680]	validation_0-auc:0.66658
# [3690]	validation_0-auc:0.66648
# [3700]	validation_0-auc:0.66632
# [3710]	validation_0-auc:0.66618
# [3720]	validation_0-auc:0.66606
# [3730]	validation_0-auc:0.66591
# [3740]	validation_0-auc:0.66580
# [3750]	validation_0-auc:0.66568
# [3760]	validation_0-auc:0.66557
# [3770]	validation_0-auc:0.66549
# [3780]	validation_0-auc:0.66545
# [3790]	validation_0-auc:0.66532
# [3800]	validation_0-auc:0.66528
# [3810]	validation_0-auc:0.66514
# [3820]	validation_0-auc:0.66500
# [3830]	validation_0-auc:0.66486
# [3840]	validation_0-auc:0.66473
# [3850]	validation_0-auc:0.66459
# [3860]	validation_0-auc:0.66445
# [3870]	validation_0-auc:0.66430
# [3880]	validation_0-auc:0.66420
# [3890]	validation_0-auc:0.66409
# [3900]	validation_0-auc:0.66396
# [3910]	validation_0-auc:0.66383
# [3920]	validation_0-auc:0.66379
# [3930]	validation_0-auc:0.66367
# [3940]	validation_0-auc:0.66354
# [3950]	validation_0-auc:0.66343
# [3960]	validation_0-auc:0.66330
# [3970]	validation_0-auc:0.66321
# [3980]	validation_0-auc:0.66318
# [3990]	validation_0-auc:0.66313
# [4000]	validation_0-auc:0.66308
# [4010]	validation_0-auc:0.66293
# [4020]	validation_0-auc:0.66284
# [4030]	validation_0-auc:0.66269
# [4040]	validation_0-auc:0.66257
# [4050]	validation_0-auc:0.66246
# [4060]	validation_0-auc:0.66236
# [4070]	validation_0-auc:0.66224
# [4080]	validation_0-auc:0.66212
# [4090]	validation_0-auc:0.66206
# [4100]	validation_0-auc:0.66196
# [4110]	validation_0-auc:0.66189
# [4120]	validation_0-auc:0.66176
# [4130]	validation_0-auc:0.66169
# [4140]	validation_0-auc:0.66158
# [4150]	validation_0-auc:0.66147
# [4160]	validation_0-auc:0.66142
# [4170]	validation_0-auc:0.66130
# [4180]	validation_0-auc:0.66122
# [4190]	validation_0-auc:0.66110
# [4200]	validation_0-auc:0.66101
# [4210]	validation_0-auc:0.66091
# [4220]	validation_0-auc:0.66082
# [4230]	validation_0-auc:0.66069
# [4240]	validation_0-auc:0.66061
# [4250]	validation_0-auc:0.66045
# [4260]	validation_0-auc:0.66029
# [4270]	validation_0-auc:0.66016
# [4280]	validation_0-auc:0.66010
# [4290]	validation_0-auc:0.66004
# [4300]	validation_0-auc:0.65990
# [4310]	validation_0-auc:0.65985
# [4320]	validation_0-auc:0.65976
# [4330]	validation_0-auc:0.65970
# [4340]	validation_0-auc:0.65964
# [4350]	validation_0-auc:0.65949
# [4360]	validation_0-auc:0.65936
# [4370]	validation_0-auc:0.65926
# [4380]	validation_0-auc:0.65912
# [4390]	validation_0-auc:0.65903
# [4400]	validation_0-auc:0.65898
# [4410]	validation_0-auc:0.65891
# [4420]	validation_0-auc:0.65888
# [4430]	validation_0-auc:0.65885
# [4440]	validation_0-auc:0.65875
# [4450]	validation_0-auc:0.65864
# [4460]	validation_0-auc:0.65859
# [4470]	validation_0-auc:0.65846
# [4480]	validation_0-auc:0.65835
# [4490]	validation_0-auc:0.65829
# [4500]	validation_0-auc:0.65819
# [4510]	validation_0-auc:0.65804
# [4520]	validation_0-auc:0.65794
# [4530]	validation_0-auc:0.65785
# [4540]	validation_0-auc:0.65774
# [4550]	validation_0-auc:0.65765
# [4560]	validation_0-auc:0.65754
# [4570]	validation_0-auc:0.65742
# [4580]	validation_0-auc:0.65733
# ...
# [290]	validation_0-auc:0.72077
# [300]	validation_0-auc:0.72070
# [310]	validation_0-auc:0.72081
# [320]	validation_0-auc:0.72079
# [330]	validation_0-auc:0.72092
# [340]	validation_0-auc:0.72091
# [350]	validation_0-auc:0.72082
# [360]	validation_0-auc:0.72068
# [370]	validation_0-auc:0.72061
# [380]	validation_0-auc:0.72044
# [390]	validation_0-auc:0.72035
# [400]	validation_0-auc:0.72036
# [410]	validation_0-auc:0.72037
# [420]	validation_0-auc:0.72016
# [430]	validation_0-auc:0.71994
# [440]	validation_0-auc:0.71984
# [450]	validation_0-auc:0.71968
# [460]	validation_0-auc:0.71970
# [470]	validation_0-auc:0.71967
# [480]	validation_0-auc:0.71960
# [490]	validation_0-auc:0.71957
# [500]	validation_0-auc:0.71952
# [510]	validation_0-auc:0.71957
# [520]	validation_0-auc:0.71948
# [530]	validation_0-auc:0.71935
# [540]	validation_0-auc:0.71928
# [550]	validation_0-auc:0.71924
# [560]	validation_0-auc:0.71925
# [570]	validation_0-auc:0.71920
# [580]	validation_0-auc:0.71912
# [590]	validation_0-auc:0.71893
# [600]	validation_0-auc:0.71876
# [610]	validation_0-auc:0.71867
# [620]	validation_0-auc:0.71843
# [630]	validation_0-auc:0.71837
# [640]	validation_0-auc:0.71828
# [650]	validation_0-auc:0.71811
# [660]	validation_0-auc:0.71796
# [670]	validation_0-auc:0.71794
# [680]	validation_0-auc:0.71777
# [690]	validation_0-auc:0.71777
# [700]	validation_0-auc:0.71770
# [710]	validation_0-auc:0.71756
# [720]	validation_0-auc:0.71738
# [730]	validation_0-auc:0.71724
# [740]	validation_0-auc:0.71714
# [750]	validation_0-auc:0.71705
# [760]	validation_0-auc:0.71693
# [770]	validation_0-auc:0.71690
# [780]	validation_0-auc:0.71680
# [790]	validation_0-auc:0.71662
# [800]	validation_0-auc:0.71657
# [810]	validation_0-auc:0.71637
# [820]	validation_0-auc:0.71621
# [830]	validation_0-auc:0.71624
# [840]	validation_0-auc:0.71609
# [850]	validation_0-auc:0.71601
# [860]	validation_0-auc:0.71584
# [870]	validation_0-auc:0.71571
# [880]	validation_0-auc:0.71558
# [890]	validation_0-auc:0.71552
# [900]	validation_0-auc:0.71530
# [910]	validation_0-auc:0.71521
# [920]	validation_0-auc:0.71510
# [930]	validation_0-auc:0.71490
# [940]	validation_0-auc:0.71485
# [950]	validation_0-auc:0.71480
# [960]	validation_0-auc:0.71473
# [970]	validation_0-auc:0.71455
# [980]	validation_0-auc:0.71452
# [990]	validation_0-auc:0.71440
# [1000]	validation_0-auc:0.71434
# [1010]	validation_0-auc:0.71419
# [1020]	validation_0-auc:0.71406
# [1030]	validation_0-auc:0.71386
# [1040]	validation_0-auc:0.71374
# [1050]	validation_0-auc:0.71356
# [1060]	validation_0-auc:0.71347
# [1070]	validation_0-auc:0.71329
# [1080]	validation_0-auc:0.71318
# [1090]	validation_0-auc:0.71301
# [1100]	validation_0-auc:0.71292
# [1110]	validation_0-auc:0.71269
# [1120]	validation_0-auc:0.71252
# [1130]	validation_0-auc:0.71236
# [1140]	validation_0-auc:0.71219
# [1150]	validation_0-auc:0.71212
# [1160]	validation_0-auc:0.71198
# [1170]	validation_0-auc:0.71178
# [1180]	validation_0-auc:0.71166
# [1190]	validation_0-auc:0.71151
# [1200]	validation_0-auc:0.71155
# [1210]	validation_0-auc:0.71147
# [1220]	validation_0-auc:0.71132
# [1230]	validation_0-auc:0.71129
# [1240]	validation_0-auc:0.71105
# [1250]	validation_0-auc:0.71090
# [1260]	validation_0-auc:0.71083
# [1270]	validation_0-auc:0.71080
# [1280]	validation_0-auc:0.71070
# [1290]	validation_0-auc:0.71052
# [1300]	validation_0-auc:0.71043
# [1310]	validation_0-auc:0.71028
# [1320]	validation_0-auc:0.71015
# [1330]	validation_0-auc:0.71005
# [1340]	validation_0-auc:0.70989
# [1350]	validation_0-auc:0.70977
# [1360]	validation_0-auc:0.70958
# [1370]	validation_0-auc:0.70944
# [1380]	validation_0-auc:0.70925
# [1390]	validation_0-auc:0.70914
# [1400]	validation_0-auc:0.70899
# [1410]	validation_0-auc:0.70881
# [1420]	validation_0-auc:0.70864
# [1430]	validation_0-auc:0.70851
# [1440]	validation_0-auc:0.70849
# [1450]	validation_0-auc:0.70834
# [1460]	validation_0-auc:0.70820
# [1470]	validation_0-auc:0.70810
# [1480]	validation_0-auc:0.70788
# [1490]	validation_0-auc:0.70780
# [1500]	validation_0-auc:0.70766
# [1510]	validation_0-auc:0.70752
# [1520]	validation_0-auc:0.70747
# [1530]	validation_0-auc:0.70742
# [1540]	validation_0-auc:0.70730
# [1550]	validation_0-auc:0.70724
# [1560]	validation_0-auc:0.70710
# [1570]	validation_0-auc:0.70693
# [1580]	validation_0-auc:0.70682
# [1590]	validation_0-auc:0.70673
# [1600]	validation_0-auc:0.70658
# [1610]	validation_0-auc:0.70647
# [1620]	validation_0-auc:0.70636
# [1630]	validation_0-auc:0.70624
# [1640]	validation_0-auc:0.70610
# [1650]	validation_0-auc:0.70592
# [1660]	validation_0-auc:0.70581
# [1670]	validation_0-auc:0.70559
# [1680]	validation_0-auc:0.70543
# [1690]	validation_0-auc:0.70527
# [1700]	validation_0-auc:0.70518
# [1710]	validation_0-auc:0.70505
# [1720]	validation_0-auc:0.70495
# [1730]	validation_0-auc:0.70489
# [1740]	validation_0-auc:0.70480
# [1750]	validation_0-auc:0.70473
# [1760]	validation_0-auc:0.70466
# [1770]	validation_0-auc:0.70443
# [1780]	validation_0-auc:0.70432
# [1790]	validation_0-auc:0.70416
# [1800]	validation_0-auc:0.70407
# [1810]	validation_0-auc:0.70386
# [1820]	validation_0-auc:0.70367
# [1830]	validation_0-auc:0.70351
# [1840]	validation_0-auc:0.70337
# [1850]	validation_0-auc:0.70323
# [1860]	validation_0-auc:0.70312
# [1870]	validation_0-auc:0.70299
# [1880]	validation_0-auc:0.70286
# [1890]	validation_0-auc:0.70274
# [1900]	validation_0-auc:0.70256
# [1910]	validation_0-auc:0.70253
# [1920]	validation_0-auc:0.70241
# [1930]	validation_0-auc:0.70226
# [1940]	validation_0-auc:0.70207
# [1950]	validation_0-auc:0.70189
# [1960]	validation_0-auc:0.70181
# [1970]	validation_0-auc:0.70167
# [1980]	validation_0-auc:0.70149
# [1990]	validation_0-auc:0.70136
# [2000]	validation_0-auc:0.70120
# [2010]	validation_0-auc:0.70099
# [2020]	validation_0-auc:0.70085
# [2030]	validation_0-auc:0.70067
# [2040]	validation_0-auc:0.70057
# [2050]	validation_0-auc:0.70042
# [2060]	validation_0-auc:0.70027
# [2070]	validation_0-auc:0.70007
# [2080]	validation_0-auc:0.69999
# [2090]	validation_0-auc:0.69985
# [2100]	validation_0-auc:0.69972
# [2110]	validation_0-auc:0.69963
# [2120]	validation_0-auc:0.69950
# [2130]	validation_0-auc:0.69927
# [2140]	validation_0-auc:0.69910
# [2150]	validation_0-auc:0.69900
# [2160]	validation_0-auc:0.69899
# [2170]	validation_0-auc:0.69888
# [2180]	validation_0-auc:0.69879
# [2190]	validation_0-auc:0.69867
# [2200]	validation_0-auc:0.69844
# [2210]	validation_0-auc:0.69828
# [2220]	validation_0-auc:0.69821
# [2230]	validation_0-auc:0.69811
# [2240]	validation_0-auc:0.69799
# [2250]	validation_0-auc:0.69781
# [2260]	validation_0-auc:0.69777
# [2270]	validation_0-auc:0.69773
# [2280]	validation_0-auc:0.69749
# [2290]	validation_0-auc:0.69735
# [2300]	validation_0-auc:0.69723
# [2310]	validation_0-auc:0.69713
# [2320]	validation_0-auc:0.69702
# [2330]	validation_0-auc:0.69688
# [2340]	validation_0-auc:0.69677
# [2350]	validation_0-auc:0.69663
# [2360]	validation_0-auc:0.69658
# [2370]	validation_0-auc:0.69644
# [2380]	validation_0-auc:0.69626
# [2390]	validation_0-auc:0.69613
# [2400]	validation_0-auc:0.69599
# [2410]	validation_0-auc:0.69586
# [2420]	validation_0-auc:0.69574
# [2430]	validation_0-auc:0.69560
# [2440]	validation_0-auc:0.69553
# [2450]	validation_0-auc:0.69544
# [2460]	validation_0-auc:0.69529
# [2470]	validation_0-auc:0.69523
# [2480]	validation_0-auc:0.69514
# [2490]	validation_0-auc:0.69500
# [2500]	validation_0-auc:0.69486
# [2510]	validation_0-auc:0.69471
# [2520]	validation_0-auc:0.69458
# [2530]	validation_0-auc:0.69452
# [2540]	validation_0-auc:0.69440
# [2550]	validation_0-auc:0.69418
# [2560]	validation_0-auc:0.69404
# [2570]	validation_0-auc:0.69387
# [2580]	validation_0-auc:0.69371
# [2590]	validation_0-auc:0.69360
# [2600]	validation_0-auc:0.69350
# [2610]	validation_0-auc:0.69334
# [2620]	validation_0-auc:0.69327
# [2630]	validation_0-auc:0.69321
# [2640]	validation_0-auc:0.69306
# [2650]	validation_0-auc:0.69300
# [2660]	validation_0-auc:0.69287
# [2670]	validation_0-auc:0.69264
# [2680]	validation_0-auc:0.69257
# [2690]	validation_0-auc:0.69238
# [2700]	validation_0-auc:0.69219
# [2710]	validation_0-auc:0.69210
# [2720]	validation_0-auc:0.69199
# [2730]	validation_0-auc:0.69185
# [2740]	validation_0-auc:0.69176
# [2750]	validation_0-auc:0.69161
# [2760]	validation_0-auc:0.69147
# [2770]	validation_0-auc:0.69127
# [2780]	validation_0-auc:0.69117
# [2790]	validation_0-auc:0.69107
# [2800]	validation_0-auc:0.69089
# [2810]	validation_0-auc:0.69077
# [2820]	validation_0-auc:0.69067
# [2830]	validation_0-auc:0.69049
# [2840]	validation_0-auc:0.69030
# [2850]	validation_0-auc:0.69021
# [2860]	validation_0-auc:0.69009
# [2870]	validation_0-auc:0.69001
# [2880]	validation_0-auc:0.68987
# [2890]	validation_0-auc:0.68985
# [2900]	validation_0-auc:0.68975
# [2910]	validation_0-auc:0.68964
# [2920]	validation_0-auc:0.68955
# [2930]	validation_0-auc:0.68942
# [2940]	validation_0-auc:0.68923
# [2950]	validation_0-auc:0.68911
# [2960]	validation_0-auc:0.68895
# [2970]	validation_0-auc:0.68885
# [2980]	validation_0-auc:0.68876
# [2990]	validation_0-auc:0.68866
# [3000]	validation_0-auc:0.68852
# [3010]	validation_0-auc:0.68841
# [3020]	validation_0-auc:0.68831
# [3030]	validation_0-auc:0.68826
# [3040]	validation_0-auc:0.68811
# [3050]	validation_0-auc:0.68803
# [3060]	validation_0-auc:0.68794
# [3070]	validation_0-auc:0.68780
# [3080]	validation_0-auc:0.68775
# [3090]	validation_0-auc:0.68751
# [3100]	validation_0-auc:0.68742
# [3110]	validation_0-auc:0.68725
# [3120]	validation_0-auc:0.68721
# [3130]	validation_0-auc:0.68711
# [3140]	validation_0-auc:0.68697
# [3150]	validation_0-auc:0.68695
# [3160]	validation_0-auc:0.68683
# [3170]	validation_0-auc:0.68669
# [3180]	validation_0-auc:0.68657
# [3190]	validation_0-auc:0.68650
# [3200]	validation_0-auc:0.68638
# [3210]	validation_0-auc:0.68624
# [3220]	validation_0-auc:0.68619
# [3230]	validation_0-auc:0.68601
# [3240]	validation_0-auc:0.68593
# [3250]	validation_0-auc:0.68581
# [3260]	validation_0-auc:0.68567
# [3270]	validation_0-auc:0.68547
# [3280]	validation_0-auc:0.68536
# [3290]	validation_0-auc:0.68524
# [3300]	validation_0-auc:0.68515
# [3310]	validation_0-auc:0.68506
# [3320]	validation_0-auc:0.68497
# [3330]	validation_0-auc:0.68481
# [3340]	validation_0-auc:0.68467
# [3350]	validation_0-auc:0.68457
# [3360]	validation_0-auc:0.68448
# [3370]	validation_0-auc:0.68437
# [3380]	validation_0-auc:0.68428
# [3390]	validation_0-auc:0.68411
# [3400]	validation_0-auc:0.68402
# [3410]	validation_0-auc:0.68391
# [3420]	validation_0-auc:0.68382
# [3430]	validation_0-auc:0.68359
# [3440]	validation_0-auc:0.68347
# [3450]	validation_0-auc:0.68332
# [3460]	validation_0-auc:0.68319
# [3470]	validation_0-auc:0.68309
# [3480]	validation_0-auc:0.68295
# [3490]	validation_0-auc:0.68284
# [3500]	validation_0-auc:0.68273
# [3510]	validation_0-auc:0.68263
# [3520]	validation_0-auc:0.68250
# [3530]	validation_0-auc:0.68237
# [3540]	validation_0-auc:0.68224
# [3550]	validation_0-auc:0.68210
# [3560]	validation_0-auc:0.68200
# [3570]	validation_0-auc:0.68191
# [3580]	validation_0-auc:0.68179
# [3590]	validation_0-auc:0.68172
# [3600]	validation_0-auc:0.68172
# [3610]	validation_0-auc:0.68164
# [3620]	validation_0-auc:0.68154
# [3630]	validation_0-auc:0.68144
# [3640]	validation_0-auc:0.68137
# [3650]	validation_0-auc:0.68125
# [3660]	validation_0-auc:0.68116
# [3670]	validation_0-auc:0.68104
# [3680]	validation_0-auc:0.68097
# [3690]	validation_0-auc:0.68080
# [3700]	validation_0-auc:0.68069
# [3710]	validation_0-auc:0.68055
# [3720]	validation_0-auc:0.68042
# [3730]	validation_0-auc:0.68035
# [3740]	validation_0-auc:0.68034
# [3750]	validation_0-auc:0.68024
# [3760]	validation_0-auc:0.68022
# [3770]	validation_0-auc:0.68016
# [3780]	validation_0-auc:0.68003
# [3790]	validation_0-auc:0.67986
# [3800]	validation_0-auc:0.67974
# [3810]	validation_0-auc:0.67965
# [3820]	validation_0-auc:0.67958
# [3830]	validation_0-auc:0.67941
# [3840]	validation_0-auc:0.67931
# [3850]	validation_0-auc:0.67923
# [3860]	validation_0-auc:0.67911
# [3870]	validation_0-auc:0.67898
# [3880]	validation_0-auc:0.67893
# [3890]	validation_0-auc:0.67875
# [3900]	validation_0-auc:0.67863
# [3910]	validation_0-auc:0.67851
# [3920]	validation_0-auc:0.67846
# [3930]	validation_0-auc:0.67839
# [3940]	validation_0-auc:0.67828
# [3950]	validation_0-auc:0.67816
# [3960]	validation_0-auc:0.67805
# [3970]	validation_0-auc:0.67798
# [3980]	validation_0-auc:0.67790
# [3990]	validation_0-auc:0.67788
# [4000]	validation_0-auc:0.67779
# [4010]	validation_0-auc:0.67777
# [4020]	validation_0-auc:0.67767
# [4030]	validation_0-auc:0.67758
# [4040]	validation_0-auc:0.67746
# [4050]	validation_0-auc:0.67735
# [4060]	validation_0-auc:0.67731
# [4070]	validation_0-auc:0.67723
# [4080]	validation_0-auc:0.67715
# [4090]	validation_0-auc:0.67701
# [4100]	validation_0-auc:0.67685
# [4110]	validation_0-auc:0.67673
# [4120]	validation_0-auc:0.67665
# [4130]	validation_0-auc:0.67658
# [4140]	validation_0-auc:0.67650
# [4150]	validation_0-auc:0.67643
# [4160]	validation_0-auc:0.67638
# [4170]	validation_0-auc:0.67632
# [4180]	validation_0-auc:0.67624
# [4190]	validation_0-auc:0.67617
# [4200]	validation_0-auc:0.67606
# [4210]	validation_0-auc:0.67599
# [4220]	validation_0-auc:0.67590
# [4230]	validation_0-auc:0.67578
# [4240]	validation_0-auc:0.67567
# [4250]	validation_0-auc:0.67564
# [4260]	validation_0-auc:0.67550
# [4270]	validation_0-auc:0.67533
# [4280]	validation_0-auc:0.67522
# [4290]	validation_0-auc:0.67516
# [4300]	validation_0-auc:0.67505
# [4310]	validation_0-auc:0.67496
# [4320]	validation_0-auc:0.67489
# [4330]	validation_0-auc:0.67481
# [4340]	validation_0-auc:0.67468
# [4350]	validation_0-auc:0.67464
# [4360]	validation_0-auc:0.67459
# [4370]	validation_0-auc:0.67452
# [4380]	validation_0-auc:0.67444
# [4390]	validation_0-auc:0.67434
# [4400]	validation_0-auc:0.67427
# [4410]	validation_0-auc:0.67417
# [4420]	validation_0-auc:0.67409
# [4430]	validation_0-auc:0.67395
# [4440]	validation_0-auc:0.67384
# [4450]	validation_0-auc:0.67376
# [4460]	validation_0-auc:0.67368
# [4470]	validation_0-auc:0.67366
# [4480]	validation_0-auc:0.67362
# [4490]	validation_0-auc:0.67351
# [4500]	validation_0-auc:0.67342
# [4510]	validation_0-auc:0.67332
# [4520]	validation_0-auc:0.67329
# [4530]	validation_0-auc:0.67312
# [4540]	validation_0-auc:0.67308
# [4550]	validation_0-auc:0.67297
# [4560]	validation_0-auc:0.67289
# [4570]	validation_0-auc:0.67281
# [4580]	validation_0-auc:0.67269
# [4590]	validation_0-auc:0.67262
# [4600]	validation_0-auc:0.67251
# [4610]	validation_0-auc:0.67235
# [4620]	validation_0-auc:0.67225
# [4630]	validation_0-auc:0.67213
# [4640]	validation_0-auc:0.67203
# [4650]	validation_0-auc:0.67195
# [4660]	validation_0-auc:0.67192
# [4670]	validation_0-auc:0.67181
# [4680]	validation_0-auc:0.67174
# [4690]	validation_0-auc:0.67165
# [4700]	validation_0-auc:0.67163
# [4710]	validation_0-auc:0.67157
# [4720]	validation_0-auc:0.67152
# [4730]	validation_0-auc:0.67144
# [4740]	validation_0-auc:0.67132
# [4750]	validation_0-auc:0.67127
# [4760]	validation_0-auc:0.67116
# [4770]	validation_0-auc:0.67107
# [4780]	validation_0-auc:0.67099
# [4790]	validation_0-auc:0.67092
# [4800]	validation_0-auc:0.67076
# [4810]	validation_0-auc:0.67071
# [4820]	validation_0-auc:0.67065
# [4830]	validation_0-auc:0.67055
# [4840]	validation_0-auc:0.67047
# [4850]	validation_0-auc:0.67039
# [4860]	validation_0-auc:0.67031
# [4870]	validation_0-auc:0.67028
# [4880]	validation_0-auc:0.67016
# [4890]	validation_0-auc:0.67001
# [4900]	validation_0-auc:0.66995
# [4910]	validation_0-auc:0.66986
# [4920]	validation_0-auc:0.66980
# [4930]	validation_0-auc:0.66977
# [4940]	validation_0-auc:0.66970
# [4950]	validation_0-auc:0.66958
# [4960]	validation_0-auc:0.66948
# [4970]	validation_0-auc:0.66939
# [4980]	validation_0-auc:0.66939
# [4990]	validation_0-auc:0.66931
# [5000]	validation_0-auc:0.66930
# [5010]	validation_0-auc:0.66930
# [5020]	validation_0-auc:0.66920
# [5030]	validation_0-auc:0.66909
# [5040]	validation_0-auc:0.66900
# [5050]	validation_0-auc:0.66899
# [5060]	validation_0-auc:0.66890
# [5070]	validation_0-auc:0.66878
# [5080]	validation_0-auc:0.66870
# [5090]	validation_0-auc:0.66853
# [5100]	validation_0-auc:0.66843
# [5110]	validation_0-auc:0.66845
# [5120]	validation_0-auc:0.66837
# [5130]	validation_0-auc:0.66830
# [5140]	validation_0-auc:0.66828
# [5150]	validation_0-auc:0.66819
# [5160]	validation_0-auc:0.66810
# [5170]	validation_0-auc:0.66805
# [5180]	validation_0-auc:0.66802
# [5190]	validation_0-auc:0.66802
# [5199]	validation_0-auc:0.66793
# Training completed in 2868.23 seconds
# Fold 5 Accuracy: 0.9703
# Fold 5 AUC: 0.6679
#
# === Final Results ===
# Average Accuracy: 0.9699 ± 0.0004
# Average AUC: 0.6631 ± 0.0061
# Average Training Time: 2567.68 seconds
#
# Best model from Fold 2 with AUC: 0.6691
# Best model saved as best_xgboost_model_fold2_auc0.6691.joblib

# %%
external_indices = df[df['Region'].isin(['Scotland', 'Wales'])].index
# 获取苏格兰和威尔士参与者的数据
X_external = data_imputed_df.loc[external_indices]  # 特征
y_external = df.loc[external_indices, 'status']  # 标签
print("外部验证集形状:", X_external.shape)
X_external
# 预测类别（0/1）
y_pred = best_model.predict(X_external)
# 预测概率（用于 AUC 等指标）
y_pred_proba = best_model.predict_proba(X_external)[:, 1]  # 正类的概率
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# 计算准确率和 AUC
accuracy = accuracy_score(y_external, y_pred)
auc = roc_auc_score(y_external, y_pred_proba)

print(f"测试集准确率: {accuracy:.4f}")
print(f"测试集 AUC: {auc:.4f}")
# Out:
# 外部验证集形状: (50653, 194)
# 测试集准确率: 0.9567
# 测试集 AUC: 0.6826

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score
import time
import joblib
# 筛选来自英格兰的参与者
england_indices = df[df['Region'] == 'England'].index
X_england = data_imputed_df.loc[england_indices]
y_england = df.loc[england_indices, 'status']

# 定义5折交叉验证
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# 存储每折的评估结果
accuracy_scores = []
auc_scores = []
training_times = []
models = []
# 计算类别权重（需要在循环内计算，因为每折的分布可能不同）
# 注意：这里我们会在循环内计算，因为y_train在每折不同

# 固定参数（从你的网格中取第一个值）
params = {
    'alpha': 1.5,          # L1 正则化
    'lambda': 1.5,         # L2 正则化
    'colsample_bytree': 0.75,  # 特征采样比例
    'n_estimators': 400,
    'learning_rate': 0.01,
    'max_depth': 3,
    'subsample': 0.7,
    'min_child_weight': 3,
    'gamma': 0.9,
    'eval_metric':'auc'
}
# 开始交叉验证
for fold, (train_idx, val_idx) in enumerate(kf.split(X_england), 1):
    try:
        print(f"\n===== Fold {fold} =====\n")
        X_train, X_val = X_england.iloc[train_idx], X_england.iloc[val_idx]
        y_train, y_val = y_england.iloc[train_idx], y_england.iloc[val_idx]

        # 计算当前fold的类别权重
        scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)
        current_params = params.copy()
        current_params['scale_pos_weight'] = scale_pos_weight

        # 初始化模型
        model = XGBClassifier(**current_params)

        # 训练模型并计时
        start_time = time.time()
        print("Training started...")
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=10  # 每10轮显示一次进度
        )
        training_time = time.time() - start_time
        training_times.append(training_time)
        print(f"Training completed in {training_time:.2f} seconds")

        # 预测
        y_pred = model.predict(X_val)
        y_pred_proba = model.predict_proba(X_val)[:, 1]  # 获取正类的概率

        # 评估
        accuracy = accuracy_score(y_val, y_pred)
        auc = roc_auc_score(y_val, y_pred_proba)

        accuracy_scores.append(accuracy)
        auc_scores.append(auc)
        models.append(model)  # 保存当前fold的模型
        print(f"Fold {fold} Accuracy: {accuracy:.4f}")
        print(f"Fold {fold} AUC: {auc:.4f}")

    except KeyboardInterrupt:
        print("\nTraining interrupted by user")
        break
    except Exception as e:
        print(f"\nError occurred during fold {fold}: {str(e)}")
        continue

# 输出结果
if accuracy_scores:
    print("\n=== Final Results ===")
    print(f"Average Accuracy: {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
    print(f"Average AUC: {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
    print(f"Average Training Time: {np.mean(training_times):.2f} seconds")

    # 找到AUC最高的fold
    best_fold = np.argmax(auc_scores)
    best_model = models[best_fold]
    best_auc = auc_scores[best_fold]

    print(f"\nBest model from Fold {best_fold + 1} with AUC: {best_auc:.4f}")

    # 保存最佳模型
    model_filename = f"best_xgboost_model_fold{best_fold + 1}_auc{best_auc:.4f}.joblib"
    # joblib.dump(best_model, model_filename)
    print(f"Best model saved as {model_filename}")
else:
    print("\nNo valid results were obtained")
# Out:
# ===== Fold 1 =====
#
# Training started...
# [0]	validation_0-auc:0.68671
# [10]	validation_0-auc:0.70096
# [20]	validation_0-auc:0.70281
# [30]	validation_0-auc:0.70396
# [40]	validation_0-auc:0.70550
# [50]	validation_0-auc:0.70669
# [60]	validation_0-auc:0.70728
# [70]	validation_0-auc:0.70811
# [80]	validation_0-auc:0.70883
# [90]	validation_0-auc:0.70975
# [100]	validation_0-auc:0.71047
# [110]	validation_0-auc:0.71139
# [120]	validation_0-auc:0.71206
# [130]	validation_0-auc:0.71279
# [140]	validation_0-auc:0.71315
# [150]	validation_0-auc:0.71390
# [160]	validation_0-auc:0.71432
# [170]	validation_0-auc:0.71493
# [180]	validation_0-auc:0.71532
# [190]	validation_0-auc:0.71584
# [200]	validation_0-auc:0.71619
# [210]	validation_0-auc:0.71676
# [220]	validation_0-auc:0.71715
# [230]	validation_0-auc:0.71746
# [240]	validation_0-auc:0.71773
# [250]	validation_0-auc:0.71792
# [260]	validation_0-auc:0.71832
# [270]	validation_0-auc:0.71859
# [280]	validation_0-auc:0.71880
# [290]	validation_0-auc:0.71907
# [300]	validation_0-auc:0.71926
# [310]	validation_0-auc:0.71958
# [320]	validation_0-auc:0.71978
# [330]	validation_0-auc:0.72005
# [340]	validation_0-auc:0.72032
# [350]	validation_0-auc:0.72049
# [360]	validation_0-auc:0.72071
# [370]	validation_0-auc:0.72086
# [380]	validation_0-auc:0.72104
# [390]	validation_0-auc:0.72116
# [399]	validation_0-auc:0.72133
# Training completed in 62.92 seconds
# Fold 1 Accuracy: 0.6408
# Fold 1 AUC: 0.7213
#
# ===== Fold 2 =====
#
# Training started...
# [0]	validation_0-auc:0.69079
# [10]	validation_0-auc:0.70848
# [20]	validation_0-auc:0.70986
# [30]	validation_0-auc:0.71189
# [40]	validation_0-auc:0.71299
# [50]	validation_0-auc:0.71420
# [60]	validation_0-auc:0.71500
# [70]	validation_0-auc:0.71556
# [80]	validation_0-auc:0.71635
# [90]	validation_0-auc:0.71701
# [100]	validation_0-auc:0.71776
# [110]	validation_0-auc:0.71850
# [120]	validation_0-auc:0.71906
# [130]	validation_0-auc:0.71967
# [140]	validation_0-auc:0.72027
# [150]	validation_0-auc:0.72113
# [160]	validation_0-auc:0.72201
# [170]	validation_0-auc:0.72237
# [180]	validation_0-auc:0.72281
# [190]	validation_0-auc:0.72349
# [200]	validation_0-auc:0.72403
# [210]	validation_0-auc:0.72454
# [220]	validation_0-auc:0.72507
# [230]	validation_0-auc:0.72553
# [240]	validation_0-auc:0.72599
# [250]	validation_0-auc:0.72636
# [260]	validation_0-auc:0.72667
# [270]	validation_0-auc:0.72710
# [280]	validation_0-auc:0.72741
# [290]	validation_0-auc:0.72766
# [300]	validation_0-auc:0.72803
# [310]	validation_0-auc:0.72827
# [320]	validation_0-auc:0.72860
# [330]	validation_0-auc:0.72893
# [340]	validation_0-auc:0.72921
# [350]	validation_0-auc:0.72946
# [360]	validation_0-auc:0.72965
# [370]	validation_0-auc:0.72984
# [380]	validation_0-auc:0.73006
# [390]	validation_0-auc:0.73030
# [399]	validation_0-auc:0.73049
# Training completed in 109.25 seconds
# Fold 2 Accuracy: 0.6437
# Fold 2 AUC: 0.7305
#
# ===== Fold 3 =====
#
# Training started...
# [0]	validation_0-auc:0.68462
# [10]	validation_0-auc:0.69858
# [20]	validation_0-auc:0.69989
# [30]	validation_0-auc:0.70209
# [40]	validation_0-auc:0.70359
# [50]	validation_0-auc:0.70505
# [60]	validation_0-auc:0.70571
# [70]	validation_0-auc:0.70600
# [80]	validation_0-auc:0.70693
# [90]	validation_0-auc:0.70791
# [100]	validation_0-auc:0.70837
# [110]	validation_0-auc:0.70888
# [120]	validation_0-auc:0.70959
# [130]	validation_0-auc:0.71027
# [140]	validation_0-auc:0.71092
# [150]	validation_0-auc:0.71133
# [160]	validation_0-auc:0.71179
# [170]	validation_0-auc:0.71240
# [180]	validation_0-auc:0.71280
# [190]	validation_0-auc:0.71317
# [200]	validation_0-auc:0.71371
# [210]	validation_0-auc:0.71420
# [220]	validation_0-auc:0.71479
#
# Error occurred during fold 3: bad allocation
#
# ===== Fold 4 =====
#
#
# Error occurred during fold 4: Unable to allocate 462. MiB for an array with shape (190, 318477) and data type float64
#
# ===== Fold 5 =====
#
#
# Error occurred during fold 5: Unable to allocate 462. MiB for an array with shape (190, 318477) and data type float64
#
# === Final Results ===
# Average Accuracy: 0.6422 ± 0.0015
# Average AUC: 0.7259 ± 0.0046
# Average Training Time: 86.08 seconds
#
# Best model from Fold 2 with AUC: 0.7305
# Best model saved as best_xgboost_model_fold2_auc0.7305.joblib

# %%
external_indices = df[df['Region'].isin(['Scotland', 'Wales'])].index
# 获取苏格兰和威尔士参与者的数据
X_external = data_imputed_df.loc[external_indices]  # 特征
y_external = df.loc[external_indices, 'status']  # 标签
print("外部验证集形状:", X_external.shape)
X_external
# 预测类别（0/1）
y_pred = best_model.predict(X_external)
# 预测概率（用于 AUC 等指标）
y_pred_proba = best_model.predict_proba(X_external)[:, 1]  # 正类的概率
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# 计算准确率和 AUC
accuracy = accuracy_score(y_external, y_pred)
auc = roc_auc_score(y_external, y_pred_proba)

print(f"测试集准确率: {accuracy:.4f}")
print(f"测试集 AUC: {auc:.4f}")
# Out:
# 外部验证集形状: (50653, 194)
# 测试集准确率: 0.6486
# 测试集 AUC: 0.7344

# %%
# 4. 用最佳模型预测
y_proba = best_model.predict_proba(X_val)[:, 1]
# 5. 计算并绘制 ROC 曲线
fpr, tpr, _ = roc_curve(y_val, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('Best XGBoost ROC Curve(internal)')
plt.legend()
plt.show()
#绘制混淆矩阵
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 使用最佳模型进行预测
y_pred = best_model.predict(X_val)

# 计算混淆矩阵
cm = confusion_matrix(y_val, y_pred)

# 可视化混淆矩阵
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['No Stroke', 'Stroke'])
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix for Stroke Prediction(internal)')
plt.show()
#外部 4. 用最佳模型预测
y_proba = best_model.predict_proba(X_external)[:, 1]
# 5. 计算并绘制 ROC 曲线
fpr, tpr, _ = roc_curve(y_external, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('Best XGBoost ROC Curve(external)')
plt.legend()
plt.show()
#绘制混淆矩阵
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 使用最佳模型进行预测
y_pred = best_model.predict(X_external)

# 计算混淆矩阵
cm = confusion_matrix(y_external, y_pred)

# 可视化混淆矩阵
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['No Stroke', 'Stroke'])
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix for Stroke Prediction(external)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 # 5. 计算并绘制 ROC 曲线
#       4 fpr, tpr, _ = roc_curve(y_val, y_proba)
# ----> 5 roc_auc = auc(fpr, tpr)
#       7 plt.figure()
#       8 plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.2f})')
#
# TypeError: 'numpy.float64' object is not callable
